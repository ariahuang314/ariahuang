# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
from tqdm import tqdm
import re
import csv

# 加载DeBERTa模型和分词器
model_name = "microsoft/deberta-base"  # 只需引用，transformers会自动下载模型
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

# 初始化NER pipeline
nlp = pipeline("ner", model=model, tokenizer=tokenizer)

# 读取清洗过的TXT文件
def read_text_file(txt_file_path):
    with open(txt_file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def split_text(text, max_len=512):
    # 将文本分段处理，以适应BERT输入限制
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    chunks = []
    current_chunk = ""
    for sentence in sentences:
        if len(current_chunk) + len(sentence) < max_len:
            current_chunk += " " + sentence
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence
    if current_chunk:
        chunks.append(current_chunk.strip())
    return chunks

# 提取ESG数据，增加进度条显示
def extract_esg_data(text_chunks):
    esg_data = []
    for chunk in tqdm(text_chunks, desc="Extracting ESG Data"):
        entities = nlp(chunk)
        current_data = {}
        for entity in entities:
            label = entity["entity"]
            word = entity["word"]
            # 根据标签分类存储
            if label == "LABEL_INDICATOR":  # 替换为DeBERTa模型的指标标签
                current_data["indicator"] = word
            elif label == "LABEL_VALUE":  # 替换为DeBERTa模型的数据值标签
                current_data["value"] = word
            elif label == "LABEL_UNIT":  # 替换为DeBERTa模型的单位标签
                current_data["unit"] = word
            # 如果当前数据项完整，保存到结果中
            if "indicator" in current_data and "value" in current_data and "unit" in current_data:
                esg_data.append(current_data)
                current_data = {}
    return esg_data

# 保存提取的数据到CSV
def save_to_csv(esg_data, output_csv_path):
    keys = ["indicator", "value", "unit"]
    with open(output_csv_path, 'w', newline='', encoding='utf-8') as output_file:
        dict_writer = csv.DictWriter(output_file, fieldnames=keys)
        dict_writer.writeheader()
        dict_writer.writerows(esg_data)
    print(f"Data saved to {output_csv_path}")

# 使用示例
txt_file_path = '../output/1030_split.txt'
output_csv_path = '../output_metric/esg_data.csv'

# 读取和提取文本
text = read_text_file(txt_file_path)
# text_chunks = [text]  # 假设不分段，直接传入整个文本
text_chunks = split_text(text)

# 提取ESG数据并显示进度
esg_data = extract_esg_data(text_chunks)

# 保存到CSV
save_to_csv(esg_data, output_csv_path)
# Out:
# Some weights of DebertaForTokenClassification were not initialized from the model checkpoint at microsoft/deberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Extracting ESG Data:   0%|          | 0/128 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Extracting ESG Data: 100%|██████████| 128/128 [01:05<00:00,  1.96it/s]
# Data saved to ../output_metric/esg_data.csv

# %%
print(model.config.id2label)
# Out:
# {0: 'LABEL_0', 1: 'LABEL_1'}

# %%
import json
# 将数据转为BIO格式
def convert_to_bio(data):
    bio_data = []
    
    for item in data:
        sentence_tokens = []
        sentence_labels = []
        
        # Process the metric (indicator)
        if item["metric"]:
            metric_tokens = item["metric"].split()
            sentence_tokens.extend(metric_tokens)
            # 标记第一个词为B-INDICATOR，其余为I-INDICATOR
            sentence_labels.append("B-INDICATOR")
            sentence_labels.extend(["I-INDICATOR"] * (len(metric_tokens) - 1))
        
        # Process the value
        if item["value"]:
            value_tokens = str(item["value"]).split()
            sentence_tokens.extend(value_tokens)
            # 标记第一个词为B-VALUE
            sentence_labels.append("B-VALUE")
            sentence_labels.extend(["I-VALUE"] * (len(value_tokens) - 1))
        
        # Process the unit
        if item["unit"]:
            unit_tokens = item["unit"].split()
            sentence_tokens.extend(unit_tokens)
            # 标记第一个词为B-UNIT，其余为I-UNIT
            sentence_labels.append("B-UNIT")
            sentence_labels.extend(["I-UNIT"] * (len(unit_tokens) - 1))
        
        # Append sentence tokens and labels to bio_data
        bio_sentence = list(zip(sentence_tokens, sentence_labels))
        bio_data.append(bio_sentence)
    
    return bio_data

# 读取JSON文件
with open("../json/grouped_data_full1.json", "r") as file:
    data = json.load(file)

# 转换为BIO格式
bio_data = convert_to_bio(data)

# 保存为BIO格式的文本文件
with open("../output/bio_data.txt", "w") as file:
    for sentence in bio_data:
        for word, label in sentence:
            file.write(f"{word} {label}\n")
        file.write("\n")  # 每个句子之间用空行分隔

# %%
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from datasets import load_dataset

# 使用 BERT 基础模型
model_name = "bert-base-uncased"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name, num_labels=3)  # 根据任务设置标签数

# 加载和处理 ESG 数据集
dataset = load_dataset('text', data_files="../output/bio_data.txt")  # 替换为 ESG 数据集路径
def preprocess_data(examples):
    return tokenizer(examples['text'], truncation=True, padding="max_length")

encoded_dataset = dataset.map(preprocess_data, batched=True)

# 定义训练参数
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
)

# 使用 Trainer API 进行微调
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=encoded_dataset["train"],
    eval_dataset=encoded_dataset["test"],
)

trainer.train()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/119 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 17
#      14 encoded_dataset = dataset.map(preprocess_data, batched=True)
#      16 # 定义训练参数
# ---> 17 training_args = TrainingArguments(
#      18     output_dir="./results",
#      19     evaluation_strategy="epoch",
#      20     learning_rate=2e-5,
#      21     per_device_train_batch_size=8,
#      22     per_device_eval_batch_size=8,
#      23     num_train_epochs=3,
#      24     weight_decay=0.01,
#      25 )
#      27 # 使用 Trainer API 进行微调
#      28 trainer = Trainer(
#      29     model=model,
#      30     args=training_args,
#      31     train_dataset=encoded_dataset["train"],
#      32     eval_dataset=encoded_dataset["test"],
#      33 )
#
# File <string>:132, in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, eval_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, torch_empty_cache_steps, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, lr_scheduler_kwargs, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, save_only_model, restore_callback_states_from_checkpoint, no_cuda, use_cpu, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, dataloader_prefetch_factor, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, fsdp, fsdp_min_num_params, fsdp_config, fsdp_transformer_layer_cls_to_wrap, accelerator_config, deepspeed, label_smoothing_factor, optim, optim_args, adafactor, group_by_length, length_column_name, report_to, ddp_find_unused_parameters, ddp_bucket_cap_mb, ddp_broadcast_buffers, dataloader_pin_memory, dataloader_persistent_workers, skip_memory_metrics, use_legacy_prediction_loop, push_to_hub, resume_from_checkpoint, hub_model_id, hub_strategy, hub_token, hub_private_repo, hub_always_push, gradient_checkpointing, gradient_checkpointing_kwargs, include_inputs_for_metrics, eval_do_concat_batches, fp16_backend, evaluation_strategy, push_to_hub_model_id, push_to_hub_organization, push_to_hub_token, mp_parameters, auto_find_batch_size, full_determinism, torchdynamo, ray_scope, ddp_timeout, torch_compile, torch_compile_backend, torch_compile_mode, dispatch_batches, split_batches, include_tokens_per_second, include_num_input_tokens_seen, neftune_noise_alpha, optim_target_modules, batch_eval_metrics, eval_on_start, use_liger_kernel, eval_use_gather_object)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\transformers\training_args.py:1750, in TrainingArguments.__post_init__(self)
#    1748 # Initialize device before we proceed
#    1749 if self.framework == "pt" and is_torch_available():
# -> 1750     self.device
#    1752 if self.torchdynamo is not None:
#    1753     warnings.warn(
#    1754         "`torchdynamo` is deprecated and will be removed in version 5 of 🤗 Transformers. Use"
#    1755         " `torch_compile_backend` instead",
#    1756         FutureWarning,
#    1757     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\transformers\training_args.py:2250, in TrainingArguments.device(self)
#    2246 """
#    2247 The device used by this process.
#    2248 """
#    2249 requires_backends(self, ["torch"])
# -> 2250 return self._setup_devices
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\transformers\utils\generic.py:60, in cached_property.__get__(self, obj, objtype)
#      58 cached = getattr(obj, attr, None)
#      59 if cached is None:
# ---> 60     cached = self.fget(obj)
#      61     setattr(obj, attr, cached)
#      62 return cached
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\transformers\training_args.py:2123, in TrainingArguments._setup_devices(self)
#    2121 if not is_sagemaker_mp_enabled():
#    2122     if not is_accelerate_available():
# -> 2123         raise ImportError(
#    2124             f"Using the `Trainer` with `PyTorch` requires `accelerate>={ACCELERATE_MIN_VERSION}`: "
#    2125             "Please run `pip install transformers[torch]` or `pip install 'accelerate>={ACCELERATE_MIN_VERSION}'`"
#    2126         )
#    2127 # We delay the init of `PartialState` to the end for clarity
#    2128 accelerator_state_kwargs = {"enabled": True, "use_configured_state": False}
#
# ImportError: Using the `Trainer` with `PyTorch` requires `accelerate>=0.26.0`: Please run `pip install transformers[torch]` or `pip install 'accelerate>={ACCELERATE_MIN_VERSION}'`

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, Trainer, TrainingArguments
import datasets

# 加载标注数据
data = datasets.load_dataset('text', data_files="../output/bio_data.txt")

# 标签映射
label_list = ["O", "B-INDICATOR", "I-INDICATOR", "B-VALUE", "B-UNIT", "I-UNIT"]

# 加载DeBERTa模型和分词器
model_name = "microsoft/deberta-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=len(label_list))

# 定义训练参数
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
)

# 初始化Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=data['train'],
    eval_dataset=data['validation'],
    tokenizer=tokenizer
)

# 开始微调
trainer.train()
# Out:
# Some weights of DebertaForTokenClassification were not initialized from the model checkpoint at microsoft/deberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 16
#      13 model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=len(label_list))
#      15 # 定义训练参数
# ---> 16 training_args = TrainingArguments(
#      17     output_dir="./results",
#      18     # evaluation_strategy="epoch",
#      19     # learning_rate=2e-5,
#      20     # per_device_train_batch_size=16,
#      21     # per_device_eval_batch_size=16,
#      22     # num_train_epochs=3,
#      23 )
#      25 # 初始化Trainer
#      26 trainer = Trainer(
#      27     model=model,
#      28     args=training_args,
#    (...)
#      31     tokenizer=tokenizer
#      32 )
#
# File <string>:132, in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, eval_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, torch_empty_cache_steps, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, lr_scheduler_kwargs, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, save_only_model, restore_callback_states_from_checkpoint, no_cuda, use_cpu, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, dataloader_prefetch_factor, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, fsdp, fsdp_min_num_params, fsdp_config, fsdp_transformer_layer_cls_to_wrap, accelerator_config, deepspeed, label_smoothing_factor, optim, optim_args, adafactor, group_by_length, length_column_name, report_to, ddp_find_unused_parameters, ddp_bucket_cap_mb, ddp_broadcast_buffers, dataloader_pin_memory, dataloader_persistent_workers, skip_memory_metrics, use_legacy_prediction_loop, push_to_hub, resume_from_checkpoint, hub_model_id, hub_strategy, hub_token, hub_private_repo, hub_always_push, gradient_checkpointing, gradient_checkpointing_kwargs, include_inputs_for_metrics, eval_do_concat_batches, fp16_backend, evaluation_strategy, push_to_hub_model_id, push_to_hub_organization, push_to_hub_token, mp_parameters, auto_find_batch_size, full_determinism, torchdynamo, ray_scope, ddp_timeout, torch_compile, torch_compile_backend, torch_compile_mode, dispatch_batches, split_batches, include_tokens_per_second, include_num_input_tokens_seen, neftune_noise_alpha, optim_target_modules, batch_eval_metrics, eval_on_start, use_liger_kernel, eval_use_gather_object)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\transformers\training_args.py:1750, in TrainingArguments.__post_init__(self)
#    1748 # Initialize device before we proceed
#    1749 if self.framework == "pt" and is_torch_available():
# -> 1750     self.device
#    1752 if self.torchdynamo is not None:
#    1753     warnings.warn(
#    1754         "`torchdynamo` is deprecated and will be removed in version 5 of 🤗 Transformers. Use"
#    1755         " `torch_compile_backend` instead",
#    1756         FutureWarning,
#    1757     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\transformers\training_args.py:2250, in TrainingArguments.device(self)
#    2246 """
#    2247 The device used by this process.
#    2248 """
#    2249 requires_backends(self, ["torch"])
# -> 2250 return self._setup_devices
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\transformers\utils\generic.py:60, in cached_property.__get__(self, obj, objtype)
#      58 cached = getattr(obj, attr, None)
#      59 if cached is None:
# ---> 60     cached = self.fget(obj)
#      61     setattr(obj, attr, cached)
#      62 return cached
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\transformers\training_args.py:2123, in TrainingArguments._setup_devices(self)
#    2121 if not is_sagemaker_mp_enabled():
#    2122     if not is_accelerate_available():
# -> 2123         raise ImportError(
#    2124             f"Using the `Trainer` with `PyTorch` requires `accelerate>={ACCELERATE_MIN_VERSION}`: "
#    2125             "Please run `pip install transformers[torch]` or `pip install 'accelerate>={ACCELERATE_MIN_VERSION}'`"
#    2126         )
#    2127 # We delay the init of `PartialState` to the end for clarity
#    2128 accelerator_state_kwargs = {"enabled": True, "use_configured_state": False}
#
# ImportError: Using the `Trainer` with `PyTorch` requires `accelerate>=0.26.0`: Please run `pip install transformers[torch]` or `pip install 'accelerate>={ACCELERATE_MIN_VERSION}'`

# %%
from datasets import load_dataset, ClassLabel, Sequence

# 加载BIO格式数据集
def load_bio_dataset(file_path):
    dataset = load_dataset("text", data_files=file_path)

    # 解析BIO数据格式并转换为NER任务的格式
    def tokenize_and_align_labels(example):
        tokens = []
        labels = []
        for line in example["text"].split("\n"):
            if line.strip():
                word, label = line.split()
                tokens.append(word)
                labels.append(label)
        return {"tokens": tokens, "ner_tags": labels}

    # 应用解析函数并转换数据集
    dataset = dataset.map(tokenize_and_align_labels, remove_columns=["text"])

    # 将标签转换为整数类型
    label_list = sorted(set(sum(dataset["train"]["ner_tags"], [])))  # 获取所有的标签
    label_to_id = {label: i for i, label in enumerate(label_list)}
    
    def label_to_int(example):
        example["ner_tags"] = [label_to_id[label] for label in example["ner_tags"]]
        return example

    dataset = dataset.map(label_to_int)
    
    # 设置标签格式
    features = dataset["train"].features.copy()
    features["ner_tags"] = Sequence(feature=ClassLabel(names=label_list))
    dataset = dataset.cast(features)

    return dataset, label_list

# 加载并处理数据集
file_path = "bio_data.txt"
dataset, label_list = load_bio_dataset(file_path)

# %%
import json
import torch
from transformers import DebertaTokenizer, DebertaForTokenClassification, Trainer, TrainingArguments
from torch.utils.data import Dataset

# 1. Load and parse the JSON, BIO, and raw text files
def load_json_data(filepath):
    with open(filepath, 'r') as file:
        data = json.load(file)
    return data

def load_bio_data(filepath):
    texts, labels = [], []
    with open(filepath, 'r') as file:
        text, label = [], []
        for line in file:
            if line.strip() == "":
                if text:
                    texts.append(" ".join(text))
                    labels.append(label)
                    text, label = [], []
                continue
            
            # 将BIO标签正确映射为数字
            word, tag = line.strip().split()
            text.append(word)
            
            # 转换标签
            if tag == 'O':
                label.append(0)
            elif 'B' in tag:
                label.append(1)  # 假设B-*标签映射为1
            elif 'I' in tag:
                label.append(2)  # 假设I-*标签映射为2
            
        if text:  # 处理文件最后一行
            texts.append(" ".join(text))
            labels.append(label)
    return texts, labels


def load_raw_text(filepath):
    with open(filepath, 'r') as file:
        return [line.strip() for line in file if line.strip()]

# %%
# File paths
json_filepath = '../json/grouped_data_full1.json'
bio_filepath = '../output/bio_data.txt'
raw_text_filepath = '../output/1030_split.txt'

# Load data
json_data = load_json_data(json_filepath)
bio_texts, bio_labels = load_bio_data(bio_filepath)
raw_texts = load_raw_text(raw_text_filepath)

# %%
# 2. Initialize tokenizer and model
tokenizer = DebertaTokenizer.from_pretrained("microsoft/deberta-base")
model = DebertaForTokenClassification.from_pretrained("microsoft/deberta-base", num_labels=3)

# 3. Custom Dataset Class for labeled and unlabeled data
class ESGDataset(Dataset):
    def __init__(self, texts, labels=None):
        self.texts = texts
        self.labels = labels

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = tokenizer(self.texts[idx], truncation=True, padding="max_length", max_length=128, return_tensors="pt")
        item = {key: val.squeeze() for key, val in encoding.items()}
        if self.labels:
            labels = self.labels[idx] + [2] * (128 - len(self.labels[idx]))  # Pad labels to max length
            item["labels"] = torch.tensor(labels)
        return item

# Prepare datasets
train_dataset = ESGDataset(bio_texts, bio_labels)  # BIO labeled data for supervised training
unlabeled_dataset = ESGDataset(raw_texts)  # Unlabeled data for unsupervised pretraining

# 4. Training parameters
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="no",#"epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
)

# 5. Trainer for supervised training with labeled data
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
)

# 6. Fine-tuning
trainer.train()
# Out:
# C:\Users\ariaH\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading file vocab.json from cache at C:\Users\ariaH/.cache\huggingface\hub\models--microsoft--deberta-base\snapshots\0d1b43ccf21b5acd9f4e5f7b077fa698f05cf195\vocab.json
# loading file merges.txt from cache at C:\Users\ariaH/.cache\huggingface\hub\models--microsoft--deberta-base\snapshots\0d1b43ccf21b5acd9f4e5f7b077fa698f05cf195\merges.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at C:\Users\ariaH/.cache\huggingface\hub\models--microsoft--deberta-base\snapshots\0d1b43ccf21b5acd9f4e5f7b077fa698f05cf195\tokenizer_config.json
# loading configuration file config.json from cache at C:\Users\ariaH/.cache\huggingface\hub\models--microsoft--deberta-base\snapshots\0d1b43ccf21b5acd9f4e5f7b077fa698f05cf195\config.json
# Model config DebertaConfig {
#   "_name_or_path": "microsoft/deberta-base",
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": [
#     "c2p",
#     "p2c"
#   ],
#   "position_biased_input": false,
#   "relative_attention": true,
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 0,
#   "vocab_size": 50265
# }
#
# loading configuration file config.json from cache at C:\Users\ariaH/.cache\huggingface\hub\models--microsoft--deberta-base\snapshots\0d1b43ccf21b5acd9f4e5f7b077fa698f05cf195\config.json
# Model config DebertaConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": [
#     "c2p",
#     "p2c"
#   ],
#   "position_biased_input": false,
#   "relative_attention": true,
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 0,
#   "vocab_size": 50265
# }
#
# loading weights file pytorch_model.bin from cache at C:\Users\ariaH/.cache\huggingface\hub\models--microsoft--deberta-base\snapshots\0d1b43ccf21b5acd9f4e5f7b077fa698f05cf195\pytorch_model.bin
# Some weights of the model checkpoint at microsoft/deberta-base were not used when initializing DebertaForTokenClassification: ['lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.weight', 'deberta.embeddings.position_embeddings.weight', 'lm_predictions.lm_head.LayerNorm.weight']
# - This IS expected if you are initializing DebertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DebertaForTokenClassification were not initialized from the model checkpoint at microsoft/deberta-base and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# C:\Users\ariaH\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 18
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 9
#   Number of trainable parameters = 138604035
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
print(bio_texts[:2])
print(bio_labels[:2])
# Out:
# ['Net profit 1.9 S$ million', 'Total greenhouse gas ( GHG ) emissions 346 tonnes CO2e']
# [[1, 2, 1, 1, 2], [1, 2, 2, 2, 2, 2, 2, 1, 1, 2]]

# %%
# 训练完成后保存模型和分词器
trainer.save_model("../model/fine_tuned_deberta")
tokenizer.save_pretrained("../model/fine_tuned_deberta")
# Out:
# Saving model checkpoint to ../model/fine_tuned_deberta
# Configuration saved in ../model/fine_tuned_deberta\config.json
# Model weights saved in ../model/fine_tuned_deberta\pytorch_model.bin
# tokenizer config file saved in ../model/fine_tuned_deberta\tokenizer_config.json
# Special tokens file saved in ../model/fine_tuned_deberta\special_tokens_map.json
# ('../model/fine_tuned_deberta\\tokenizer_config.json',
#  '../model/fine_tuned_deberta\\special_tokens_map.json',
#  '../model/fine_tuned_deberta\\vocab.json',
#  '../model/fine_tuned_deberta\\merges.txt',
#  '../model/fine_tuned_deberta\\added_tokens.json')

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification
import re

# 加载保存的微调模型和分词器
model_path = "../model/fine_tuned_deberta"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForTokenClassification.from_pretrained(model_path)

# 初始化NER pipeline
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# 读取新的TXT文件
def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        text = f.read()
    return text

# 分段处理长文本
def split_text_by_sentences(text, max_len=512):
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s', text)
    chunks = []
    current_chunk = ""
    
    for sentence in sentences:
        if len(current_chunk) + len(sentence) < max_len:
            current_chunk += " " + sentence
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence
    if current_chunk:
        chunks.append(current_chunk.strip())
    
    return chunks


# 修改提取代码，将通用标签转换为实际标签
def extract_structured_data(text_chunks):
    structured_data = []
    for chunk in tqdm(text_chunks, desc="Processing Text Chunks"):
        entities = ner_pipeline(chunk)
        current_data = {}
        for entity in entities:
            label = label_mapping.get(entity["entity_group"], "O")  # 映射标签
            word = entity["word"]
            # 根据映射后的标签分类存储
            if label == "INDICATOR":
                current_data["indicator"] = word
            elif label == "VALUE":
                current_data["value"] = word
            elif label == "UNIT":
                current_data["unit"] = word
            
            # 保存完整的结构化数据项
            if "indicator" in current_data and "value" in current_data and "unit" in current_data:
                structured_data.append(current_data)
                current_data = {}
    return structured_data


# 使用示例
# 定义标签映射
label_mapping = {
    "LABEL_0": "INDICATOR",
    "LABEL_1": "VALUE",
    "LABEL_2": "UNIT"
}
file_path = raw_text_filepath  # 新的报告TXT文件
text = read_text_file(file_path)
text_chunks = split_text_by_sentences(text)  # 分段处理文本，避免超长输入

# 提取结构化数据
structured_data = extract_structured_data(text_chunks)

# 输出结果
for item in structured_data:
    print(item)
# Out:
# loading file vocab.json
# loading file merges.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
# loading configuration file ../model/fine_tuned_deberta\config.json
# Model config DebertaConfig {
#   "_name_or_path": "../model/fine_tuned_deberta",
#   "architectures": [
#     "DebertaForTokenClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": [
#     "c2p",
#     "p2c"
#   ],
#   "position_biased_input": false,
#   "relative_attention": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 0,
#   "vocab_size": 50265
# }
#
# loading weights file ../model/fine_tuned_deberta\pytorch_model.bin
# All model checkpoint weights were used when initializing DebertaForTokenClassification.
#
# All the weights of DebertaForTokenClassification were initialized from the model checkpoint at ../model/fine_tuned_deberta.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DebertaForTokenClassification for predictions without further training.

# %%
for chunk in text_chunks:
    entities = ner_pipeline(chunk)
    print(entities)  # 查看模型返回的实体标签
# Out:
# [{'entity_group': 'LABEL_2', 'score': 0.47819662, 'word': '1 \n ', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_0', 'score': 0.43586332, 'word': '\n', 'start': 4, 'end': 5}, {'entity_group': 'LABEL_2', 'score': 0.50138974, 'word': 'ASIAMEDIC LIMITED \n(Incorporated', 'start': 5, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.47888404, 'word': ' in', 'start': 37, 'end': 40}, {'entity_group': 'LABEL_2', 'score': 0.49527386, 'word': ' the Republic of Singapore) \nCompany Registration No.: 197401556E \n \n \n', 'start': 40, 'end': 111}, {'entity_group': 'LABEL_0', 'score': 0.41129524, 'word': 'S', 'start': 111, 'end': 112}, {'entity_group': 'LABEL_2', 'score': 0.5227687, 'word': 'USTAINABILITY REPORT \nfor', 'start': 112, 'end': 137}, {'entity_group': 'LABEL_0', 'score': 0.46330255, 'word': ' the', 'start': 137, 'end': 141}, {'entity_group': 'LABEL_2', 'score': 0.492158, 'word': ' financial year ("FY )', 'start': 141, 'end': 163}, {'entity_group': 'LABEL_0', 'score': 0.36549348, 'word': ' ended', 'start': 163, 'end': 169}, {'entity_group': 'LABEL_2', 'score': 0.5446043, 'word': ' 31 December 2023 ( FY2023 ) \n \n \n1.', 'start': 169, 'end': 205}]
# [{'entity_group': 'LABEL_2', 'score': 0.53914416, 'word': 'Board Statement', 'start': 0, 'end': 15}, {'entity_group': 'LABEL_0', 'score': 0.42983454, 'word': '  ', 'start': 15, 'end': 17}, {'entity_group': 'LABEL_2', 'score': 0.5100498, 'word': '\n \nThe Board of Directors', 'start': 17, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.5293505, 'word': ' (', 'start': 42, 'end': 44}, {'entity_group': 'LABEL_2', 'score': 0.7321074, 'word': ' Board', 'start': 44, 'end': 50}, {'entity_group': 'LABEL_0', 'score': 0.52902395, 'word': ' ) of', 'start': 50, 'end': 55}, {'entity_group': 'LABEL_2', 'score': 0.5021411, 'word': ' AsiaMedic', 'start': 55, 'end': 65}, {'entity_group': 'LABEL_0', 'score': 0.51559746, 'word': ' Limited (', 'start': 65, 'end': 75}, {'entity_group': 'LABEL_2', 'score': 0.6031268, 'word': ' Company', 'start': 75, 'end': 83}, {'entity_group': 'LABEL_0', 'score': 0.43366376, 'word': ' ', 'start': 83, 'end': 84}, {'entity_group': 'LABEL_2', 'score': 0.42855555, 'word': ' or', 'start': 84, 'end': 87}, {'entity_group': 'LABEL_0', 'score': 0.41357327, 'word': ' ', 'start': 87, 'end': 88}, {'entity_group': 'LABEL_2', 'score': 0.5288255, 'word': ' AsiaMedic', 'start': 88, 'end': 98}, {'entity_group': 'LABEL_0', 'score': 0.5522573, 'word': ' )', 'start': 98, 'end': 100}, {'entity_group': 'LABEL_2', 'score': 0.54998994, 'word': ' reaffirms our', 'start': 100, 'end': 114}, {'entity_group': 'LABEL_0', 'score': 0.49138308, 'word': ' \n', 'start': 114, 'end': 116}, {'entity_group': 'LABEL_2', 'score': 0.44797394, 'word': 'commitment', 'start': 116, 'end': 126}, {'entity_group': 'LABEL_0', 'score': 0.5210053, 'word': ' to', 'start': 126, 'end': 129}, {'entity_group': 'LABEL_2', 'score': 0.56127393, 'word': ' sustainability', 'start': 129, 'end': 144}, {'entity_group': 'LABEL_0', 'score': 0.49765778, 'word': ' with', 'start': 144, 'end': 149}, {'entity_group': 'LABEL_2', 'score': 0.48693845, 'word': ' the publication of', 'start': 149, 'end': 168}, {'entity_group': 'LABEL_0', 'score': 0.5901559, 'word': ' this', 'start': 168, 'end': 173}, {'entity_group': 'LABEL_2', 'score': 0.58594877, 'word': ' sustainability', 'start': 173, 'end': 188}, {'entity_group': 'LABEL_0', 'score': 0.54721326, 'word': ' report (', 'start': 188, 'end': 197}, {'entity_group': 'LABEL_2', 'score': 0.6916928, 'word': ' Report', 'start': 197, 'end': 204}, {'entity_group': 'LABEL_0', 'score': 0.65609026, 'word': ' ) on', 'start': 204, 'end': 209}, {'entity_group': 'LABEL_2', 'score': 0.51598775, 'word': ' insights', 'start': 209, 'end': 218}, {'entity_group': 'LABEL_0', 'score': 0.48409897, 'word': ' of ', 'start': 218, 'end': 222}, {'entity_group': 'LABEL_2', 'score': 0.47251603, 'word': '\nour', 'start': 222, 'end': 226}, {'entity_group': 'LABEL_0', 'score': 0.5565805, 'word': ' strategies and', 'start': 226, 'end': 241}, {'entity_group': 'LABEL_2', 'score': 0.56787026, 'word': ' initiatives', 'start': 241, 'end': 253}, {'entity_group': 'LABEL_0', 'score': 0.5904777, 'word': ' in our', 'start': 253, 'end': 260}, {'entity_group': 'LABEL_2', 'score': 0.58139664, 'word': ' sustainability', 'start': 260, 'end': 275}, {'entity_group': 'LABEL_0', 'score': 0.55933315, 'word': ' journey under the', 'start': 275, 'end': 293}, {'entity_group': 'LABEL_2', 'score': 0.46871734, 'word': ' sustainability pillars', 'start': 293, 'end': 316}, {'entity_group': 'LABEL_0', 'score': 0.5708469, 'word': ' of', 'start': 316, 'end': 319}, {'entity_group': 'LABEL_2', 'score': 0.51800317, 'word': ' economic, ', 'start': 319, 'end': 330}, {'entity_group': 'LABEL_0', 'score': 0.519134, 'word': '\n', 'start': 330, 'end': 331}, {'entity_group': 'LABEL_2', 'score': 0.6527634, 'word': 'environmental, social', 'start': 331, 'end': 352}, {'entity_group': 'LABEL_0', 'score': 0.49613482, 'word': ', and', 'start': 352, 'end': 357}, {'entity_group': 'LABEL_2', 'score': 0.56567115, 'word': ' governance', 'start': 357, 'end': 368}, {'entity_group': 'LABEL_0', 'score': 0.58794653, 'word': ' (', ...
# [{'entity_group': 'LABEL_2', 'score': 0.5149833, 'word': 'The Board', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.48042312, 'word': ' is committed to achieving a', 'start': 9, 'end': 37}, {'entity_group': 'LABEL_2', 'score': 0.42936873, 'word': ' balance', 'start': 37, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.66637325, 'word': ' between', 'start': 45, 'end': 53}, {'entity_group': 'LABEL_2', 'score': 0.515884, 'word': ' growth, profit, the environment', 'start': 53, 'end': 85}, {'entity_group': 'LABEL_0', 'score': 0.46376017, 'word': ',', 'start': 85, 'end': 86}, {'entity_group': 'LABEL_2', 'score': 0.5043242, 'word': ' the ', 'start': 86, 'end': 91}, {'entity_group': 'LABEL_0', 'score': 0.4765199, 'word': '\n', 'start': 91, 'end': 92}, {'entity_group': 'LABEL_2', 'score': 0.4910907, 'word': 'development', 'start': 92, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.5303253, 'word': ' of our', 'start': 103, 'end': 110}, {'entity_group': 'LABEL_2', 'score': 0.55521935, 'word': ' people', 'start': 110, 'end': 117}, {'entity_group': 'LABEL_0', 'score': 0.485717, 'word': ', governance, and', 'start': 117, 'end': 134}, {'entity_group': 'LABEL_2', 'score': 0.54234576, 'word': ' well-being', 'start': 134, 'end': 145}, {'entity_group': 'LABEL_0', 'score': 0.48590085, 'word': ' of our', 'start': 145, 'end': 152}, {'entity_group': 'LABEL_2', 'score': 0.47829098, 'word': ' communities to', 'start': 152, 'end': 167}, {'entity_group': 'LABEL_0', 'score': 0.5296709, 'word': ' secure', 'start': 167, 'end': 174}, {'entity_group': 'LABEL_2', 'score': 0.46516445, 'word': ' long-term', 'start': 174, 'end': 184}, {'entity_group': 'LABEL_0', 'score': 0.4391269, 'word': ' and', 'start': 184, 'end': 188}, {'entity_group': 'LABEL_2', 'score': 0.52050173, 'word': ' \nsustainable growth', 'start': 188, 'end': 208}, {'entity_group': 'LABEL_0', 'score': 0.5026772, 'word': ' for the', 'start': 208, 'end': 216}, {'entity_group': 'LABEL_2', 'score': 0.45014486, 'word': ' Company', 'start': 216, 'end': 224}, {'entity_group': 'LABEL_0', 'score': 0.5511158, 'word': ' and', 'start': 224, 'end': 228}, {'entity_group': 'LABEL_2', 'score': 0.51571256, 'word': ' its subsidiaries', 'start': 228, 'end': 245}, {'entity_group': 'LABEL_0', 'score': 0.6275988, 'word': ' (', 'start': 245, 'end': 247}, {'entity_group': 'LABEL_1', 'score': 0.38889396, 'word': 'collectively', 'start': 247, 'end': 259}, {'entity_group': 'LABEL_2', 'score': 0.46480292, 'word': ' referred to', 'start': 259, 'end': 271}, {'entity_group': 'LABEL_0', 'score': 0.49166182, 'word': ' as', 'start': 271, 'end': 274}, {'entity_group': 'LABEL_2', 'score': 0.43718374, 'word': ' the', 'start': 274, 'end': 278}, {'entity_group': 'LABEL_0', 'score': 0.48392937, 'word': ' ', 'start': 278, 'end': 279}, {'entity_group': 'LABEL_2', 'score': 0.44290727, 'word': ' Group', 'start': 279, 'end': 285}, {'entity_group': 'LABEL_0', 'score': 0.43989205, 'word': '  or ', 'start': 285, 'end': 290}, {'entity_group': 'LABEL_2', 'score': 0.44389892, 'word': ' We', 'start': 290, 'end': 293}, {'entity_group': 'LABEL_0', 'score': 0.4552583, 'word': ' ).', 'start': 293, 'end': 296}]
# [{'entity_group': 'LABEL_2', 'score': 0.58419394, 'word': 'In line with', 'start': 0, 'end': 12}, {'entity_group': 'LABEL_0', 'score': 0.6333503, 'word': ' our', 'start': 12, 'end': 16}, {'entity_group': 'LABEL_2', 'score': 0.5412283, 'word': ' commitment', 'start': 16, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.431755, 'word': ',', 'start': 27, 'end': 28}, {'entity_group': 'LABEL_2', 'score': 0.5655449, 'word': ' the Board', 'start': 28, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.73643017, 'word': ' considered', 'start': 38, 'end': 49}, {'entity_group': 'LABEL_2', 'score': 0.45004478, 'word': ' sustainability', 'start': 49, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.5167002, 'word': ' issues as part of its', 'start': 64, 'end': 86}, {'entity_group': 'LABEL_2', 'score': 0.5538818, 'word': ' strategic', 'start': 86, 'end': 96}, {'entity_group': 'LABEL_0', 'score': 0.47434986, 'word': ' \n', 'start': 96, 'end': 98}, {'entity_group': 'LABEL_2', 'score': 0.642001, 'word': 'formulation', 'start': 98, 'end': 109}, {'entity_group': 'LABEL_0', 'score': 0.48834443, 'word': ', determine the key', 'start': 109, 'end': 128}, {'entity_group': 'LABEL_2', 'score': 0.5002291, 'word': ' Sustainability Factors', 'start': 128, 'end': 151}, {'entity_group': 'LABEL_0', 'score': 0.54854816, 'word': ' and overseen the management and', 'start': 151, 'end': 183}, {'entity_group': 'LABEL_2', 'score': 0.5335851, 'word': ' monitoring', 'start': 183, 'end': 194}, {'entity_group': 'LABEL_0', 'score': 0.5718115, 'word': ' of', 'start': 194, 'end': 197}, {'entity_group': 'LABEL_2', 'score': 0.4662823, 'word': ' ', 'start': 197, 'end': 198}, {'entity_group': 'LABEL_0', 'score': 0.4566189, 'word': '\n', 'start': 198, 'end': 199}, {'entity_group': 'LABEL_2', 'score': 0.49868003, 'word': 'the', 'start': 199, 'end': 202}, {'entity_group': 'LABEL_0', 'score': 0.4695259, 'word': ' key', 'start': 202, 'end': 206}, {'entity_group': 'LABEL_2', 'score': 0.5462394, 'word': ' Sustainability Factors.', 'start': 206, 'end': 230}, {'entity_group': 'LABEL_0', 'score': 0.44131282, 'word': ' ', 'start': 230, 'end': 231}, {'entity_group': 'LABEL_2', 'score': 0.55440706, 'word': '\n \n', 'start': 231, 'end': 234}, {'entity_group': 'LABEL_0', 'score': 0.5446207, 'word': 'The', 'start': 234, 'end': 237}, {'entity_group': 'LABEL_2', 'score': 0.52226365, 'word': ' needs', 'start': 237, 'end': 243}, {'entity_group': 'LABEL_0', 'score': 0.55801696, 'word': ' of our key', 'start': 243, 'end': 254}, {'entity_group': 'LABEL_2', 'score': 0.6060575, 'word': ' stakeholders', 'start': 254, 'end': 267}, {'entity_group': 'LABEL_0', 'score': 0.46201184, 'word': ', comprising', 'start': 267, 'end': 279}, {'entity_group': 'LABEL_2', 'score': 0.5100235, 'word': ' communities', 'start': 279, 'end': 291}, {'entity_group': 'LABEL_0', 'score': 0.48724043, 'word': ',', 'start': 291, 'end': 292}, {'entity_group': 'LABEL_2', 'score': 0.5266002, 'word': ' customers', 'start': 292, 'end': 302}, {'entity_group': 'LABEL_0', 'score': 0.46606734, 'word': ',', 'start': 302, 'end': 303}, {'entity_group': 'LABEL_2', 'score': 0.50441325, 'word': ' employees', 'start': 303, 'end': 313}, {'entity_group': 'LABEL_0', 'score': 0.46310863, 'word': ',', 'start': 313, 'end': 314}, {'entity_group': 'LABEL_2', 'score': 0.5110033, 'word': ' regulators, ', 'start': 314, 'end': 327}, {'entity_group': 'LABEL_0', 'score': 0.4970455, 'word': '\n', 'start': 327, 'end': 328}, {'entity_group': 'LABEL_2', 'score': 0.65900624, 'word': 'shareholders', 'start': 328, 'end': 340}, {'entity_group': 'LABEL_0', 'score': 0.4479386, 'word': ' and', 'start': 340, 'end': 344}, {'entity_group': 'LABEL_2', 'score': 0.5321893, 'word': ' suppliers', 'start': 344, 'end': 354}, {'entity_group': 'LABEL_0', 'score': 0.5723056, 'word': ', are an integral consideration in our', 'start': 354, 'end': 392}, {'entity_group': 'LABEL_2', 'score': 0.4551654, 'word': ' sustainability', 'start': 392, 'end': 407}, {'entity_group': 'LABEL_0', ...
# [{'entity_group': 'LABEL_2', 'score': 0.5139174, 'word': 'To', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_0', 'score': 0.43605903, 'word': ' fulfil', 'start': 2, 'end': 9}, {'entity_group': 'LABEL_2', 'score': 0.45733002, 'word': ' our', 'start': 9, 'end': 13}, {'entity_group': 'LABEL_0', 'score': 0.5217534, 'word': ' \nkey stakeholders ', 'start': 13, 'end': 32}, {'entity_group': 'LABEL_2', 'score': 0.6210881, 'word': ' needs', 'start': 32, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.52622736, 'word': ', we work closely with them, and', 'start': 38, 'end': 70}, {'entity_group': 'LABEL_2', 'score': 0.46434516, 'word': ' their input', 'start': 70, 'end': 82}, {'entity_group': 'LABEL_0', 'score': 0.52515125, 'word': ' drives our', 'start': 82, 'end': 93}, {'entity_group': 'LABEL_2', 'score': 0.4389672, 'word': ' focus', 'start': 93, 'end': 99}, {'entity_group': 'LABEL_0', 'score': 0.5306862, 'word': ' on our', 'start': 99, 'end': 106}, {'entity_group': 'LABEL_2', 'score': 0.50175077, 'word': ' key', 'start': 106, 'end': 110}, {'entity_group': 'LABEL_0', 'score': 0.5361002, 'word': ' \nS', 'start': 110, 'end': 113}, {'entity_group': 'LABEL_2', 'score': 0.5027619, 'word': 'ustainability', 'start': 113, 'end': 126}, {'entity_group': 'LABEL_0', 'score': 0.5264677, 'word': ' Factors', 'start': 126, 'end': 134}, {'entity_group': 'LABEL_2', 'score': 0.43236753, 'word': '. We', 'start': 134, 'end': 138}, {'entity_group': 'LABEL_0', 'score': 0.5114672, 'word': ' will continue', 'start': 138, 'end': 152}, {'entity_group': 'LABEL_2', 'score': 0.5052242, 'word': ' to monitor', 'start': 152, 'end': 163}, {'entity_group': 'LABEL_0', 'score': 0.48226127, 'word': ', review and update our key S', 'start': 163, 'end': 192}, {'entity_group': 'LABEL_2', 'score': 0.52174026, 'word': 'ustainability', 'start': 192, 'end': 205}, {'entity_group': 'LABEL_0', 'score': 0.49829304, 'word': ' Factors \n', 'start': 205, 'end': 215}, {'entity_group': 'LABEL_2', 'score': 0.4929552, 'word': 'regularly', 'start': 215, 'end': 224}, {'entity_group': 'LABEL_0', 'score': 0.5453817, 'word': ', taking into account the', 'start': 224, 'end': 249}, {'entity_group': 'LABEL_2', 'score': 0.5714899, 'word': ' feedback', 'start': 249, 'end': 258}, {'entity_group': 'LABEL_0', 'score': 0.48155245, 'word': ' that', 'start': 258, 'end': 263}, {'entity_group': 'LABEL_2', 'score': 0.483113, 'word': ' we receive', 'start': 263, 'end': 274}, {'entity_group': 'LABEL_0', 'score': 0.4727132, 'word': ' from our', 'start': 274, 'end': 283}, {'entity_group': 'LABEL_2', 'score': 0.52915645, 'word': ' stakeholders', 'start': 283, 'end': 296}, {'entity_group': 'LABEL_0', 'score': 0.5617618, 'word': ',', 'start': 296, 'end': 297}, {'entity_group': 'LABEL_2', 'score': 0.50247777, 'word': ' organisational and ', 'start': 297, 'end': 317}, {'entity_group': 'LABEL_0', 'score': 0.4717507, 'word': '\n', 'start': 317, 'end': 318}, {'entity_group': 'LABEL_2', 'score': 0.47687566, 'word': 'external developments', 'start': 318, 'end': 339}, {'entity_group': 'LABEL_0', 'score': 0.44862252, 'word': '. ', 'start': 339, 'end': 341}, {'entity_group': 'LABEL_2', 'score': 0.5120754, 'word': ' \n \n2.', 'start': 341, 'end': 347}]
# [{'entity_group': 'LABEL_2', 'score': 0.43723163, 'word': 'Sustainability Performance at', 'start': 0, 'end': 29}, {'entity_group': 'LABEL_0', 'score': 0.4707779, 'word': ' a', 'start': 29, 'end': 31}, {'entity_group': 'LABEL_2', 'score': 0.51717705, 'word': ' Glance', 'start': 31, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.45695803, 'word': ' ', 'start': 38, 'end': 39}, {'entity_group': 'LABEL_2', 'score': 0.46241894, 'word': '\n \n', 'start': 39, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.4442992, 'word': 'A', 'start': 42, 'end': 43}, {'entity_group': 'LABEL_2', 'score': 0.5041319, 'word': ' summary', 'start': 43, 'end': 51}, {'entity_group': 'LABEL_0', 'score': 0.51453245, 'word': ' of our', 'start': 51, 'end': 58}, {'entity_group': 'LABEL_2', 'score': 0.53831834, 'word': ' key sustainability performance in FY2023', 'start': 58, 'end': 99}, {'entity_group': 'LABEL_0', 'score': 0.46449155, 'word': ' is as', 'start': 99, 'end': 105}, {'entity_group': 'LABEL_2', 'score': 0.4642188, 'word': ' follows: \nSustainability', 'start': 105, 'end': 130}, {'entity_group': 'LABEL_0', 'score': 0.4651987, 'word': ' \n', 'start': 130, 'end': 132}, {'entity_group': 'LABEL_2', 'score': 0.49921188, 'word': 'pillar \nPerformance indicator \nSustainability ', 'start': 132, 'end': 178}, {'entity_group': 'LABEL_0', 'score': 0.40044808, 'word': '\n', 'start': 178, 'end': 179}, {'entity_group': 'LABEL_2', 'score': 0.51521504, 'word': 'performance \nFY2023 \nFY2022 \nEconomic \nNet profit', 'start': 179, 'end': 228}, {'entity_group': 'LABEL_0', 'score': 0.55175704, 'word': ' (', 'start': 228, 'end': 230}, {'entity_group': 'LABEL_2', 'score': 0.5449266, 'word': 'S$ million', 'start': 230, 'end': 240}, {'entity_group': 'LABEL_0', 'score': 0.43118525, 'word': ')', 'start': 240, 'end': 241}, {'entity_group': 'LABEL_2', 'score': 0.5586999, 'word': ' \n1.9 \n2.2 \nEnvironmental \nTotal greenhouse gas ( GHG', 'start': 241, 'end': 294}, {'entity_group': 'LABEL_0', 'score': 0.44632226, 'word': ' )', 'start': 294, 'end': 296}, {'entity_group': 'LABEL_2', 'score': 0.58415824, 'word': ' emissions \n \n(tonnes CO2e) \n', 'start': 296, 'end': 325}, {'entity_group': 'LABEL_1', 'score': 0.40690288, 'word': '346', 'start': 325, 'end': 328}, {'entity_group': 'LABEL_2', 'score': 0.5586388, 'word': ' \n285 \nGHG emissions intensity', 'start': 328, 'end': 358}, {'entity_group': 'LABEL_0', 'score': 0.5338347, 'word': ' (', 'start': 358, 'end': 360}, {'entity_group': 'LABEL_2', 'score': 0.5713445, 'word': 'Scope 2) \n \n(tonnes CO2e / revenue S$ 000) \n0.018 \n0.021 \nSocial', 'start': 360, 'end': 424}, {'entity_group': 'LABEL_0', 'score': 0.42654976, 'word': ' ', 'start': 424, 'end': 425}, {'entity_group': 'LABEL_2', 'score': 0.4235254, 'word': '\nNumber', 'start': 425, 'end': 432}, {'entity_group': 'LABEL_0', 'score': 0.4428357, 'word': ' of', 'start': 432, 'end': 435}, {'entity_group': 'LABEL_2', 'score': 0.5414764, 'word': ' non', 'start': 435, 'end': 439}, {'entity_group': 'LABEL_0', 'score': 0.51195544, 'word': '-', 'start': 439, 'end': 440}, {'entity_group': 'LABEL_2', 'score': 0.49135995, 'word': 'compliance incidents', 'start': 440, 'end': 460}, {'entity_group': 'LABEL_0', 'score': 0.5714603, 'word': ' of', 'start': 460, 'end': 463}, {'entity_group': 'LABEL_2', 'score': 0.51145643, 'word': ' health and ', 'start': 463, 'end': 475}, {'entity_group': 'LABEL_0', 'score': 0.5262065, 'word': '\n', 'start': 475, 'end': 476}, {'entity_group': 'LABEL_2', 'score': 0.52348536, 'word': 'safety of products', 'start': 476, 'end': 494}, {'entity_group': 'LABEL_0', 'score': 0.4496348, 'word': ' and', 'start': 494, 'end': 498}, {'entity_group': 'LABEL_2', 'score': 0.54773134, 'word': ' services1 \n- \n- \nEmployee turnover rate (%)', 'start': 498, 'end': 542}, {'entity_group': 'LABEL_1', 'score': 0.41607484, 'word': '2', 'start': 542, 'end': 543}, {'entity_group': 'LABEL_2', 'score': 0.5347998, 'word': ' \n', 'start': 543, 'end': 545}, {'entity_group': 'LABEL_1',  ...
# [{'entity_group': 'LABEL_0', 'score': 0.46559957, 'word': '2', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_2', 'score': 0.53387034, 'word': ' Turn', 'start': 1, 'end': 6}, {'entity_group': 'LABEL_0', 'score': 0.40168107, 'word': 'over', 'start': 6, 'end': 10}, {'entity_group': 'LABEL_2', 'score': 0.41913208, 'word': ' is computed', 'start': 10, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.53927064, 'word': ' based', 'start': 22, 'end': 28}, {'entity_group': 'LABEL_2', 'score': 0.5232833, 'word': ' on confirmed full', 'start': 28, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.6051664, 'word': '-', 'start': 46, 'end': 47}, {'entity_group': 'LABEL_2', 'score': 0.51063037, 'word': 'time employees. \n3 Unlaw', 'start': 47, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.4687888, 'word': 'ful', 'start': 71, 'end': 74}, {'entity_group': 'LABEL_2', 'score': 0.42022336, 'word': ' discrimination refers', 'start': 74, 'end': 96}, {'entity_group': 'LABEL_0', 'score': 0.41867954, 'word': ' to', 'start': 96, 'end': 99}, {'entity_group': 'LABEL_2', 'score': 0.4475756, 'word': ' an', 'start': 99, 'end': 102}, {'entity_group': 'LABEL_0', 'score': 0.520543, 'word': ' incident whereby', 'start': 102, 'end': 119}, {'entity_group': 'LABEL_2', 'score': 0.5120864, 'word': ' the relevant authority has', 'start': 119, 'end': 146}, {'entity_group': 'LABEL_0', 'score': 0.5077248, 'word': ' commenced investigation and', 'start': 146, 'end': 174}, {'entity_group': 'LABEL_2', 'score': 0.48956853, 'word': ' ', 'start': 174, 'end': 175}, {'entity_group': 'LABEL_0', 'score': 0.48767948, 'word': '\n', 'start': 175, 'end': 176}, {'entity_group': 'LABEL_2', 'score': 0.46663365, 'word': 'result', 'start': 176, 'end': 182}, {'entity_group': 'LABEL_0', 'score': 0.5340163, 'word': 'ed in a penalty to', 'start': 182, 'end': 200}, {'entity_group': 'LABEL_2', 'score': 0.5168216, 'word': ' a', 'start': 200, 'end': 202}, {'entity_group': 'LABEL_0', 'score': 0.43880978, 'word': ' company', 'start': 202, 'end': 210}, {'entity_group': 'LABEL_2', 'score': 0.49604362, 'word': '. \n4 A substantiated', 'start': 210, 'end': 230}, {'entity_group': 'LABEL_0', 'score': 0.46577683, 'word': ' complaint', 'start': 230, 'end': 240}, {'entity_group': 'LABEL_2', 'score': 0.38770747, 'word': ' refers', 'start': 240, 'end': 247}, {'entity_group': 'LABEL_0', 'score': 0.3857117, 'word': ' to', 'start': 247, 'end': 250}, {'entity_group': 'LABEL_2', 'score': 0.53444624, 'word': ' a', 'start': 250, 'end': 252}, {'entity_group': 'LABEL_0', 'score': 0.48421583, 'word': ' complaint that', 'start': 252, 'end': 267}, {'entity_group': 'LABEL_2', 'score': 0.43715978, 'word': ' has been', 'start': 267, 'end': 276}, {'entity_group': 'LABEL_0', 'score': 0.54486644, 'word': ' investigated by the Personal', 'start': 276, 'end': 305}, {'entity_group': 'LABEL_2', 'score': 0.42268226, 'word': ' Data', 'start': 305, 'end': 310}, {'entity_group': 'LABEL_0', 'score': 0.5737801, 'word': ' Protection \nCommission and', 'start': 310, 'end': 337}, {'entity_group': 'LABEL_2', 'score': 0.4586789, 'word': ' violation', 'start': 337, 'end': 347}, {'entity_group': 'LABEL_0', 'score': 0.608223, 'word': ' of', 'start': 347, 'end': 350}, {'entity_group': 'LABEL_2', 'score': 0.4520209, 'word': ' regulations has been', 'start': 350, 'end': 371}, {'entity_group': 'LABEL_0', 'score': 0.43592146, 'word': ' established.', 'start': 371, 'end': 384}]
# [{'entity_group': 'LABEL_2', 'score': 0.49468705, 'word': '2 \n \nSustainability', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.47087246, 'word': ' \n', 'start': 19, 'end': 21}, {'entity_group': 'LABEL_2', 'score': 0.52589273, 'word': 'pillar \nPerformance indicator \nSustainability ', 'start': 21, 'end': 67}, {'entity_group': 'LABEL_0', 'score': 0.41144374, 'word': '\n', 'start': 67, 'end': 68}, {'entity_group': 'LABEL_2', 'score': 0.53386116, 'word': 'performance \nFY2023 \nFY2022 \nGovernance \nNumber', 'start': 68, 'end': 115}, {'entity_group': 'LABEL_0', 'score': 0.43775997, 'word': ' of', 'start': 115, 'end': 118}, {'entity_group': 'LABEL_2', 'score': 0.4440845, 'word': ' incidents', 'start': 118, 'end': 128}, {'entity_group': 'LABEL_0', 'score': 0.45714456, 'word': ' of', 'start': 128, 'end': 131}, {'entity_group': 'LABEL_2', 'score': 0.51150197, 'word': ' serious offences5 \n- \n- \n \n3. Our Business', 'start': 131, 'end': 174}, {'entity_group': 'LABEL_0', 'score': 0.4307018, 'word': ' ', 'start': 174, 'end': 175}, {'entity_group': 'LABEL_2', 'score': 0.43954435, 'word': '\n \n', 'start': 175, 'end': 178}, {'entity_group': 'LABEL_0', 'score': 0.5348965, 'word': 'We are a', 'start': 178, 'end': 186}, {'entity_group': 'LABEL_2', 'score': 0.49571842, 'word': ' one-stop outpatient wellness', 'start': 186, 'end': 215}, {'entity_group': 'LABEL_0', 'score': 0.5177363, 'word': ',', 'start': 215, 'end': 216}, {'entity_group': 'LABEL_2', 'score': 0.55098706, 'word': ' medical diagnostic imaging', 'start': 216, 'end': 243}, {'entity_group': 'LABEL_0', 'score': 0.46388236, 'word': ',', 'start': 243, 'end': 244}, {'entity_group': 'LABEL_2', 'score': 0.5459473, 'word': ' family', 'start': 244, 'end': 251}, {'entity_group': 'LABEL_0', 'score': 0.48295808, 'word': ' clinic and', 'start': 251, 'end': 262}, {'entity_group': 'LABEL_2', 'score': 0.49664506, 'word': ' medical aesthetics ', 'start': 262, 'end': 282}, {'entity_group': 'LABEL_0', 'score': 0.48885733, 'word': '\n', 'start': 282, 'end': 283}, {'entity_group': 'LABEL_2', 'score': 0.5292523, 'word': 'service', 'start': 283, 'end': 290}, {'entity_group': 'LABEL_0', 'score': 0.5646781, 'word': ' provider in', 'start': 290, 'end': 302}, {'entity_group': 'LABEL_2', 'score': 0.42382815, 'word': ' Singapore.', 'start': 302, 'end': 313}]
# [{'entity_group': 'LABEL_0', 'score': 0.44521788, 'word': 'Detailed', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_2', 'score': 0.5385715, 'word': ' information', 'start': 8, 'end': 20}, {'entity_group': 'LABEL_0', 'score': 0.49874192, 'word': ' on', 'start': 20, 'end': 23}, {'entity_group': 'LABEL_2', 'score': 0.5158318, 'word': ' our businesses and performance', 'start': 23, 'end': 54}, {'entity_group': 'LABEL_0', 'score': 0.43015173, 'word': ' for', 'start': 54, 'end': 58}, {'entity_group': 'LABEL_2', 'score': 0.5510142, 'word': ' FY2023 can be', 'start': 58, 'end': 72}, {'entity_group': 'LABEL_0', 'score': 0.47577944, 'word': ' found in', 'start': 72, 'end': 81}, {'entity_group': 'LABEL_2', 'score': 0.50963014, 'word': ' our Annual Report \nfor FY2023 issued', 'start': 81, 'end': 118}, {'entity_group': 'LABEL_0', 'score': 0.3836311, 'word': ' on', 'start': 118, 'end': 121}, {'entity_group': 'LABEL_2', 'score': 0.62543434, 'word': ' 12 April 2024', 'start': 121, 'end': 135}, {'entity_group': 'LABEL_0', 'score': 0.45241392, 'word': ' (', 'start': 135, 'end': 137}, {'entity_group': 'LABEL_2', 'score': 0.5252727, 'word': 'the  Annual Report  or  AR', 'start': 137, 'end': 163}, {'entity_group': 'LABEL_0', 'score': 0.5233746, 'word': ' ),', 'start': 163, 'end': 166}, {'entity_group': 'LABEL_2', 'score': 0.5519179, 'word': ' a copy of which has been \ndisseminated', 'start': 166, 'end': 205}, {'entity_group': 'LABEL_0', 'score': 0.44377568, 'word': ' on the', 'start': 205, 'end': 212}, {'entity_group': 'LABEL_2', 'score': 0.6082363, 'word': ' SGXNet.', 'start': 212, 'end': 220}, {'entity_group': 'LABEL_0', 'score': 0.4521468, 'word': ' ', 'start': 220, 'end': 221}, {'entity_group': 'LABEL_2', 'score': 0.52008754, 'word': '\n \n4. Reporting Period', 'start': 221, 'end': 243}, {'entity_group': 'LABEL_0', 'score': 0.4264357, 'word': ' and', 'start': 243, 'end': 247}, {'entity_group': 'LABEL_2', 'score': 0.50103104, 'word': ' Scope \n \n', 'start': 247, 'end': 257}, {'entity_group': 'LABEL_0', 'score': 0.50374466, 'word': 'This', 'start': 257, 'end': 261}, {'entity_group': 'LABEL_2', 'score': 0.4488218, 'word': ' Report', 'start': 261, 'end': 268}, {'entity_group': 'LABEL_0', 'score': 0.49234736, 'word': ' provides an', 'start': 268, 'end': 280}, {'entity_group': 'LABEL_2', 'score': 0.5274092, 'word': ' overview', 'start': 280, 'end': 289}, {'entity_group': 'LABEL_0', 'score': 0.4883721, 'word': ' of our', 'start': 289, 'end': 296}, {'entity_group': 'LABEL_2', 'score': 0.4871721, 'word': ' sustainability performance', 'start': 296, 'end': 323}, {'entity_group': 'LABEL_0', 'score': 0.50905246, 'word': ' for', 'start': 323, 'end': 327}, {'entity_group': 'LABEL_2', 'score': 0.5276642, 'word': ' FY2023', 'start': 327, 'end': 334}, {'entity_group': 'LABEL_0', 'score': 0.500302, 'word': ' (', 'start': 334, 'end': 336}, {'entity_group': 'LABEL_2', 'score': 0.46641138, 'word': 'the  Reporting', 'start': 336, 'end': 350}, {'entity_group': 'LABEL_0', 'score': 0.45239067, 'word': ' ', 'start': 350, 'end': 351}, {'entity_group': 'LABEL_2', 'score': 0.50845516, 'word': '\nPeriod', 'start': 351, 'end': 358}, {'entity_group': 'LABEL_0', 'score': 0.61588913, 'word': ' ).', 'start': 358, 'end': 361}]
# [{'entity_group': 'LABEL_2', 'score': 0.48749846, 'word': 'It covers', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.52204335, 'word': ':', 'start': 9, 'end': 10}, {'entity_group': 'LABEL_2', 'score': 0.4815725, 'word': ' (i) wellness', 'start': 10, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.46652263, 'word': ' assessment', 'start': 23, 'end': 34}, {'entity_group': 'LABEL_2', 'score': 0.48135743, 'word': ' centre', 'start': 34, 'end': 41}, {'entity_group': 'LABEL_0', 'score': 0.48913932, 'word': ';', 'start': 41, 'end': 42}, {'entity_group': 'LABEL_2', 'score': 0.57224226, 'word': ' (ii', 'start': 42, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.45381758, 'word': ')', 'start': 46, 'end': 47}, {'entity_group': 'LABEL_2', 'score': 0.47470614, 'word': ' diagnostic', 'start': 47, 'end': 58}, {'entity_group': 'LABEL_0', 'score': 0.46442187, 'word': ' imaging', 'start': 58, 'end': 66}, {'entity_group': 'LABEL_2', 'score': 0.4757081, 'word': ' centre', 'start': 66, 'end': 73}, {'entity_group': 'LABEL_0', 'score': 0.48385066, 'word': ';', 'start': 73, 'end': 74}, {'entity_group': 'LABEL_2', 'score': 0.56037015, 'word': ' (iii', 'start': 74, 'end': 79}, {'entity_group': 'LABEL_0', 'score': 0.44732878, 'word': ')', 'start': 79, 'end': 80}, {'entity_group': 'LABEL_2', 'score': 0.45787048, 'word': ' aesthetic clinic', 'start': 80, 'end': 97}, {'entity_group': 'LABEL_0', 'score': 0.46088666, 'word': ';', 'start': 97, 'end': 98}, {'entity_group': 'LABEL_2', 'score': 0.5416526, 'word': ' \nand (iv', 'start': 98, 'end': 107}, {'entity_group': 'LABEL_0', 'score': 0.5173187, 'word': ') international', 'start': 107, 'end': 122}, {'entity_group': 'LABEL_2', 'score': 0.4565164, 'word': ' clinic', 'start': 122, 'end': 129}, {'entity_group': 'LABEL_0', 'score': 0.4905652, 'word': ' business', 'start': 129, 'end': 138}, {'entity_group': 'LABEL_2', 'score': 0.43859553, 'word': ' units', 'start': 138, 'end': 144}, {'entity_group': 'LABEL_0', 'score': 0.46040514, 'word': ' of the', 'start': 144, 'end': 151}, {'entity_group': 'LABEL_2', 'score': 0.4624956, 'word': ' Group', 'start': 151, 'end': 157}, {'entity_group': 'LABEL_0', 'score': 0.52924025, 'word': ' which contributed', 'start': 157, 'end': 175}, {'entity_group': 'LABEL_2', 'score': 0.4979096, 'word': ' 100%', 'start': 175, 'end': 180}, {'entity_group': 'LABEL_0', 'score': 0.45697582, 'word': ' (', 'start': 180, 'end': 182}, {'entity_group': 'LABEL_2', 'score': 0.5653431, 'word': 'FY2022: 100%)', 'start': 182, 'end': 195}, {'entity_group': 'LABEL_0', 'score': 0.4805624, 'word': ' of the', 'start': 195, 'end': 202}, {'entity_group': 'LABEL_2', 'score': 0.4993165, 'word': ' \nGroup s', 'start': 202, 'end': 211}, {'entity_group': 'LABEL_0', 'score': 0.5174533, 'word': ' total revenue for the', 'start': 211, 'end': 233}, {'entity_group': 'LABEL_2', 'score': 0.4761761, 'word': ' Reporting', 'start': 233, 'end': 243}, {'entity_group': 'LABEL_0', 'score': 0.4620244, 'word': ' Period', 'start': 243, 'end': 250}, {'entity_group': 'LABEL_2', 'score': 0.5458316, 'word': '. \n \n5.', 'start': 250, 'end': 257}]
# [{'entity_group': 'LABEL_2', 'score': 0.4570731, 'word': 'Sustainability Reporting', 'start': 0, 'end': 24}, {'entity_group': 'LABEL_0', 'score': 0.45289364, 'word': ' Framework \n', 'start': 24, 'end': 36}, {'entity_group': 'LABEL_2', 'score': 0.42508382, 'word': ' \n', 'start': 36, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.497067, 'word': 'This', 'start': 38, 'end': 42}, {'entity_group': 'LABEL_2', 'score': 0.45174748, 'word': ' Report', 'start': 42, 'end': 49}, {'entity_group': 'LABEL_0', 'score': 0.47278804, 'word': ' is', 'start': 49, 'end': 52}, {'entity_group': 'LABEL_2', 'score': 0.47900525, 'word': ' prepared in accordance', 'start': 52, 'end': 75}, {'entity_group': 'LABEL_0', 'score': 0.47929698, 'word': ' with', 'start': 75, 'end': 80}, {'entity_group': 'LABEL_2', 'score': 0.508758, 'word': ' Rules 711A and 711B of', 'start': 80, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.43157488, 'word': ' the', 'start': 103, 'end': 107}, {'entity_group': 'LABEL_2', 'score': 0.48716804, 'word': ' Listing', 'start': 107, 'end': 115}, {'entity_group': 'LABEL_0', 'score': 0.39746216, 'word': ' Manual', 'start': 115, 'end': 122}, {'entity_group': 'LABEL_2', 'score': 0.5094548, 'word': ' Section B', 'start': 122, 'end': 132}, {'entity_group': 'LABEL_0', 'score': 0.4736603, 'word': ': \nRules of', 'start': 132, 'end': 143}, {'entity_group': 'LABEL_2', 'score': 0.5247158, 'word': ' Catalist', 'start': 143, 'end': 152}, {'entity_group': 'LABEL_0', 'score': 0.47045642, 'word': ' of the', 'start': 152, 'end': 159}, {'entity_group': 'LABEL_2', 'score': 0.47371906, 'word': ' Singapore Exchange Securities Trading', 'start': 159, 'end': 197}, {'entity_group': 'LABEL_0', 'score': 0.5452442, 'word': ' Limited (', 'start': 197, 'end': 207}, {'entity_group': 'LABEL_2', 'score': 0.6300317, 'word': ' SGX-ST', 'start': 207, 'end': 214}, {'entity_group': 'LABEL_0', 'score': 0.52364427, 'word': ' ) and', 'start': 214, 'end': 220}, {'entity_group': 'LABEL_2', 'score': 0.454039, 'word': ' with reference ', 'start': 220, 'end': 236}, {'entity_group': 'LABEL_0', 'score': 0.4949508, 'word': '\nto the', 'start': 236, 'end': 243}, {'entity_group': 'LABEL_2', 'score': 0.4794572, 'word': ' Global Reporting', 'start': 243, 'end': 260}, {'entity_group': 'LABEL_0', 'score': 0.45616195, 'word': ' Initiative (', 'start': 260, 'end': 273}, {'entity_group': 'LABEL_2', 'score': 0.5629614, 'word': ' GRI', 'start': 273, 'end': 277}, {'entity_group': 'LABEL_0', 'score': 0.6035102, 'word': ' )', 'start': 277, 'end': 279}, {'entity_group': 'LABEL_2', 'score': 0.37405562, 'word': ' Standards', 'start': 279, 'end': 289}, {'entity_group': 'LABEL_0', 'score': 0.6153707, 'word': ' for the', 'start': 289, 'end': 297}, {'entity_group': 'LABEL_2', 'score': 0.4707358, 'word': ' Reporting', 'start': 297, 'end': 307}, {'entity_group': 'LABEL_0', 'score': 0.47025317, 'word': ' Period.', 'start': 307, 'end': 315}, {'entity_group': 'LABEL_2', 'score': 0.43961552, 'word': ' We', 'start': 315, 'end': 318}, {'entity_group': 'LABEL_0', 'score': 0.44671386, 'word': ' choose to', 'start': 318, 'end': 328}, {'entity_group': 'LABEL_2', 'score': 0.4461337, 'word': ' report using ', 'start': 328, 'end': 342}, {'entity_group': 'LABEL_0', 'score': 0.4871155, 'word': '\nthe', 'start': 342, 'end': 346}, {'entity_group': 'LABEL_2', 'score': 0.6219582, 'word': ' G', 'start': 346, 'end': 348}, {'entity_group': 'LABEL_0', 'score': 0.47569802, 'word': 'RI framework as it is an', 'start': 348, 'end': 372}, {'entity_group': 'LABEL_2', 'score': 0.58492196, 'word': ' internationally', 'start': 372, 'end': 388}, {'entity_group': 'LABEL_0', 'score': 0.44344026, 'word': ' recognised', 'start': 388, 'end': 399}, {'entity_group': 'LABEL_2', 'score': 0.4616013, 'word': ' reporting', 'start': 399, 'end': 409}, {'entity_group': 'LABEL_0', 'score': 0.5239444, 'word': ' standard that covers a', 'start': 409, 'end': 432}, {'entity_group': 'LABEL_2', 'score': 0.4973868, 'word': ' comprehensive ', 'start': ...
# [{'entity_group': 'LABEL_0', 'score': 0.5367672, 'word': 'The', 'start': 0, 'end': 3}, {'entity_group': 'LABEL_2', 'score': 0.4886582, 'word': ' GRI content index can', 'start': 3, 'end': 25}, {'entity_group': 'LABEL_0', 'score': 0.46657586, 'word': ' be found in', 'start': 25, 'end': 37}, {'entity_group': 'LABEL_2', 'score': 0.4676106, 'word': ' Section 14 of', 'start': 37, 'end': 51}, {'entity_group': 'LABEL_0', 'score': 0.44535676, 'word': ' this', 'start': 51, 'end': 56}, {'entity_group': 'LABEL_2', 'score': 0.5327628, 'word': ' Report.', 'start': 56, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.4676236, 'word': ' ', 'start': 64, 'end': 65}, {'entity_group': 'LABEL_2', 'score': 0.48639637, 'word': '\n \nAs part', 'start': 65, 'end': 75}, {'entity_group': 'LABEL_0', 'score': 0.50737673, 'word': ' of our continual efforts', 'start': 75, 'end': 100}, {'entity_group': 'LABEL_2', 'score': 0.5057146, 'word': ' to align', 'start': 100, 'end': 109}, {'entity_group': 'LABEL_0', 'score': 0.49211374, 'word': ' our', 'start': 109, 'end': 113}, {'entity_group': 'LABEL_2', 'score': 0.45982042, 'word': ' sustainability reporting', 'start': 113, 'end': 138}, {'entity_group': 'LABEL_0', 'score': 0.49618283, 'word': ' with', 'start': 138, 'end': 143}, {'entity_group': 'LABEL_2', 'score': 0.5127469, 'word': ' relevant market standards', 'start': 143, 'end': 169}, {'entity_group': 'LABEL_0', 'score': 0.526117, 'word': ', we', 'start': 169, 'end': 173}, {'entity_group': 'LABEL_2', 'score': 0.45196858, 'word': ' ', 'start': 173, 'end': 174}, {'entity_group': 'LABEL_0', 'score': 0.66613835, 'word': '\n', 'start': 174, 'end': 175}, {'entity_group': 'LABEL_2', 'score': 0.5264342, 'word': 'm', 'start': 175, 'end': 176}, {'entity_group': 'LABEL_0', 'score': 0.55424595, 'word': 'apped our sustainability efforts to the', 'start': 176, 'end': 215}, {'entity_group': 'LABEL_2', 'score': 0.5103136, 'word': ' 2030 Agenda', 'start': 215, 'end': 227}, {'entity_group': 'LABEL_0', 'score': 0.6704085, 'word': ' for', 'start': 227, 'end': 231}, {'entity_group': 'LABEL_2', 'score': 0.58598876, 'word': ' Sustainable Development', 'start': 231, 'end': 255}, {'entity_group': 'LABEL_0', 'score': 0.49644747, 'word': ' which', 'start': 255, 'end': 261}, {'entity_group': 'LABEL_2', 'score': 0.4890523, 'word': ' is adopted by', 'start': 261, 'end': 275}, {'entity_group': 'LABEL_0', 'score': 0.48182645, 'word': ' \n', 'start': 275, 'end': 277}, {'entity_group': 'LABEL_2', 'score': 0.5163436, 'word': 'all United Nations Member States', 'start': 277, 'end': 309}, {'entity_group': 'LABEL_0', 'score': 0.48859197, 'word': ' in', 'start': 309, 'end': 312}, {'entity_group': 'LABEL_2', 'score': 0.66394466, 'word': ' 2015', 'start': 312, 'end': 317}, {'entity_group': 'LABEL_0', 'score': 0.47280467, 'word': ' ( UN S', 'start': 317, 'end': 324}, {'entity_group': 'LABEL_2', 'score': 0.46339905, 'word': 'ustainability Agenda', 'start': 324, 'end': 344}, {'entity_group': 'LABEL_0', 'score': 0.5453184, 'word': ' ). The', 'start': 344, 'end': 351}, {'entity_group': 'LABEL_2', 'score': 0.39940792, 'word': ' UN', 'start': 351, 'end': 354}, {'entity_group': 'LABEL_0', 'score': 0.45035994, 'word': ' S', 'start': 354, 'end': 356}, {'entity_group': 'LABEL_2', 'score': 0.5812604, 'word': 'ustainability', 'start': 356, 'end': 369}, {'entity_group': 'LABEL_0', 'score': 0.5200843, 'word': ' \n', 'start': 369, 'end': 371}, {'entity_group': 'LABEL_2', 'score': 0.5709112, 'word': 'Agenda', 'start': 371, 'end': 377}, {'entity_group': 'LABEL_0', 'score': 0.5548426, 'word': ' provides a', 'start': 377, 'end': 388}, {'entity_group': 'LABEL_2', 'score': 0.5437478, 'word': ' shared', 'start': 388, 'end': 395}, {'entity_group': 'LABEL_0', 'score': 0.5321251, 'word': ' blueprint for', 'start': 395, 'end': 409}, {'entity_group': 'LABEL_2', 'score': 0.5618028, 'word': ' peace', 'start': 409, 'end': 415}, {'entity_group': 'LABEL_0', 'score': 0.55536366, 'word': ' and', 'start': 415, 'end': 419}, {'entity_ ...
# [{'entity_group': 'LABEL_2', 'score': 0.45801654, 'word': 'The 17 Sustainable Development Goals', 'start': 0, 'end': 36}, {'entity_group': 'LABEL_0', 'score': 0.59426004, 'word': ' (', 'start': 36, 'end': 38}, {'entity_group': 'LABEL_2', 'score': 0.4657951, 'word': ' SDGs', 'start': 38, 'end': 43}, {'entity_group': 'LABEL_0', 'score': 0.5349168, 'word': ' ) form an urgent call for action by all \n', 'start': 43, 'end': 85}, {'entity_group': 'LABEL_2', 'score': 0.4586208, 'word': 'count', 'start': 85, 'end': 90}, {'entity_group': 'LABEL_0', 'score': 0.449161, 'word': 'ries -', 'start': 90, 'end': 96}, {'entity_group': 'LABEL_2', 'score': 0.5497308, 'word': ' developed and developing', 'start': 96, 'end': 121}, {'entity_group': 'LABEL_0', 'score': 0.5445883, 'word': ' - in a', 'start': 121, 'end': 128}, {'entity_group': 'LABEL_2', 'score': 0.46763444, 'word': ' global partnership', 'start': 128, 'end': 147}, {'entity_group': 'LABEL_0', 'score': 0.44998056, 'word': '.', 'start': 147, 'end': 148}, {'entity_group': 'LABEL_2', 'score': 0.43151, 'word': ' We', 'start': 148, 'end': 151}, {'entity_group': 'LABEL_0', 'score': 0.537586, 'word': ' incorporated the', 'start': 151, 'end': 168}, {'entity_group': 'LABEL_2', 'score': 0.47778434, 'word': ' SDGs', 'start': 168, 'end': 173}, {'entity_group': 'LABEL_0', 'score': 0.48247823, 'word': ',', 'start': 173, 'end': 174}, {'entity_group': 'LABEL_2', 'score': 0.5509616, 'word': ' where \nappropriate', 'start': 174, 'end': 193}, {'entity_group': 'LABEL_0', 'score': 0.5621701, 'word': ', as a supporting framework to shape and guide our', 'start': 193, 'end': 243}, {'entity_group': 'LABEL_2', 'score': 0.46276826, 'word': ' sustainability strategy', 'start': 243, 'end': 267}, {'entity_group': 'LABEL_0', 'score': 0.45774212, 'word': '.', 'start': 267, 'end': 268}, {'entity_group': 'LABEL_2', 'score': 0.38246632, 'word': ' ', 'start': 268, 'end': 269}, {'entity_group': 'LABEL_0', 'score': 0.393999, 'word': '\n', 'start': 269, 'end': 270}, {'entity_group': 'LABEL_2', 'score': 0.43201452, 'word': ' \n', 'start': 270, 'end': 272}, {'entity_group': 'LABEL_0', 'score': 0.47439033, 'word': 'Our', 'start': 272, 'end': 275}, {'entity_group': 'LABEL_2', 'score': 0.65497875, 'word': ' climate', 'start': 275, 'end': 283}, {'entity_group': 'LABEL_0', 'score': 0.45430663, 'word': '-related', 'start': 283, 'end': 291}, {'entity_group': 'LABEL_2', 'score': 0.40660927, 'word': ' disclosures', 'start': 291, 'end': 303}, {'entity_group': 'LABEL_0', 'score': 0.5133411, 'word': ' are prepared based on the 11', 'start': 303, 'end': 332}, {'entity_group': 'LABEL_2', 'score': 0.3919831, 'word': ' recommendations', 'start': 332, 'end': 348}, {'entity_group': 'LABEL_0', 'score': 0.46775982, 'word': ' of Task Force on \n', 'start': 348, 'end': 367}, {'entity_group': 'LABEL_2', 'score': 0.6083337, 'word': 'Climate', 'start': 367, 'end': 374}, {'entity_group': 'LABEL_0', 'score': 0.5282074, 'word': '-related', 'start': 374, 'end': 382}, {'entity_group': 'LABEL_2', 'score': 0.41658378, 'word': ' Financial Discl', 'start': 382, 'end': 398}, {'entity_group': 'LABEL_0', 'score': 0.5068214, 'word': 'osures (', 'start': 398, 'end': 406}, {'entity_group': 'LABEL_2', 'score': 0.5701711, 'word': ' TCFD', 'start': 406, 'end': 411}, {'entity_group': 'LABEL_0', 'score': 0.41227624, 'word': ' ). \n', 'start': 411, 'end': 416}, {'entity_group': 'LABEL_2', 'score': 0.46610352, 'word': ' ', 'start': 416, 'end': 417}, {'entity_group': 'LABEL_0', 'score': 0.5369898, 'word': '\nWe relied on internal', 'start': 417, 'end': 439}, {'entity_group': 'LABEL_2', 'score': 0.4928894, 'word': ' data monitoring and verification to ensure accuracy', 'start': 439, 'end': 491}, {'entity_group': 'LABEL_0', 'score': 0.54306865, 'word': ' for this', 'start': 491, 'end': 500}, {'entity_group': 'LABEL_2', 'score': 0.50510335, 'word': ' Report', 'start': 500, 'end': 507}, {'entity_group': 'LABEL_0', 'score': 0.34101662, 'word': '.', 'start': 507, 'end': 508}]
# [{'entity_group': 'LABEL_2', 'score': 0.5134132, 'word': 'Internal review', 'start': 0, 'end': 15}, {'entity_group': 'LABEL_0', 'score': 0.45125574, 'word': ' ', 'start': 15, 'end': 16}, {'entity_group': 'LABEL_2', 'score': 0.47817922, 'word': '\non', 'start': 16, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.48639786, 'word': ' the', 'start': 19, 'end': 23}, {'entity_group': 'LABEL_2', 'score': 0.46775037, 'word': ' sustainability reporting', 'start': 23, 'end': 48}, {'entity_group': 'LABEL_0', 'score': 0.49645147, 'word': ' process', 'start': 48, 'end': 56}, {'entity_group': 'LABEL_2', 'score': 0.49088764, 'word': ' has been', 'start': 56, 'end': 65}, {'entity_group': 'LABEL_0', 'score': 0.4662333, 'word': ' incorporated as', 'start': 65, 'end': 81}, {'entity_group': 'LABEL_2', 'score': 0.44029972, 'word': ' part', 'start': 81, 'end': 86}, {'entity_group': 'LABEL_0', 'score': 0.49270743, 'word': ' of our', 'start': 86, 'end': 93}, {'entity_group': 'LABEL_2', 'score': 0.5630713, 'word': ' internal audit review cycle ', 'start': 93, 'end': 122}, {'entity_group': 'LABEL_0', 'score': 0.4638353, 'word': '\n', 'start': 122, 'end': 123}, {'entity_group': 'LABEL_2', 'score': 0.44807473, 'word': 'and', 'start': 123, 'end': 126}, {'entity_group': 'LABEL_0', 'score': 0.5213709, 'word': ' we will work towards', 'start': 126, 'end': 147}, {'entity_group': 'LABEL_2', 'score': 0.5392439, 'word': ' external assurance', 'start': 147, 'end': 166}, {'entity_group': 'LABEL_0', 'score': 0.57506126, 'word': ' for', 'start': 166, 'end': 170}, {'entity_group': 'LABEL_2', 'score': 0.48248136, 'word': ' our future sustainability reports. \n \n6. Feedback \n \n', 'start': 170, 'end': 224}, {'entity_group': 'LABEL_0', 'score': 0.53607893, 'word': 'We welcome', 'start': 224, 'end': 234}, {'entity_group': 'LABEL_2', 'score': 0.49341697, 'word': ' feedback from all stakeholders', 'start': 234, 'end': 265}, {'entity_group': 'LABEL_0', 'score': 0.47171366, 'word': ' on this', 'start': 265, 'end': 273}, {'entity_group': 'LABEL_2', 'score': 0.5977021, 'word': ' Report', 'start': 273, 'end': 280}, {'entity_group': 'LABEL_0', 'score': 0.41759017, 'word': '.', 'start': 280, 'end': 281}, {'entity_group': 'LABEL_2', 'score': 0.5030352, 'word': ' You may', 'start': 281, 'end': 289}, {'entity_group': 'LABEL_0', 'score': 0.55364597, 'word': ' send', 'start': 289, 'end': 294}, {'entity_group': 'LABEL_2', 'score': 0.50856876, 'word': ' related questions, comments, ', 'start': 294, 'end': 324}, {'entity_group': 'LABEL_0', 'score': 0.47316074, 'word': '\n', 'start': 324, 'end': 325}, {'entity_group': 'LABEL_2', 'score': 0.52950823, 'word': 'suggestions', 'start': 325, 'end': 336}, {'entity_group': 'LABEL_0', 'score': 0.46536705, 'word': ' or', 'start': 336, 'end': 339}, {'entity_group': 'LABEL_2', 'score': 0.4146151, 'word': ' feedback', 'start': 339, 'end': 348}, {'entity_group': 'LABEL_0', 'score': 0.5139369, 'word': ' to our', 'start': 348, 'end': 355}, {'entity_group': 'LABEL_2', 'score': 0.5753678, 'word': ' investor relations email account', 'start': 355, 'end': 388}, {'entity_group': 'LABEL_0', 'score': 0.45644078, 'word': ' at', 'start': 388, 'end': 391}, {'entity_group': 'LABEL_2', 'score': 0.5367234, 'word': ' finance@asiamedic.com.sg. \n \n', 'start': 391, 'end': 421}, {'entity_group': 'LABEL_0', 'score': 0.34548056, 'word': '7', 'start': 421, 'end': 422}, {'entity_group': 'LABEL_2', 'score': 0.51963556, 'word': '.', 'start': 422, 'end': 423}]
# ...
# [{'entity_group': 'LABEL_0', 'score': 0.6491261, 'word': 'They were mainly', 'start': 0, 'end': 16}, {'entity_group': 'LABEL_2', 'score': 0.49246222, 'word': ' health ', 'start': 16, 'end': 24}, {'entity_group': 'LABEL_0', 'score': 0.53960794, 'word': '\n', 'start': 24, 'end': 25}, {'entity_group': 'LABEL_2', 'score': 0.4968093, 'word': 'screening assistants.', 'start': 25, 'end': 46}]
# [{'entity_group': 'LABEL_2', 'score': 0.5071138, 'word': '2-9 Governance', 'start': 0, 'end': 14}, {'entity_group': 'LABEL_0', 'score': 0.477685, 'word': ' structure and', 'start': 14, 'end': 28}, {'entity_group': 'LABEL_2', 'score': 0.52202785, 'word': ' composition \nAR 4   6, AR 17   21, 2', 'start': 28, 'end': 65}, {'entity_group': 'LABEL_1', 'score': 0.5314272, 'word': ' ', 'start': 65, 'end': 66}, {'entity_group': 'LABEL_2', 'score': 0.5348026, 'word': '  3 \n2-', 'start': 66, 'end': 73}, {'entity_group': 'LABEL_1', 'score': 0.41809213, 'word': '10', 'start': 73, 'end': 75}, {'entity_group': 'LABEL_2', 'score': 0.4812832, 'word': ' Nomination', 'start': 75, 'end': 86}, {'entity_group': 'LABEL_0', 'score': 0.47479877, 'word': ' and', 'start': 86, 'end': 90}, {'entity_group': 'LABEL_2', 'score': 0.39413148, 'word': ' selection', 'start': 90, 'end': 100}, {'entity_group': 'LABEL_0', 'score': 0.42266107, 'word': ' of the', 'start': 100, 'end': 107}, {'entity_group': 'LABEL_2', 'score': 0.44395858, 'word': ' highest ', 'start': 107, 'end': 116}, {'entity_group': 'LABEL_0', 'score': 0.48322165, 'word': '\n', 'start': 116, 'end': 117}, {'entity_group': 'LABEL_2', 'score': 0.5361017, 'word': 'governance', 'start': 117, 'end': 127}, {'entity_group': 'LABEL_0', 'score': 0.4271516, 'word': ' body', 'start': 127, 'end': 132}, {'entity_group': 'LABEL_2', 'score': 0.5324255, 'word': ' \nAR 20   21 \n2-', 'start': 132, 'end': 148}, {'entity_group': 'LABEL_1', 'score': 0.43620592, 'word': '11', 'start': 148, 'end': 150}, {'entity_group': 'LABEL_2', 'score': 0.43657368, 'word': ' Chair', 'start': 150, 'end': 156}, {'entity_group': 'LABEL_0', 'score': 0.41513252, 'word': ' of', 'start': 156, 'end': 159}, {'entity_group': 'LABEL_1', 'score': 0.36763185, 'word': ' the', 'start': 159, 'end': 163}, {'entity_group': 'LABEL_2', 'score': 0.5460567, 'word': ' highest governance body \nAR 4, AR 19, 2', 'start': 163, 'end': 203}, {'entity_group': 'LABEL_1', 'score': 0.5042192, 'word': ' ', 'start': 203, 'end': 204}, {'entity_group': 'LABEL_2', 'score': 0.5358012, 'word': '  3 \n2-', 'start': 204, 'end': 211}, {'entity_group': 'LABEL_1', 'score': 0.42005208, 'word': '12', 'start': 211, 'end': 213}, {'entity_group': 'LABEL_2', 'score': 0.3559626, 'word': ' Role', 'start': 213, 'end': 218}, {'entity_group': 'LABEL_0', 'score': 0.41754985, 'word': ' of', 'start': 218, 'end': 221}, {'entity_group': 'LABEL_2', 'score': 0.51157147, 'word': ' the highest governance body', 'start': 221, 'end': 249}, {'entity_group': 'LABEL_0', 'score': 0.49750796, 'word': ' in', 'start': 249, 'end': 252}, {'entity_group': 'LABEL_2', 'score': 0.43981302, 'word': ' ', 'start': 252, 'end': 253}, {'entity_group': 'LABEL_0', 'score': 0.50088876, 'word': '\n', 'start': 253, 'end': 254}, {'entity_group': 'LABEL_2', 'score': 0.5311318, 'word': 'over', 'start': 254, 'end': 258}, {'entity_group': 'LABEL_0', 'score': 0.469353, 'word': 'seeing the', 'start': 258, 'end': 268}, {'entity_group': 'LABEL_2', 'score': 0.49855044, 'word': ' management', 'start': 268, 'end': 279}, {'entity_group': 'LABEL_0', 'score': 0.60022813, 'word': ' of', 'start': 279, 'end': 282}, {'entity_group': 'LABEL_2', 'score': 0.5445575, 'word': ' impacts \nAR 13   14, AR 34, 1', 'start': 282, 'end': 312}, {'entity_group': 'LABEL_1', 'score': 0.514037, 'word': ' ', 'start': 312, 'end': 313}, {'entity_group': 'LABEL_2', 'score': 0.54676116, 'word': '  3 \n2-13 Delegation', 'start': 313, 'end': 333}, {'entity_group': 'LABEL_0', 'score': 0.6042523, 'word': ' of', 'start': 333, 'end': 336}, {'entity_group': 'LABEL_2', 'score': 0.4546566, 'word': ' responsibility', 'start': 336, 'end': 351}, {'entity_group': 'LABEL_0', 'score': 0.6051177, 'word': ' for managing', 'start': 351, 'end': 364}, {'entity_group': 'LABEL_2', 'score': 0.45406026, 'word': ' ', 'start': 364, 'end': 365}, {'entity_group': 'LABEL_0', 'score': 0.5459175, 'word': '\n', 'start': 365, 'end': 366}, {'entity_group': 'LABEL_2', 'score': 0.54708767, 'word' ...
# [{'entity_group': 'LABEL_2', 'score': 0.45040774, 'word': 'Material Topics ', 'start': 0, 'end': 16}, {'entity_group': 'LABEL_0', 'score': 0.40461764, 'word': '\n', 'start': 16, 'end': 17}, {'entity_group': 'LABEL_2', 'score': 0.48612517, 'word': 'GRI', 'start': 17, 'end': 20}, {'entity_group': 'LABEL_0', 'score': 0.44134545, 'word': ' 3:', 'start': 20, 'end': 23}, {'entity_group': 'LABEL_2', 'score': 0.6079046, 'word': ' Material', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.43824166, 'word': ' \n', 'start': 32, 'end': 34}, {'entity_group': 'LABEL_2', 'score': 0.5087953, 'word': 'Topics 2021 \n3-1 Process to determine material topics \n', 'start': 34, 'end': 89}, {'entity_group': 'LABEL_1', 'score': 0.51628244, 'word': '3', 'start': 89, 'end': 90}, {'entity_group': 'LABEL_2', 'score': 0.5309998, 'word': '   5 \n3-2 List', 'start': 90, 'end': 104}, {'entity_group': 'LABEL_0', 'score': 0.43068126, 'word': ' of', 'start': 104, 'end': 107}, {'entity_group': 'LABEL_2', 'score': 0.55822253, 'word': ' material topics \n', 'start': 107, 'end': 125}, {'entity_group': 'LABEL_1', 'score': 0.4629681, 'word': '5', 'start': 125, 'end': 126}, {'entity_group': 'LABEL_2', 'score': 0.52425635, 'word': ' \n22 \n ', 'start': 126, 'end': 133}, {'entity_group': 'LABEL_0', 'score': 0.44594243, 'word': '\n', 'start': 133, 'end': 134}, {'entity_group': 'LABEL_2', 'score': 0.51196223, 'word': 'GRI Standard', 'start': 134, 'end': 146}, {'entity_group': 'LABEL_0', 'score': 0.43128377, 'word': ' \n', 'start': 146, 'end': 148}, {'entity_group': 'LABEL_2', 'score': 0.5039582, 'word': 'Disclosure', 'start': 148, 'end': 158}, {'entity_group': 'LABEL_0', 'score': 0.42658105, 'word': ' ', 'start': 158, 'end': 159}, {'entity_group': 'LABEL_2', 'score': 0.5160864, 'word': '\nLocation', 'start': 159, 'end': 168}, {'entity_group': 'LABEL_0', 'score': 0.53710467, 'word': ' and', 'start': 168, 'end': 172}, {'entity_group': 'LABEL_2', 'score': 0.55007005, 'word': ' Omissions \n', 'start': 172, 'end': 184}, {'entity_group': 'LABEL_0', 'score': 0.4006448, 'word': '3', 'start': 184, 'end': 185}, {'entity_group': 'LABEL_2', 'score': 0.5097444, 'word': '-3 Management', 'start': 185, 'end': 198}, {'entity_group': 'LABEL_0', 'score': 0.4786899, 'word': ' of', 'start': 198, 'end': 201}, {'entity_group': 'LABEL_2', 'score': 0.5462683, 'word': ' material topics \n', 'start': 201, 'end': 219}, {'entity_group': 'LABEL_1', 'score': 0.44541478, 'word': '6', 'start': 219, 'end': 220}, {'entity_group': 'LABEL_2', 'score': 0.49959022, 'word': '   15 \nSustainable Business Performance ', 'start': 220, 'end': 260}, {'entity_group': 'LABEL_0', 'score': 0.4082355, 'word': '\n', 'start': 260, 'end': 261}, {'entity_group': 'LABEL_2', 'score': 0.50648767, 'word': 'GRI \n201', 'start': 261, 'end': 269}, {'entity_group': 'LABEL_0', 'score': 0.40818518, 'word': ': ', 'start': 269, 'end': 271}, {'entity_group': 'LABEL_2', 'score': 0.4727338, 'word': '\nEconomic \nPerformance', 'start': 271, 'end': 293}, {'entity_group': 'LABEL_0', 'score': 0.44233307, 'word': ' ', 'start': 293, 'end': 294}, {'entity_group': 'LABEL_2', 'score': 0.5409826, 'word': '\n2016 \n201-2', 'start': 294, 'end': 306}, {'entity_group': 'LABEL_0', 'score': 0.43262413, 'word': ' Financial', 'start': 306, 'end': 316}, {'entity_group': 'LABEL_2', 'score': 0.37941468, 'word': ' implications', 'start': 316, 'end': 329}, {'entity_group': 'LABEL_0', 'score': 0.4356794, 'word': ' and', 'start': 329, 'end': 333}, {'entity_group': 'LABEL_2', 'score': 0.5325322, 'word': ' other risks and \nopportunities due to climate change \n17   19  \n201-3 Defined benefit plan', 'start': 333, 'end': 424}, {'entity_group': 'LABEL_0', 'score': 0.4869646, 'word': ' obligations and', 'start': 424, 'end': 440}, {'entity_group': 'LABEL_2', 'score': 0.4767822, 'word': ' other ', 'start': 440, 'end': 447}, {'entity_group': 'LABEL_0', 'score': 0.47202122, 'word': '\n', 'start': 447, 'end': 448}, {'entity_group': 'LABEL_2', 'score': 0.503 ...
# [{'entity_group': 'LABEL_2', 'score': 0.54937893, 'word': 'It has', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_0', 'score': 0.53620243, 'word': ' not', 'start': 6, 'end': 10}, {'entity_group': 'LABEL_2', 'score': 0.4612677, 'word': ' been', 'start': 10, 'end': 15}, {'entity_group': 'LABEL_0', 'score': 0.51334935, 'word': ' \n', 'start': 15, 'end': 17}, {'entity_group': 'LABEL_2', 'score': 0.5248131, 'word': 'examined', 'start': 17, 'end': 25}, {'entity_group': 'LABEL_0', 'score': 0.45916677, 'word': ' or approved by', 'start': 25, 'end': 40}, {'entity_group': 'LABEL_2', 'score': 0.6456764, 'word': ' the SGX-ST', 'start': 40, 'end': 51}, {'entity_group': 'LABEL_0', 'score': 0.4966617, 'word': ' and', 'start': 51, 'end': 55}, {'entity_group': 'LABEL_2', 'score': 0.6537776, 'word': ' the SGX-ST', 'start': 55, 'end': 66}, {'entity_group': 'LABEL_0', 'score': 0.51659834, 'word': ' assumes no responsibility for the', 'start': 66, 'end': 100}, {'entity_group': 'LABEL_2', 'score': 0.5277252, 'word': ' contents of', 'start': 100, 'end': 112}, {'entity_group': 'LABEL_0', 'score': 0.45873874, 'word': ' \n', 'start': 112, 'end': 114}, {'entity_group': 'LABEL_2', 'score': 0.5100324, 'word': 'this announcement', 'start': 114, 'end': 131}, {'entity_group': 'LABEL_0', 'score': 0.48296282, 'word': ', including the', 'start': 131, 'end': 146}, {'entity_group': 'LABEL_2', 'score': 0.49149323, 'word': ' correctness', 'start': 146, 'end': 158}, {'entity_group': 'LABEL_0', 'score': 0.41245434, 'word': ' of any of', 'start': 158, 'end': 168}, {'entity_group': 'LABEL_2', 'score': 0.5145996, 'word': ' the statements or opinions made', 'start': 168, 'end': 200}, {'entity_group': 'LABEL_0', 'score': 0.44289455, 'word': ' or', 'start': 200, 'end': 203}, {'entity_group': 'LABEL_2', 'score': 0.57288885, 'word': ' reports', 'start': 203, 'end': 211}, {'entity_group': 'LABEL_0', 'score': 0.4610887, 'word': ' \n', 'start': 211, 'end': 213}, {'entity_group': 'LABEL_2', 'score': 0.58611, 'word': 'contained in this announcement', 'start': 213, 'end': 243}, {'entity_group': 'LABEL_0', 'score': 0.40125808, 'word': '. The contact', 'start': 243, 'end': 256}, {'entity_group': 'LABEL_1', 'score': 0.36782688, 'word': ' person', 'start': 256, 'end': 263}, {'entity_group': 'LABEL_0', 'score': 0.53417265, 'word': ' for the', 'start': 263, 'end': 271}, {'entity_group': 'LABEL_2', 'score': 0.5757825, 'word': ' Sponsor', 'start': 271, 'end': 279}, {'entity_group': 'LABEL_0', 'score': 0.4327622, 'word': ' is', 'start': 279, 'end': 282}, {'entity_group': 'LABEL_2', 'score': 0.458328, 'word': ' Ms Pauline Sim', 'start': 282, 'end': 297}, {'entity_group': 'LABEL_0', 'score': 0.4050268, 'word': ' (', 'start': 297, 'end': 299}, {'entity_group': 'LABEL_2', 'score': 0.38811392, 'word': 'Registered', 'start': 299, 'end': 309}, {'entity_group': 'LABEL_0', 'score': 0.47652096, 'word': ' \nProfessional) at', 'start': 309, 'end': 327}, {'entity_group': 'LABEL_1', 'score': 0.40694377, 'word': ' 3', 'start': 327, 'end': 329}, {'entity_group': 'LABEL_2', 'score': 0.40581408, 'word': ' Shenton Way', 'start': 329, 'end': 341}, {'entity_group': 'LABEL_0', 'score': 0.38179085, 'word': ',', 'start': 341, 'end': 342}, {'entity_group': 'LABEL_2', 'score': 0.4483281, 'word': ' #24-02 Shenton House', 'start': 342, 'end': 363}, {'entity_group': 'LABEL_0', 'score': 0.4248394, 'word': ',', 'start': 363, 'end': 364}, {'entity_group': 'LABEL_2', 'score': 0.47274828, 'word': ' Singapore 068805.', 'start': 364, 'end': 382}, {'entity_group': 'LABEL_1', 'score': 0.38358065, 'word': ' Telephone', 'start': 382, 'end': 392}, {'entity_group': 'LABEL_0', 'score': 0.50004476, 'word': ' number: (', 'start': 392, 'end': 402}, {'entity_group': 'LABEL_1', 'score': 0.41585088, 'word': '65', 'start': 402, 'end': 404}, {'entity_group': 'LABEL_0', 'score': 0.48432222, 'word': ') \n', 'start': 404, 'end': 407}, {'entity_group': 'LABEL_2', 'score': 0.52295464, 'word': '63', 'start': 407, 'end': 409}, {'entity_group': ' ...

# %%
structured_data
# Out:
# []

# %%
print(model.config.id2label)
# Out:
# {0: 'LABEL_0', 1: 'LABEL_1', 2: 'LABEL_2'}
