# %%
import re
import json
import pandas as pd

def read_data_from_json(filename):
    with open(filename, 'r') as f:
        return json.load(f)
    
def convert_to_bio(data):
    text = data.get("value", "")
    labels = data.get("metrics", [])
    
    # Define a regex pattern to capture numbers with commas, decimal numbers, units, and words
    tokens = re.findall(r'\b\d{1,3}(?:,\d{3})*(?:\.\d+)?|\b\d+\.\d+|\b\d+|(?:\(\w+/\w+\))|(?:\w+(?:\w+)?)', text)
    
    # Filter out unwanted punctuation tokens
    tokens = [token for token in tokens if token not in ['.', '/']]

    bio_labels = ['O'] * len(tokens)

    for entry in labels:
        start = entry['start']
        end = entry['end']
        label_type = entry['labels'][0]

        # Validate start and end indices
        if start < 0 or end > len(text):
            print(f"Skipping entry with invalid indices: {entry}")
            continue
        
        # Calculate the start token index
        start_token_index = len(re.findall(r'\b\d{1,3}(?:,\d{3})*(?:\.\d+)?|\b\d+\.\d+|\b\d+|(?:\(\w+/\w+\))|(?:\w+(?:\w+)?)', text[:start]))
        
        # Validate start_token_index
        if start_token_index < 0 or start_token_index >= len(tokens):
            print(f"Invalid start token index: {start_token_index} for text: {text}")
            continue
        
        bio_labels[start_token_index] = f'B-{label_type}'

        # Process remaining tokens for the current label
        for i in range(1, len(re.findall(r'\b\d{1,3}(?:,\d{3})*(?:\.\d+)?|\b\d+\.\d+|\b\d+|(?:\(\w+/\w+\))|(?:\w+(?:\w+)?)', entry['text']))):
            if start_token_index + i >= len(bio_labels):
                print(f"Index out of bounds while assigning I-{label_type} for index: {start_token_index + i}")
                break  # Exit loop if out of bounds
            
            bio_labels[start_token_index + i] = f'I-{label_type}'

    return list(zip(tokens, bio_labels))

# Process each JSON object and convert to BIO format
def process_json_file(filename):
    data_entries = read_data_from_json(filename)
    
    all_bio_formats = []
    
    for index, data in enumerate(data_entries):
        print(f"Processing entry {index}: {data}")  # Debug output
        if isinstance(data, dict):
            print(f"Keys found: {list(data.keys())}")  # Show the keys for each entry
            
            # Use the correct keys based on your findings
            if 'value' in data and 'metrics' in data:
                bio_format = convert_to_bio(data)
                all_bio_formats.extend(bio_format)
            else:
                print(f"Skipping entry due to missing 'value' or 'metrics': {data}")

    if not all_bio_formats:
        print("No valid entries found for BIO conversion.")

    return all_bio_formats

# Read and process the data from the JSON file
filename = '/Users/roselynnnn/Downloads/project-5 copy.json'
bio_format = process_json_file(filename)

# Save the BIO format to CSV and text files
def save_to_csv(bio_format, filename):
    df = pd.DataFrame(bio_format, columns=['Token', 'BIO Label'])
    df.to_csv(filename, index=False)

def save_to_text(bio_format, filename):
    with open(filename, 'w') as f:
        for token, label in bio_format:
            f.write(f"{token}\t{label}\n")

# Save to files
save_to_csv(bio_format, 'bio_output_6.csv')
save_to_text(bio_format, 'bio_output_6.txt')

print("BIO format saved to bio_output_6.csv and bio_output_6.txt.")
# Out:
# Processing entry 0: {'value': 'The SSC is led by the Chief have not sought external assurance on this report but may Executive Officer and Executive Director, and is responsible consider doing so in the future.', 'id': 5847, 'metrics': [{'start': 44, 'end': 62, 'text': 'external assurance', 'labels': ['metric']}, {'start': 33, 'end': 36, 'text': 'not', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 49, 'created_at': '2024-11-06T18:56:45.247110Z', 'updated_at': '2024-11-06T18:56:45.247110Z', 'lead_time': 12.429}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 1: {'value': 'weforum.org/agenda/2022/10/cop27-how-healthcare-can-reduce-carbon-footprint/ ANNUAL REPORT 2023 55 SUSTAINABILITY REPORT The breakdown of the energy consumption for OUEH s businesses are as follows: COUNTRY SINGAPORE CHINA OUEH Singapore 12 Clinics Pharmaceutical Business Xi Nan Hospital Corporate Office under O2HG Business Office Surface Area 255.0 592.1 4,000.0 440.0 (sqm) 12-month electricity 7.8 68.6 358.6 13.6 consumption (MWh) 12-month electricity 30.5 115.8 89.6 30.9 intensity (kWh/m ) In FY2023, OUEH reports an absolute Scope 2 GHG emissions of 244,059.4 kgCO  from its total electricity consumption.', 'id': 5977, 'metrics': [{'start': 378, 'end': 398, 'text': '12-month electricity', 'labels': ['metric']}, {'start': 399, 'end': 402, 'text': '7.8', 'labels': ['value']}, {'start': 432, 'end': 435, 'text': 'MWh', 'labels': ['unit']}, {'start': 479, 'end': 488, 'text': 'intensity', 'labels': ['metric']}, {'start': 458, 'end': 462, 'text': '30.5', 'labels': ['value']}, {'start': 490, 'end': 495, 'text': 'kWh/m', 'labels': ['unit']}, {'start': 533, 'end': 555, 'text': ' Scope 2 GHG emissions', 'labels': ['metric']}, {'start': 569, 'end': 573, 'text': 'kgCO', 'labels': ['unit']}, {'start': 559, 'end': 568, 'text': '244,059.4', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 41, 'created_at': '2024-11-06T18:09:33.238982Z', 'updated_at': '2024-11-06T18:09:33.238982Z', 'lead_time': 123.341}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 2: {'value': 'The breakdown of Scope 2 GHG emissions and intensity for OUEH s businesses are as follows: COUNTRY SINGAPORE CHINA OUEH Singapore 12 Clinics Pharmaceutical Business Xi Nan Hospital Corporate Office under O2HG Business Office Surface Area 255.0 592.1 4,000.0 440.0 (sqm) Absolute Scope 2 GHG 3,238.1 28,584.7 204,483.9 7,752.7 Emissions (kgCO ) 12-month Scope 2 12.7 48.3 51.1 17.6 intensity (kgCO /m ) 56 OUE HEALTHCARE LIMITED Water Water scarcity is a worldwide concern, and water is OUEH s second most consumed natural resource (with energy being first).', 'id': 5980, 'metrics': [{'start': 270, 'end': 290, 'text': 'Absolute Scope 2 GHG', 'labels': ['metric']}, {'start': 291, 'end': 298, 'text': '3,238.1', 'labels': ['value']}, {'start': 337, 'end': 341, 'text': 'kgCO', 'labels': ['unit']}, {'start': 344, 'end': 360, 'text': '12-month Scope 2', 'labels': ['metric']}, {'start': 361, 'end': 365, 'text': '12.7', 'labels': ['value']}, {'start': 392, 'end': 400, 'text': 'kgCO /m ', 'labels': ['unit']}, {'start': 225, 'end': 237, 'text': 'Surface Area', 'labels': ['metric']}, {'start': 238, 'end': 243, 'text': '255.0', 'labels': ['value']}, {'start': 265, 'end': 268, 'text': 'sqm', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 42, 'created_at': '2024-11-06T18:12:12.290692Z', 'updated_at': '2024-11-06T18:12:12.290692Z', 'lead_time': 135.429}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 3: {'value': 'In FY2023, OUEH s businesses reported a total water withdrawal of 11,866.2 cubic metres ( m ), which translates to a water intensity of 2.2 m  per square metre ( m /m ).', 'id': 5989, 'metrics': [{'start': 46, 'end': 62, 'text': 'water withdrawal', 'labels': ['metric']}, {'start': 66, 'end': 74, 'text': '11,866.2', 'labels': ['value']}, {'start': 75, 'end': 93, 'text': 'cubic metres ( m )', 'labels': ['unit']}, {'start': 117, 'end': 132, 'text': 'water intensity', 'labels': ['metric']}, {'start': 136, 'end': 139, 'text': '2.2', 'labels': ['value']}, {'start': 140, 'end': 168, 'text': 'm per square metre ( m /m )', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 44, 'created_at': '2024-11-06T18:39:07.609651Z', 'updated_at': '2024-11-06T18:39:07.609651Z', 'lead_time': 22.361}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 4: {'value': 'of employees that returned to work in the reporting period after parental 0 3 3 leave ended that were still employed 12 months after their return to work (100% retention rate) Total number of new employee hires during FY2023, by age group, gender and region Age Group Gender Region Total 51 Total 51 Total 51 42 29 25 22 14 12 9 < 30 30 50 > 50 Male Female Singapore China Years Old Years Old Years Old Rate of new employee hires during FY2023, by age group, gender and region Age Group Gender Region < 30 Years Old 30 -50 Years Old Male Female Singapore China > 50 Years Old 8% 5.1% 12.5% 14.2% 23.9% 16.5% Total Total Total 6.8% 29% 29% 29% 62 OUE HEALTHCARE LIMITED Total number of employee turnover during FY2023, by age group, gender and region Age Group Gender Region Total 49 Total 49 Total 49 33 32 23 20 16 17 6 < 30 30 50 > 50 Male Female Singapore China Years Old Years Old Years Old Rate of employee turnover during FY2023, by age group, gender and region Age Group Gender Region < 30 Years Old 30 -50 Years Old Male Female Singapore China > 50 Years Old 3.4% 9.1% 9.7% 13.1% 18.8% 18.2% 11.4% Total Total Total 27.8% 27.8% 27.8% ANNUAL REPORT 2023 63 SUSTAINABILITY REPORT Training and Development (GRI 3-3, 404) Average hours of training employees have undertaken It is crucial that our employees continuously uphold their during FY2023 by employee category expertise and knowledge so that they can provide the highest quality healthcare services to meet the ever- Employee Category changing needs of local communities.', 'id': 6026, 'metrics': [{'start': 3, 'end': 73, 'text': 'employees that returned to work in the reporting period after parental', 'labels': ['metric']}, {'start': 78, 'end': 79, 'text': '3', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 45, 'created_at': '2024-11-06T18:39:41.960450Z', 'updated_at': '2024-11-06T18:39:41.960450Z', 'lead_time': 13.505}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 5: {'value': 'Male Female 12.5% Our corporate office in Singapore adopts the same Occupational Health and Safety ( OHS ) Management System and Workplace Safety and Health ( WSH ) Policy implemented by OUE Limited.', 'id': 6054, 'metrics': [{'start': 0, 'end': 4, 'text': 'Male', 'labels': ['metric']}, {'start': 12, 'end': 16, 'text': '12.5', 'labels': ['value']}, {'start': 16, 'end': 17, 'text': '%', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 46, 'created_at': '2024-11-06T18:43:25.180302Z', 'updated_at': '2024-11-06T18:43:25.180302Z', 'lead_time': 22.221}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 6: {'value': 'Man-hours worked 361,454 0 In addition, the hospital management conduct regular safety walkabouts to proactively identify and mitigate risks within Number and Rate of Work-related Incidents the hospital.', 'id': 6066, 'metrics': [{'start': 0, 'end': 16, 'text': 'Man-hours worked', 'labels': ['metric']}, {'start': 17, 'end': 24, 'text': '361,454', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 47, 'created_at': '2024-11-06T18:44:31.314616Z', 'updated_at': '2024-11-06T18:44:31.314616Z', 'lead_time': 17.728}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 7: {'value': 'In FY2023, we reported zero high-consequence work-related injuries or fatalities, and there were also zero incidents of Zero incidents of There were zero Zero incidents of work-related ill-health.', 'id': 6076, 'metrics': [{'start': 107, 'end': 116, 'text': 'incidents', 'labels': ['metric']}, {'start': 119, 'end': 124, 'text': ' Zero', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 48, 'created_at': '2024-11-06T18:45:19.001609Z', 'updated_at': '2024-11-06T18:45:19.001609Z', 'lead_time': 16.245}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# BIO format saved to bio_output_6.csv and bio_output_6.txt.

# %%
import re
import json
import pandas as pd

def read_data_from_json(filename):
    with open(filename, 'r') as f:
        return json.load(f)
    
def convert_to_bio(data):
    text = data.get("value", "")
    labels = data.get("metrics", [])
    
    # Define a regex pattern to capture numbers with commas, decimal numbers, units, and words
    tokens = re.findall(r'\b\d{1,3}(?:,\d{3})*(?:\.\d+)?|\b\d+\.\d+|\b\d+|(?:\(\w+/\w+\))|(?:\w+(?:\w+)?)', text)
    
    # Filter out unwanted punctuation tokens
    tokens = [token for token in tokens if token not in ['.', '/']]

    bio_labels = ['O'] * len(tokens)

    for entry in labels:
        start = entry['start']
        end = entry['end']
        label_type = entry['labels'][0]

        # Validate start and end indices
        if start < 0 or end > len(text):
            print(f"Skipping entry with invalid indices: {entry}")
            continue
        
        # Calculate the start token index
        start_token_index = len(re.findall(r'\b\d{1,3}(?:,\d{3})*(?:\.\d+)?|\b\d+\.\d+|\b\d+|(?:\(\w+/\w+\))|(?:\w+(?:\w+)?)', text[:start]))
        
        # Validate start_token_index
        if start_token_index < 0 or start_token_index >= len(tokens):
            print(f"Invalid start token index: {start_token_index} for text: {text}")
            continue
        
        bio_labels[start_token_index] = f'B-{label_type}'

        # Process remaining tokens for the current label
        for i in range(1, len(re.findall(r'\b\d{1,3}(?:,\d{3})*(?:\.\d+)?|\b\d+\.\d+|\b\d+|(?:\(\w+/\w+\))|(?:\w+(?:\w+)?)', entry['text']))):
            if start_token_index + i >= len(bio_labels):
                print(f"Index out of bounds while assigning I-{label_type} for index: {start_token_index + i}")
                break  # Exit loop if out of bounds
            
            bio_labels[start_token_index + i] = f'I-{label_type}'

    return list(zip(tokens, bio_labels))

# Process each JSON object and convert to BIO format
def process_json_file(filename):
    data_entries = read_data_from_json(filename)
    
    all_bio_formats = []
    
    for index, data in enumerate(data_entries):
        print(f"Processing entry {index}: {data}")  # Debug output
        if isinstance(data, dict):
            print(f"Keys found: {list(data.keys())}")  # Show the keys for each entry
            
            # Use the correct keys based on your findings
            if 'value' in data and 'metrics' in data:
                bio_format = convert_to_bio(data)
                all_bio_formats.extend(bio_format)
            else:
                print(f"Skipping entry due to missing 'value' or 'metrics': {data}")

    if not all_bio_formats:
        print("No valid entries found for BIO conversion.")

    return all_bio_formats

# Read and process the data from the JSON file
filename = '/Users/roselynnnn/Downloads/project-1.json'
bio_format = process_json_file(filename)

# Save the BIO format to CSV and text files
def save_to_csv(bio_format, filename):
    df = pd.DataFrame(bio_format, columns=['Token', 'BIO Label'])
    df.to_csv(filename, index=False)

def save_to_text(bio_format, filename):
    with open(filename, 'w') as f:
        for token, label in bio_format:
            f.write(f"{token}\t{label}\n")

# Save to files
save_to_csv(bio_format, 'bio_output_1.csv')
save_to_text(bio_format, 'bio_output_1.txt')

print("BIO format saved to bio_output_1.csv and bio_output_1.txt.")
# Out:
# Processing entry 0: {'value': '1 ', 'id': 1, 'annotator': 1, 'annotation_id': 27, 'created_at': '2024-10-30T12:29:28.924502Z', 'updated_at': '2024-10-30T12:29:28.924502Z', 'lead_time': 2.359}
# Keys found: ['value', 'id', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Skipping entry due to missing 'value' or 'metrics': {'value': '1 ', 'id': 1, 'annotator': 1, 'annotation_id': 27, 'created_at': '2024-10-30T12:29:28.924502Z', 'updated_at': '2024-10-30T12:29:28.924502Z', 'lead_time': 2.359}
# Processing entry 1: {'value': 'Net profit (S$ million) ', 'id': 44, 'metrics': [{'start': 0, 'end': 10, 'text': 'Net profit', 'labels': ['metric']}, {'start': 12, 'end': 22, 'text': 'S$ million', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 1, 'created_at': '2024-10-30T11:36:08.419250Z', 'updated_at': '2024-10-30T11:36:08.419250Z', 'lead_time': 120.997}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 2: {'value': '1.9 ', 'id': 45, 'metrics': [{'start': 0, 'end': 3, 'text': '1.9', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 26, 'created_at': '2024-10-30T12:29:12.240891Z', 'updated_at': '2024-10-30T12:29:12.240891Z', 'lead_time': 15.957}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 3: {'value': 'Total greenhouse gas ( GHG ) emissions ', 'id': 48, 'metrics': [{'start': 0, 'end': 38, 'text': 'Total greenhouse gas ( GHG ) emissions', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 2, 'created_at': '2024-10-30T11:37:05.009668Z', 'updated_at': '2024-10-30T11:37:25.541002Z', 'lead_time': 13.391000000000002}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 4: {'value': '(tonnes CO2e) ', 'id': 50, 'metrics': [{'start': 1, 'end': 12, 'text': 'tonnes CO2e', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 3, 'created_at': '2024-10-30T11:37:48.853610Z', 'updated_at': '2024-10-30T11:37:48.853610Z', 'lead_time': 11.725}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 5: {'value': '346 ', 'id': 51, 'metrics': [{'start': 0, 'end': 3, 'text': '346', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 25, 'created_at': '2024-10-30T12:28:54.560714Z', 'updated_at': '2024-10-30T12:28:54.560714Z', 'lead_time': 12.835}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 6: {'value': 'GHG emissions intensity (Scope 2) ', 'id': 53, 'metrics': [{'start': 0, 'end': 33, 'text': 'GHG emissions intensity (Scope 2)', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 4, 'created_at': '2024-10-30T11:38:41.901775Z', 'updated_at': '2024-10-30T11:38:41.901775Z', 'lead_time': 9.439}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 7: {'value': '(tonnes CO2e / revenue S$ 000) ', 'id': 55, 'metrics': [{'start': 1, 'end': 29, 'text': 'tonnes CO2e / revenue S$ 000', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 5, 'created_at': '2024-10-30T11:39:04.881013Z', 'updated_at': '2024-10-30T11:39:04.881013Z', 'lead_time': 14.019}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 8: {'value': '0.018 ', 'id': 56, 'metrics': [{'start': 0, 'end': 5, 'text': '0.018', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 6, 'created_at': '2024-10-30T11:39:24.577857Z', 'updated_at': '2024-10-30T11:39:24.577857Z', 'lead_time': 9.617}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 9: {'value': 'Employee turnover rate (%)2 ', 'id': 63, 'metrics': [{'start': 0, 'end': 22, 'text': 'Employee turnover rate', 'labels': ['metric']}, {'start': 23, 'end': 27, 'text': '(%)2', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 7, 'created_at': '2024-10-30T11:39:52.463284Z', 'updated_at': '2024-10-30T11:39:52.463284Z', 'lead_time': 14.27}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 10: {'value': '13.7 ', 'id': 64, 'metrics': [{'start': 0, 'end': 4, 'text': '13.7', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 8, 'created_at': '2024-10-30T11:40:41.394245Z', 'updated_at': '2024-10-30T11:40:41.394245Z', 'lead_time': 45.823}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 11: {'value': 'Electricity consumption ', 'id': 652, 'metrics': [{'start': 0, 'end': 23, 'text': 'Electricity consumption', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 9, 'created_at': '2024-10-30T11:47:28.716544Z', 'updated_at': '2024-10-30T11:47:28.716544Z', 'lead_time': 6.202}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 12: {'value': 'kWh ', 'id': 653, 'metrics': [{'start': 0, 'end': 3, 'text': 'kWh', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 10, 'created_at': '2024-10-30T11:47:38.877041Z', 'updated_at': '2024-10-30T11:47:38.877041Z', 'lead_time': 7.691}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 13: {'value': '830,232 ', 'id': 654, 'metrics': [{'start': 0, 'end': 7, 'text': '830,232', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 11, 'created_at': '2024-10-30T11:47:44.852198Z', 'updated_at': '2024-10-30T11:47:44.852198Z', 'lead_time': 4.776}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 14: {'value': 'Electricity consumption intensity ', 'id': 656, 'metrics': [{'start': 0, 'end': 33, 'text': 'Electricity consumption intensity', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 12, 'created_at': '2024-10-30T11:47:59.811698Z', 'updated_at': '2024-10-30T11:47:59.811698Z', 'lead_time': 6.32}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 15: {'value': 'Total indirect GHG emissions (Scope 2)8 ', 'id': 661, 'metrics': [{'start': 0, 'end': 38, 'text': 'Total indirect GHG emissions (Scope 2)', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 13, 'created_at': '2024-10-30T11:49:03.309366Z', 'updated_at': '2024-10-30T11:49:03.309366Z', 'lead_time': 6.272}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 16: {'value': 'tonnes CO2e ', 'id': 662, 'metrics': [{'start': 0, 'end': 11, 'text': 'tonnes CO2e', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 14, 'created_at': '2024-10-30T11:49:10.053370Z', 'updated_at': '2024-10-30T11:49:10.054370Z', 'lead_time': 5.637}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 17: {'value': '346 ', 'id': 663, 'metrics': [{'start': 0, 'end': 3, 'text': '346', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 15, 'created_at': '2024-10-30T11:49:16.195654Z', 'updated_at': '2024-10-30T11:49:16.195654Z', 'lead_time': 4.753}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 18: {'value': 'FY2023 ', 'id': 774, 'metrics': [{'start': 0, 'end': 6, 'text': 'FY2023', 'labels': ['year']}], 'annotator': 1, 'annotation_id': 16, 'created_at': '2024-10-30T11:50:50.464308Z', 'updated_at': '2024-10-30T11:50:50.464308Z', 'lead_time': 9.829}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 19: {'value': 'New hires rate ', 'id': 778, 'metrics': [{'start': 0, 'end': 14, 'text': 'New hires rate', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 17, 'created_at': '2024-10-30T11:51:14.109360Z', 'updated_at': '2024-10-30T11:51:14.109360Z', 'lead_time': 4.288}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 20: {'value': 'New hires rate ', 'id': 783, 'metrics': [{'start': 0, 'end': 14, 'text': 'New hires rate', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 18, 'created_at': '2024-10-30T11:52:09.039488Z', 'updated_at': '2024-10-30T11:52:09.039488Z', 'lead_time': 6.419}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 21: {'value': '27.1% ', 'id': 785, 'metrics': [{'start': 0, 'end': 5, 'text': '27.1%', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 19, 'created_at': '2024-10-30T11:52:42.699257Z', 'updated_at': '2024-10-30T11:52:42.699257Z', 'lead_time': 19.328}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 22: {'value': 'FY2023 ', 'id': 823, 'metrics': [{'start': 0, 'end': 6, 'text': 'FY2023', 'labels': ['year']}], 'annotator': 1, 'annotation_id': 20, 'created_at': '2024-10-30T11:53:48.737849Z', 'updated_at': '2024-10-30T11:53:48.737849Z', 'lead_time': 6.888}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 23: {'value': 'Turnover rate ', 'id': 827, 'metrics': [{'start': 0, 'end': 13, 'text': 'Turnover rate', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 21, 'created_at': '2024-10-30T11:54:04.090799Z', 'updated_at': '2024-10-30T11:54:04.090799Z', 'lead_time': 8.552}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 24: {'value': 'FY2023 ', 'id': 885, 'metrics': [{'start': 2, 'end': 6, 'text': '2023', 'labels': ['year']}], 'annotator': 1, 'annotation_id': 22, 'created_at': '2024-10-30T11:54:47.642109Z', 'updated_at': '2024-10-30T11:54:47.642109Z', 'lead_time': 5.906}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Invalid start token index: 1 for text: FY2023
# Processing entry 25: {'value': 'Total training hours ', 'id': 888, 'metrics': [{'start': 0, 'end': 20, 'text': 'Total training hours', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 23, 'created_at': '2024-10-30T11:54:58.798603Z', 'updated_at': '2024-10-30T11:54:58.798603Z', 'lead_time': 4.781}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 26: {'value': '480 ', 'id': 889, 'metrics': [{'start': 0, 'end': 3, 'text': '480', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 24, 'created_at': '2024-10-30T11:55:10.166038Z', 'updated_at': '2024-10-30T11:55:10.166038Z', 'lead_time': 3.981}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 27: {'value': 'Average training hours per employee ', 'id': 891, 'metrics': [{'start': 0, 'end': 35, 'text': 'Average training hours per employee', 'labels': ['metric']}, {'start': 17, 'end': 22, 'text': 'hours', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 28, 'created_at': '2024-10-30T14:27:24.168590Z', 'updated_at': '2024-10-30T14:27:24.168590Z', 'lead_time': 37.163}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 28: {'value': '3.3 ', 'id': 892, 'metrics': [{'start': 0, 'end': 3, 'text': '3.3', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 29, 'created_at': '2024-10-30T14:27:38.521658Z', 'updated_at': '2024-10-30T14:27:38.521658Z', 'lead_time': 12.704}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 29: {'value': 'Gender Diversity (%) ', 'id': 1000, 'metrics': [{'start': 0, 'end': 17, 'text': 'Gender Diversity ', 'labels': ['metric']}, {'start': 18, 'end': 19, 'text': '%', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 30, 'created_at': '2024-10-30T14:29:33.556328Z', 'updated_at': '2024-10-30T14:29:33.556328Z', 'lead_time': 9.386}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Invalid start token index: 2 for text: Gender Diversity (%)
# Processing entry 30: {'value': 'On gender diversity, the percentage of female to total number of full-time employees is 80% (FY2022: ', 'id': 1001, 'metrics': [{'start': 88, 'end': 91, 'text': '80%', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 32, 'created_at': '2024-10-30T14:30:35.380276Z', 'updated_at': '2024-10-30T14:30:35.380276Z', 'lead_time': 32.964}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 31: {'value': '31 December 2023, 17% of our workforce is above 50 years old (31 December 2022: 25%).  ', 'id': 1008, 'metrics': [{'start': 41, 'end': 60, 'text': ' above 50 years old', 'labels': ['metric']}, {'start': 20, 'end': 21, 'text': '%', 'labels': ['unit']}, {'start': 18, 'end': 21, 'text': '17%', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 31, 'created_at': '2024-10-30T14:30:28.080800Z', 'updated_at': '2024-10-30T14:30:28.080800Z', 'lead_time': 15.994}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 32: {'value': 'Below 30 ', 'id': 1022, 'metrics': [{'start': 0, 'end': 8, 'text': 'Below 30', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 33, 'created_at': '2024-10-30T14:32:52.007874Z', 'updated_at': '2024-10-30T14:32:52.007874Z', 'lead_time': 25.375999999999998}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 33: {'value': '29% ', 'id': 1026, 'metrics': [{'start': 0, 'end': 3, 'text': '29%', 'labels': ['value']}, {'start': 2, 'end': 3, 'text': '%', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 34, 'created_at': '2024-10-30T14:32:59.239774Z', 'updated_at': '2024-10-30T14:33:02.970879Z', 'lead_time': 8.055}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Invalid start token index: 1 for text: 29%
# Processing entry 34: {'value': 'Customer Satisfaction ', 'id': 1152, 'metrics': [{'start': 0, 'end': 21, 'text': 'Customer Satisfaction', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 35, 'created_at': '2024-10-30T14:35:01.791472Z', 'updated_at': '2024-10-30T14:35:01.791472Z', 'lead_time': 5.888}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 35: {'value': 'Maintain zero non-compliance incident of ', 'id': 1154, 'metrics': [{'start': 0, 'end': 37, 'text': 'Maintain zero non-compliance incident', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 36, 'created_at': '2024-10-30T14:35:23.237473Z', 'updated_at': '2024-10-30T14:35:23.238472Z', 'lead_time': 14.754}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 36: {'value': 'Economic Performance ', 'id': 1159, 'metrics': [{'start': 0, 'end': 20, 'text': 'Economic Performance', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 37, 'created_at': '2024-10-30T14:35:40.742731Z', 'updated_at': '2024-10-30T14:35:40.742731Z', 'lead_time': 7.966}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 37: {'value': 'Creating sustainable value for our ', 'id': 1161, 'metrics': [{'start': 0, 'end': 26, 'text': 'Creating sustainable value', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 38, 'created_at': '2024-10-30T14:35:48.433104Z', 'updated_at': '2024-10-30T14:35:48.433104Z', 'lead_time': 4.026}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 38: {'value': 'Emissions Management ', 'id': 1177, 'metrics': [{'start': 0, 'end': 20, 'text': 'Emissions Management', 'labels': ['metric']}], 'annotator': 1, 'annotation_id': 39, 'created_at': '2024-10-30T14:36:16.818724Z', 'updated_at': '2024-10-30T14:36:16.818724Z', 'lead_time': 4.253}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 39: {'value': 'Maintain or reduce Scope 2 GHG ', 'id': 1180, 'metrics': [{'start': 0, 'end': 30, 'text': 'Maintain or reduce Scope 2 GHG', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 40, 'created_at': '2024-10-30T14:36:27.805737Z', 'updated_at': '2024-10-30T14:36:39.688606Z', 'lead_time': 17.083}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# BIO format saved to bio_output_1.csv and bio_output_1.txt.

# %%
import re
import json
import pandas as pd
import os

def read_data_from_json(filename):
    with open(filename, 'r') as f:
        return json.load(f)
    
def convert_to_bio(data):
    text = data.get("value", "")
    labels = data.get("metrics", [])
    
    # Define a regex pattern to capture numbers with commas, decimal numbers, units, and words
    tokens = re.findall(r'\b\d{1,3}(?:,\d{3})*(?:\.\d+)?|\b\d+\.\d+|\b\d+|(?:\(\w+/\w+\))|(?:\w+(?:\w+)?)', text)
    
    # Filter out unwanted punctuation tokens
    tokens = [token for token in tokens if token not in ['.', '/']]

    bio_labels = ['O'] * len(tokens)

    for entry in labels:
        start = entry['start']
        end = entry['end']
        label_type = entry['labels'][0]

        # Validate start and end indices
        if start < 0 or end > len(text):
            print(f"Skipping entry with invalid indices: {entry}")
            continue
        
        # Calculate the start token index
        start_token_index = len(re.findall(r'\b\d{1,3}(?:,\d{3})*(?:\.\d+)?|\b\d+\.\d+|\b\d+|(?:\(\w+/\w+\))|(?:\w+(?:\w+)?)', text[:start]))
        
        # Validate start_token_index
        if start_token_index < 0 or start_token_index >= len(tokens):
            print(f"Invalid start token index: {start_token_index} for text: {text}")
            continue
        
        bio_labels[start_token_index] = f'B-{label_type}'

        # Process remaining tokens for the current label
        for i in range(1, len(re.findall(r'\b\d{1,3}(?:,\d{3})*(?:\.\d+)?|\b\d+\.\d+|\b\d+|(?:\(\w+/\w+\))|(?:\w+(?:\w+)?)', entry['text']))):
            if start_token_index + i >= len(bio_labels):
                print(f"Index out of bounds while assigning I-{label_type} for index: {start_token_index + i}")
                break  # Exit loop if out of bounds
            
            bio_labels[start_token_index + i] = f'I-{label_type}'

    return list(zip(tokens, bio_labels))

# Process each JSON object and convert to BIO format
def process_json_file(filename):
    data_entries = read_data_from_json(filename)
    
    all_bio_formats = []
    
    for index, data in enumerate(data_entries):
        print(f"Processing entry {index}: {data}")  # Debug output
        if isinstance(data, dict):
            print(f"Keys found: {list(data.keys())}")  # Show the keys for each entry
            
            # Use the correct keys based on your findings
            if 'value' in data and 'metrics' in data:
                bio_format = convert_to_bio(data)
                all_bio_formats.extend(bio_format)
            else:
                print(f"Skipping entry due to missing 'value' or 'metrics': {data}")

    if not all_bio_formats:
        print("No valid entries found for BIO conversion.")

    return all_bio_formats

# Save to JSON file
def save_to_json(bio_format, filename):
    # Convert the bio_format to a list of dictionaries
    json_data = [{"Token": token, "BIO Label": label} for token, label in bio_format]
    
    with open(filename, 'w') as f:
        json.dump(json_data, f, indent=4)

# Process all JSON files in the input folder
def process_folder(input_folder, output_folder):
    # Create output folder if it does not exist
    os.makedirs(output_folder, exist_ok=True)
    
    # Loop through all JSON files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.json'):
            input_file_path = os.path.join(input_folder, filename)
            print(f"Processing file: {input_file_path}")
            bio_format = process_json_file(input_file_path)

            # Save the BIO format to a JSON file in the output folder
            output_file_path = os.path.join(output_folder, f'bio_{filename}')
            save_to_json(bio_format, output_file_path)

            print(f"SAVED: {output_file_path}")

# Define input and output folders
input_folder = '/Users/roselynnnn/Downloads/Raw_Json'  # Replace with your input folder path
output_folder = '/Users/roselynnnn/Downloads/Raw_Json_Bio'  # Replace with your output folder path

# Process the folder
process_folder(input_folder, output_folder)
# Out:
# Processing file: /Users/roselynnnn/Downloads/Raw_Json/project-2-at-2024-11-07-21-01-a53c81a7.json
# Processing entry 0: {'value': 'In 2023, there were no workers with high risk of diseases related to their occupation.', 'id': 1692, 'metrics': [{'start': 31, 'end': 85, 'text': 'with high risk of diseases related to their occupation', 'labels': ['metric']}, {'start': 20, 'end': 22, 'text': 'no', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 96, 'created_at': '2024-11-06T11:37:53.895741Z', 'updated_at': '2024-11-06T11:37:53.895741Z', 'lead_time': 11.289}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 1: {'value': 'Percentage of employees at the manufacturing division of Haw Par Healthcare Singapore covered by a collective bargaining agreement: 2023 2022 2021 67% 65% 77% Supply Chain To guide and   Committed to an ethical and accountable procurement process that maintains encourage integrity and fairness.', 'id': 1707, 'metrics': [{'start': 0, 'end': 130, 'text': 'Percentage of employees at the manufacturing division of Haw Par Healthcare Singapore covered by a collective bargaining agreement', 'labels': ['metric']}, {'start': 147, 'end': 150, 'text': '67%', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 97, 'created_at': '2024-11-06T11:38:36.362193Z', 'updated_at': '2024-11-06T11:38:36.362193Z', 'lead_time': 17.119}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 2: {'value': 'GHG profiling and Scope 3 GHG screening Haw Par Healthcare - Singapore 2023 2022 2021 Incidents of non-compliance with environmental laws and regulations Nil Nil Nil Energy consumption within the Organisation (MWh) 3,969.98 3,232.56 3,197.5 Purchased Grid Electricity GHG Emissions** Scope 2 GHG emissions (tCO2e) 1,654.7 1,347.3 1,306.2 Water withdrawal from third-party water source (megalitre) 16.29 10.75 8.0 Water discharge (megalitre) 11.24 7.42 5.24 Water consumption (megalitre) 5.05 3.33 2.76 Note: Our manufacturing plants are powered by electricity, which we purchased from the grid.', 'id': 1726, 'metrics': [{'start': 457, 'end': 474, 'text': 'Water consumption', 'labels': ['metric']}, {'start': 497, 'end': 501, 'text': '2.76', 'labels': ['value']}, {'start': 476, 'end': 485, 'text': 'megalitre', 'labels': ['unit']}, {'start': 413, 'end': 429, 'text': 'Water discharge ', 'labels': ['metric']}, {'start': 452, 'end': 456, 'text': '5.24', 'labels': ['value']}, {'start': 430, 'end': 439, 'text': 'megalitre', 'labels': ['unit']}, {'start': 338, 'end': 384, 'text': 'Water withdrawal from third-party water source', 'labels': ['metric']}, {'start': 409, 'end': 412, 'text': '8.0', 'labels': ['value']}, {'start': 386, 'end': 395, 'text': 'megalitre', 'labels': ['unit']}, {'start': 292, 'end': 305, 'text': 'GHG emissions', 'labels': ['metric']}, {'start': 330, 'end': 337, 'text': '1,306.2', 'labels': ['value']}, {'start': 307, 'end': 312, 'text': 'tCO2e', 'labels': ['unit']}, {'start': 241, 'end': 267, 'text': 'Purchased Grid Electricity', 'labels': ['metric']}, {'start': 233, 'end': 240, 'text': '3,197.5', 'labels': ['value']}, {'start': 210, 'end': 213, 'text': 'MWh', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 95, 'created_at': '2024-11-06T11:31:01.927054Z', 'updated_at': '2024-11-06T11:31:01.927054Z', 'lead_time': 115.733}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 3: {'value': '19', 'id': 1877, 'annotator': 1, 'annotation_id': 98, 'created_at': '2024-11-06T11:41:21.886926Z', 'updated_at': '2024-11-06T11:41:21.886926Z', 'lead_time': 6.262}
# Keys found: ['value', 'id', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Skipping entry due to missing 'value' or 'metrics': {'value': '19', 'id': 1877, 'annotator': 1, 'annotation_id': 98, 'created_at': '2024-11-06T11:41:21.886926Z', 'updated_at': '2024-11-06T11:41:21.886926Z', 'lead_time': 6.262}
# SAVED: /Users/roselynnnn/Downloads/Raw_Json_Bio/bio_project-2-at-2024-11-07-21-01-a53c81a7.json
# Processing file: /Users/roselynnnn/Downloads/Raw_Json/project-5.json
# Processing entry 0: {'value': 'The SSC is led by the Chief have not sought external assurance on this report but may Executive Officer and Executive Director, and is responsible consider doing so in the future.', 'id': 5847, 'metrics': [{'start': 44, 'end': 62, 'text': 'external assurance', 'labels': ['metric']}, {'start': 33, 'end': 36, 'text': 'not', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 49, 'created_at': '2024-11-06T18:56:45.247110Z', 'updated_at': '2024-11-06T18:56:45.247110Z', 'lead_time': 12.429}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 1: {'value': 'weforum.org/agenda/2022/10/cop27-how-healthcare-can-reduce-carbon-footprint/ ANNUAL REPORT 2023 55 SUSTAINABILITY REPORT The breakdown of the energy consumption for OUEH s businesses are as follows: COUNTRY SINGAPORE CHINA OUEH Singapore 12 Clinics Pharmaceutical Business Xi Nan Hospital Corporate Office under O2HG Business Office Surface Area 255.0 592.1 4,000.0 440.0 (sqm) 12-month electricity 7.8 68.6 358.6 13.6 consumption (MWh) 12-month electricity 30.5 115.8 89.6 30.9 intensity (kWh/m ) In FY2023, OUEH reports an absolute Scope 2 GHG emissions of 244,059.4 kgCO  from its total electricity consumption.', 'id': 5977, 'metrics': [{'start': 378, 'end': 398, 'text': '12-month electricity', 'labels': ['metric']}, {'start': 399, 'end': 402, 'text': '7.8', 'labels': ['value']}, {'start': 432, 'end': 435, 'text': 'MWh', 'labels': ['unit']}, {'start': 479, 'end': 488, 'text': 'intensity', 'labels': ['metric']}, {'start': 458, 'end': 462, 'text': '30.5', 'labels': ['value']}, {'start': 490, 'end': 495, 'text': 'kWh/m', 'labels': ['unit']}, {'start': 533, 'end': 555, 'text': ' Scope 2 GHG emissions', 'labels': ['metric']}, {'start': 569, 'end': 573, 'text': 'kgCO', 'labels': ['unit']}, {'start': 559, 'end': 568, 'text': '244,059.4', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 41, 'created_at': '2024-11-06T18:09:33.238982Z', 'updated_at': '2024-11-06T18:09:33.238982Z', 'lead_time': 123.341}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 2: {'value': 'The breakdown of Scope 2 GHG emissions and intensity for OUEH s businesses are as follows: COUNTRY SINGAPORE CHINA OUEH Singapore 12 Clinics Pharmaceutical Business Xi Nan Hospital Corporate Office under O2HG Business Office Surface Area 255.0 592.1 4,000.0 440.0 (sqm) Absolute Scope 2 GHG 3,238.1 28,584.7 204,483.9 7,752.7 Emissions (kgCO ) 12-month Scope 2 12.7 48.3 51.1 17.6 intensity (kgCO /m ) 56 OUE HEALTHCARE LIMITED Water Water scarcity is a worldwide concern, and water is OUEH s second most consumed natural resource (with energy being first).', 'id': 5980, 'metrics': [{'start': 270, 'end': 290, 'text': 'Absolute Scope 2 GHG', 'labels': ['metric']}, {'start': 291, 'end': 298, 'text': '3,238.1', 'labels': ['value']}, {'start': 337, 'end': 341, 'text': 'kgCO', 'labels': ['unit']}, {'start': 344, 'end': 360, 'text': '12-month Scope 2', 'labels': ['metric']}, {'start': 361, 'end': 365, 'text': '12.7', 'labels': ['value']}, {'start': 392, 'end': 400, 'text': 'kgCO /m ', 'labels': ['unit']}, {'start': 225, 'end': 237, 'text': 'Surface Area', 'labels': ['metric']}, {'start': 238, 'end': 243, 'text': '255.0', 'labels': ['value']}, {'start': 265, 'end': 268, 'text': 'sqm', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 42, 'created_at': '2024-11-06T18:12:12.290692Z', 'updated_at': '2024-11-06T18:12:12.290692Z', 'lead_time': 135.429}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 3: {'value': 'In FY2023, OUEH s businesses reported a total water withdrawal of 11,866.2 cubic metres ( m ), which translates to a water intensity of 2.2 m  per square metre ( m /m ).', 'id': 5989, 'metrics': [{'start': 46, 'end': 62, 'text': 'water withdrawal', 'labels': ['metric']}, {'start': 66, 'end': 74, 'text': '11,866.2', 'labels': ['value']}, {'start': 75, 'end': 93, 'text': 'cubic metres ( m )', 'labels': ['unit']}, {'start': 117, 'end': 132, 'text': 'water intensity', 'labels': ['metric']}, {'start': 136, 'end': 139, 'text': '2.2', 'labels': ['value']}, {'start': 140, 'end': 168, 'text': 'm per square metre ( m /m )', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 43, 'created_at': '2024-11-06T18:14:17.668786Z', 'updated_at': '2024-11-06T18:14:17.668786Z', 'lead_time': 59.346}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 4: {'value': 'of employees that took Parental Leave 0 3 3 Total No.', 'id': 6024, 'metrics': [{'start': 3, 'end': 39, 'text': 'employees entitled to Parental Leave', 'labels': ['metric']}, {'start': 44, 'end': 46, 'text': '3 ', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 44, 'created_at': '2024-11-06T18:39:07.609651Z', 'updated_at': '2024-11-06T18:39:07.609651Z', 'lead_time': 22.361}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 5: {'value': 'of employees that returned to work in the reporting period after parental 0 3 3 leave ended that were still employed 12 months after their return to work (100% retention rate) Total number of new employee hires during FY2023, by age group, gender and region Age Group Gender Region Total 51 Total 51 Total 51 42 29 25 22 14 12 9 < 30 30 50 > 50 Male Female Singapore China Years Old Years Old Years Old Rate of new employee hires during FY2023, by age group, gender and region Age Group Gender Region < 30 Years Old 30 -50 Years Old Male Female Singapore China > 50 Years Old 8% 5.1% 12.5% 14.2% 23.9% 16.5% Total Total Total 6.8% 29% 29% 29% 62 OUE HEALTHCARE LIMITED Total number of employee turnover during FY2023, by age group, gender and region Age Group Gender Region Total 49 Total 49 Total 49 33 32 23 20 16 17 6 < 30 30 50 > 50 Male Female Singapore China Years Old Years Old Years Old Rate of employee turnover during FY2023, by age group, gender and region Age Group Gender Region < 30 Years Old 30 -50 Years Old Male Female Singapore China > 50 Years Old 3.4% 9.1% 9.7% 13.1% 18.8% 18.2% 11.4% Total Total Total 27.8% 27.8% 27.8% ANNUAL REPORT 2023 63 SUSTAINABILITY REPORT Training and Development (GRI 3-3, 404) Average hours of training employees have undertaken It is crucial that our employees continuously uphold their during FY2023 by employee category expertise and knowledge so that they can provide the highest quality healthcare services to meet the ever- Employee Category changing needs of local communities.', 'id': 6026, 'metrics': [{'start': 3, 'end': 73, 'text': 'employees that returned to work in the reporting period after parental', 'labels': ['metric']}, {'start': 78, 'end': 79, 'text': '3', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 45, 'created_at': '2024-11-06T18:39:41.960450Z', 'updated_at': '2024-11-06T18:39:41.960450Z', 'lead_time': 13.505}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 6: {'value': 'Male Female 12.5% Our corporate office in Singapore adopts the same Occupational Health and Safety ( OHS ) Management System and Workplace Safety and Health ( WSH ) Policy implemented by OUE Limited.', 'id': 6054, 'metrics': [{'start': 0, 'end': 4, 'text': 'Male', 'labels': ['metric']}, {'start': 12, 'end': 16, 'text': '12.5', 'labels': ['value']}, {'start': 16, 'end': 17, 'text': '%', 'labels': ['unit']}], 'annotator': 1, 'annotation_id': 46, 'created_at': '2024-11-06T18:43:25.180302Z', 'updated_at': '2024-11-06T18:43:25.180302Z', 'lead_time': 22.221}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 7: {'value': 'Man-hours worked 361,454 0 In addition, the hospital management conduct regular safety walkabouts to proactively identify and mitigate risks within Number and Rate of Work-related Incidents the hospital.', 'id': 6066, 'metrics': [{'start': 0, 'end': 16, 'text': 'Man-hours worked', 'labels': ['metric']}, {'start': 17, 'end': 24, 'text': '361,454', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 47, 'created_at': '2024-11-06T18:44:31.314616Z', 'updated_at': '2024-11-06T18:44:31.314616Z', 'lead_time': 17.728}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# Processing entry 8: {'value': 'In FY2023, we reported zero high-consequence work-related injuries or fatalities, and there were also zero incidents of Zero incidents of There were zero Zero incidents of work-related ill-health.', 'id': 6076, 'metrics': [{'start': 107, 'end': 116, 'text': 'incidents', 'labels': ['metric']}, {'start': 119, 'end': 124, 'text': ' Zero', 'labels': ['value']}], 'annotator': 1, 'annotation_id': 48, 'created_at': '2024-11-06T18:45:19.001609Z', 'updated_at': '2024-11-06T18:45:19.001609Z', 'lead_time': 16.245}
# Keys found: ['value', 'id', 'metrics', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time']
# SAVED: /Users/roselynnnn/Downloads/Raw_Json_Bio/bio_project-5.json
