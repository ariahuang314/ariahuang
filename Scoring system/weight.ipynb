# %%
import fitz 
import pandas as pd
import os

# %%
pdf_folder_path = "../report_new"

# %% [markdown]
# # weight

# %%
#dictionary
esg_dictionary = {
    "Environment": {
        "Biodiversity & Land Use": {
            "Protected or restored habitats": [
                "Natural resources", "Biodiversity", "Ecosystem Services", "Restoration Projects", "GRI 304"
            ]
        },
        "Carbon Emissions": {
            "Absolute emissions": [
                "Absolute emissions", "GRI 305-1", "GRI 305-2", "GRI 305-3"
            ],
            "Emission intensities": [
                "Emission intensities", "GRI 305-4"
            ],
            "Total energy consumption": [
                "energy consumption", "GRI 302-1"
            ],
            "Energy consumption intensity": [
                "Energy consumption intensity", "GRI 302-3"
            ]
        },
        "Electronic Waste": {
            "Total waste generated": [
                "Electronic waste generated", "GRI 306-1", "E-Waste", "GRI 306"
            ]
        },
        "Financing Environmental Impact": {
            "Green financing projects": [
                "Sustainable Investment", "Climate-related Financing", "Green Bonds Issued", "Environmental Impact of Financed Projects", "GRI 201-1"
            ]
        },
        "Opportunities in Clean Tech": {
            "Investment in clean technology": [
                "Research and Development (R&D) for Clean Technology", "Renewable Energy Investment", "Carbon Capture and Storage (CCS) Projects",
                "Water Treatment and Conservation Technologies", "Circular Economy and Waste Reduction Technologies"
            ]
        },
        "Opportunities in Green Building": {
            "Green certified buildings": [
                "LEED", "BREEAM", "WELL", "GRI 413-1"
            ]
        },
        "Opportunities in Renewable Energy": {
            "Renewable energy generation capacity": [
                "Installed Renewable Energy Capacity", "Renewable Energy Production", "Greenhouse Gas (GHG) Emissions Reduction",
                "Investments in Renewable Energy Infrastructure", "Renewable Energy Intensity"
            ]
        },
        "Packaging Material & Waste": {
            "Total waste generated": [
                "packaging waste", "GRI 306-3"
            ]
        },
        "Raw Material Sourcing": {
            "Percentage of sustainable materials sourced": [
                "Sustainable Material Sourcing", "GRI 301-1:"
            ]
        },
        "Toxic Emissions & Waste": {
            "Total waste generated": [
                "Toxic Emissions", "GRI 305-7"
            ]
        },
        "Water Stress": {
            "Total water consumption": [
                "Total water consumption", "GRI 303-5"
            ],
            "water discharged": [
                "water discharged", "GRI 303-4"
            ],
            "water intake": [
                "Water Withdrawal", "GRI 303-3"
            ]
        }
    },
    "Social": {
        "Access to Health Care": {
            "Percentage of employees covered by health insurance": [
                "Employee Health Insurance Coverage", "GRI 403-3"
            ],
            "Availability of Healthcare Resources": [
                "Healthcare Coverage for Employees", "GRI 403-6"
            ],
            "Community Health Program Count": [
                "Community Health Initiatives", "GRI 413-1"
            ]
        },
        "Human Capital Development": {
            "Average training hours per employee": [
                "Employee Training Hours", "GRI 404-1"
            ],
            "Average training hours per employee by gender": [
                "Training Hours by Gender", "GRI 404-2"
            ]
        },
        "Labor Management": {
            "Current employees by gender": [
                "Employee Gender Distribution", "Gender-based Turnover Rate"
            ],
            "New hires and turnover by gender": [
                "New Hires by Gender", "Employee Turnover by Gender"
            ],
            "Current employees by age groups": [
                "Employee Age Distribution", "Age Diversity"
            ],
            "New hires and turnover by age groups": [
                "Employee Turnover by Age Group"
            ],
            "Total turnover": [
                "Turnover Rate", "GRI 401-1"
            ],
            "Total number of employees": [
                "Total Workforce Count", "GRI 102-8"
            ],
            "Employee satisfaction rate": [
                "Work-life Balance Satisfaction", "GRI 401-3"
            ]
        },
        "Privacy & Data Security": {
            "Number of Data Breaches": [
                "Data Breach Incidents", "GRI 418-1"
            ],
            "Customer Data Protection Measures": [
                "Data Privacy Policies", "Data Encryption and Security Protocols", "Data Protection", "Authentication", "Access Control"
            ],
            "Compliance Audit": [
                "Compliance", "Compliance Audit Outcomes", "GRI 419-1"
            ],
            "Employee Privacy Training Rate": [
                "Data Protection Training"
            ],
            "Privacy-Related Customer Complaints": [
                "Privacy Complaints"
            ]
        },
        "Product Safety & Quality": {
            "Number of Product Recalls": [
                "Product Recalls", "GRI 416-2"
            ],
            "Clinical Trial Transparency": [
                "Disclosure of Clinical Trial Results", "Patient Safety", "Clinical Trial Registration", "Ethics and Compliance in Clinical Trials", "GRI 416-1"
            ],
            "Adverse Event Reporting Rate": [
                "Adverse Event", "GRI 403-2"
            ]
        },
        "Customer Financial Protection": {
            "Consumer rights protection": [
                "Customer Privacy and Data Protection", "Consumer rights", "Product Health", "Customer Feedback", "GRI 102-17"
            ]
        },
        "Opportunities in Nutrition & Health": {
            "Community nutrition programs": [
                "Nutrition and Health Initiatives", "Health and Wellness Programs", "Balanced Diets", "Nutrition Organizations", "Food Banks"
            ]
        },
        "Community Relations": {
            "Philanthropic initiatives": [
                "Charitable Contributions", "Philanthropy", "Employee Volunteering", "Disaster Relief", "Corporate Donations"
            ]
        },
        "Controversial Sourcing": {
            "Controversial Sourcing": [
                "Controversial Sourcing", "GRI 308-2"
            ]
        }
    },
    "Governance": {
        "Board": {
            "Women in the management team": [
                "Women in Leadership", "Gender Balance in Executive Roles", "Gender Diversity in Management", "Women in Management", "GRI 405-1"
            ],
            "Women on the board": [
                "Female Representation in Governance Bodies", "Women’s Representation on the Board", "Gender Diversity on the Board"
            ],
            "Board independence": [
                "Frequency of Independent Board", "Board independence"
            ]
        },
        "Business Ethics": {
            "List of relevant certifications": [
                "ISO 14001", "ISO 45001", "ISO 37001", "ISO 9001", "LEED", "Energy Star", "FSC", "SA8000", "Fair Trade Certification", "B Corp Certification",
                "OHSAS 18001", "AA1000", "SMETA", "CarbonNeutral Certification", "CDP", "Green Seal Certification", "GRI"
            ],
            "Assurance of sustainability report": [
                "PwC", "Deloitte", "EY", "KPMG", "SGS", "Bureau Veritas", "DNV GL"
            ],
            "Anti-corruption disclosures": [
                "Anti-corruption Policies", "Corruption Risk Assessments", "Anti-corruption Training for Employees", "Anti-corruption Procedures"
            ]
        },
        "Tax Transparency": {
            "Tax payments disclosed": [
                "Country-by-Country Tax Reporting", "GRI 207-4", "Total Tax Contributions", "GRI 207-1", "Tax Transparency and Reporting Policies", "GRI 207-2"
            ]
        },
        "Accounting and Audit": {
            "External audit conducted": [
                "External Financial Audit", "GRI 102-56"
            ]
        },
        "Remuneration": {
            "Executive compensation disclosure": [
                "Executive Compensation Structure", "GRI 102-35"
            ]
        }
    }
}

# %%
metrics_info = []
for category, issues in esg_dictionary.items():
    for issue, metrics in issues.items():
        for metric, keywords in metrics.items():
            metrics_info.append({
                "ESG categories": category,
                "Issue": issue,
                "Metric": metric,
                "Keywords": [k.lower() for k in keywords]
            })

# %%
metrics_count = {info["Metric"]: 0 for info in metrics_info}

for filename in os.listdir(pdf_folder_path):
    if filename.endswith(".pdf"):
        pdf_path = os.path.join(pdf_folder_path, filename)
        pdf_document = fitz.open(pdf_path)

        metric_keyword_seen = {info["Metric"]: False for info in metrics_info}

        for info in metrics_info:
            metric = info["Metric"]
            
            for page_num in range(pdf_document.page_count):
                page = pdf_document.load_page(page_num)
                text = page.get_text().lower()

                for keyword in info["Keywords"]:
                    if keyword in text:
                        metric_keyword_seen[metric] = True
                        break
                if metric_keyword_seen[metric]:
                    break
                    
        for metric, seen in metric_keyword_seen.items():
            if seen:
                metrics_count[metric] += 1

# %%
data = []
total_frequency = sum(metrics_count.values())

for info in metrics_info:
    metric = info["Metric"]
    frequency = metrics_count[metric]
    percentage = (frequency / total_frequency * 100) 
    data.append({
        "ESG categories": info["ESG categories"],
        "Issue": info["Issue"],
        "Metric": metric,
        "Frequency": frequency,
        "Percentage (%)": round(percentage, 5)
    })
    

df = pd.DataFrame(data)
# Out:
# Total frequency (sum of all metrics): 806

# %%
df.to_csv("esg_metrics_frequency_with_proportions.csv", index=False)

# %%
print("The result is already saved as esg_metrics_frequency.csv")
# Out:
# The result is already saved as esg_metrics_frequency.csv
