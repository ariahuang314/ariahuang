# %%
import pandas as pd

df = pd.read_excel("dictionary.xlsx")

dic_esg = df.to_dict(orient='records')

# %%
dic_esg
# Out:
# [{'categories': 'Environment',
#   'topic': 'Climate Change',
#   'metric': 'Carbon Emissions',
#   'key': 'Energy and Emissions',
#   'GRI': 'GRI 302-1:Energy consumption within the organization/GRI 302-1:Energy consumption within the organisation'},
#  {'categories': 'Environment',
#   'topic': 'Climate Change',
#   'metric': 'Carbon Emissions',
#   'key': 'Natural gas purchased',
#   'GRI': 'GRI 302-1:Energy consumption within the organization/GRI 302-1:Energy consumption within the organisation'},
#  {'categories': 'Environment',
#   'topic': 'Climate Change',
#   'metric': 'Carbon Emissions',
#   'key': 'Electricity used',
#   'GRI': 'GRI 302-1:Energy consumption within the organization/GRI 302-1:Energy consumption within the organisation'},
#  {'categories': 'Environment',
#   'topic': 'Climate Change',
#   'metric': 'Carbon Emissions',
#   'key': 'Purchased renewable electricity',
# ...
