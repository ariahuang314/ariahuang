# %%
import fitz  # PyMuPDF 用于提取PDF文本
import pandas as pd
import camelot  # 用于表格提取
import re
from transformers import pipeline

def extract_tables_from_pdf(pdf_path):
    # 更改读取 PDF 文件的方式
    tables = camelot.read_pdf(pdf_path, pages='all', flavor='stream')  # 'stream' 适用于有线框的表格
    return tables

# 加载 BERT 模型进行数据抽取
def load_bert_model():
    nlp = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english")
    return nlp

# 使用 BERT 模型提取文本中的数值和单位
def extract_with_bert(text, nlp):
    ner_results = nlp(text)
    entities = []
    for entity in ner_results:
        if entity['entity_group'] == 'MISC':  # BERT 模型识别到的相关实体
            entities.append((entity['word'], entity['score']))
    return entities

# 从PDF中提取文本
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page_num in range(doc.page_count):
        page = doc.load_page(page_num)
        text += page.get_text()
    return text

# 从PDF中提取表格
def extract_tables_from_pdf(pdf_path):
    tables = camelot.read_pdf(pdf_path, pages='all', flavor='stream')  # 'stream' 适用于有线框的表格
    return tables

# 从表格中提取数据
def extract_data_from_tables(tables, dictionary):
    extracted_data = []
    for table in tables:
        df = table.df  # 转换为DataFrame
        for index, row in df.iterrows():
            for keyword in dictionary['key']:
                if keyword in row.to_string():  # 简单的关键词匹配
                    data_row = {
                        'Metric': dictionary[dictionary['key'] == keyword]['metric'].values[0],
                        'Data': extract_number_from_row(row),
                        'Unit': extract_unit_from_row(row),
                        'Confidence': calculate_confidence(row, keyword)
                    }
                    extracted_data.append(data_row)
    return extracted_data

# 提取行中的数值
def extract_number_from_row(row):
    numbers = re.findall(r'\d+\.?\d*', row.to_string())  # 提取所有数字
    return numbers[0] if numbers else None

# 提取行中的单位
def extract_unit_from_row(row):
    units = re.findall(r'(tons|kg|%)', row.to_string())  # 匹配常见的单位
    return units[0] if units else None

# 计算可信度
def calculate_confidence(row, keyword):
    confidence = 0.5  # 基础可信度
    if keyword in row.to_string():
        confidence += 0.3
    if extract_number_from_row(row):
        confidence += 0.2
    return confidence

# %%
# 调用主函数
pdf_path = 'data/Abbott-2022.pdf'
dictionary_path = 'dictionary.xlsx'

# 加载关键词字典
dictionary = pd.read_excel(dictionary_path)

# 加载BERT模型
nlp = load_bert_model()

# 从PDF中提取文本和表格
text = extract_text_from_pdf(pdf_path)
# tables = extract_tables_from_pdf(pdf_path)

# 使用BERT模型从文本中提取数据
bert_entities = extract_with_bert(text, nlp)
print("BERT 提取的实体：", bert_entities)

# 从表格中提取数据
# extracted_table_data = extract_data_from_tables(tables, dictionary)
# print("表格提取结果：", pd.DataFrame(extracted_table_data))

# %% [markdown]
# -------

# %%
import fitz  # PyMuPDF
import re
import pandas as pd

# %%
pdf_path = 'data/GSK-esg-performance-report-2023.pdf'
dictionary_path = 'dictionary.xlsx'

# %%
doc = fitz.open(pdf_path)

# 提取所有文本
text = ""
for page_num in range(doc.page_count):
    page = doc.load_page(page_num)
    text += page.get_text()

# 关闭PDF文件
doc.close()

# 查看提取的文本内容（前500字）
print(text[:500])
# Out:
# GLOBAL
# SUSTAINABILITY
# REPORT 2022
# Sustainability is about operating responsibly
# to deliver long-term impact. At Abbott, we’re
# strengthening the resilience of our company so we
# can continue to shape the future of healthcare —
# to help more people live better, healthier lives.
# In this report, we detail our progress against the
# goals of our 2030 Sustainability Plan. The data
# presented reflects 2022 performance unless
# otherwise stated.
# We have aligned our reporting with the
# requirements of

# %%
# 加载字典
dictionary_df = pd.read_excel(dictionary_path)

# 关键词匹配函数
def keyword_match(text, dictionary_df):
    matched_metrics = []
    for index, row in dictionary_df.iterrows():
        key = row['key']
        if re.search(rf'\b{re.escape(key)}\b', text, re.IGNORECASE):
            matched_metrics.append({
                'category': row['categories'],
                'topic': row['topic'],
                'metric': row['metric'],
                'key': key,
                'GRI': row['GRI']
            })
    return matched_metrics

matched_metrics = keyword_match(text, dictionary_df)
pd.DataFrame(matched_metrics).head()
# Out:
#       category           topic                    metric  \
# 0  Environment  Climate Change          Carbon Emissions
# 1  Environment  Climate Change          Carbon Emissions
# 2  Environment  Climate Change          Carbon Emissions
# 3  Environment  Climate Change          Carbon Emissions
# 4  Environment  Climate Change  Product Carbon Footprint
#
#                     key                                                GRI
# 0  Energy and Emissions  GRI 302-1:Energy consumption within the organi...
# 1                  Coal  GRI 302-1:Energy consumption within the organi...
# 2      Energy intensity                         GRI 302-3:Energy intensity
# 3  Energy and Emissions          GRI 302-4:Reduction of energy consumption
# 4      Waste Management  GRI 306-1:Waste generation and significant was...

# %%
# 数据提取正则表达式
def extract_data(text, metric_keyword):
    pattern = rf'({metric_keyword})[^0-9]*([\d,.]+)\s*(\w+)?'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return {'metric': match.group(1), 'value': match.group(2), 'unit': match.group(3)}
    return None

# 示例提取
for metric in matched_metrics:
    result = extract_data(text, metric['key'])
    if result:
        print(f"metric: {result['metric']}, value: {result['value']}, unit: {result['unit']}")

# %%
def assess_confidence(data):
    confidence = 0
    if data['value']:
        confidence += 0.5
    if data['unit']:
        confidence += 0.5
    return confidence

for metric in matched_metrics:
    result = extract_data(text, metric['key'])
    if result:
        confidence = assess_confidence(result)
        print(f"指标: {result['metric']}, 数据: {result['value']}, 单位: {result['unit']}, 可信度: {confidence}")

# %%
# 将提取结果保存为DataFrame
output_data = []
for metric in matched_metrics:
    result = extract_data(text, metric['key'])
    if result:
        confidence = assess_confidence(result)
        output_data.append({
            'Metric': result['metric'],
            'Value': result['value'],
            'Unit': result['unit'],
            'Confidence': confidence
        })

output_df = pd.DataFrame(output_data)
output_df.to_excel('output_data.xlsx', index=False)

# %% [markdown]
# ---

# %%
from transformers import BertTokenizer, BertForTokenClassification
import torch

# 加载预训练的BERT模型和tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForTokenClassification.from_pretrained('bert-base-uncased')

# Tokenizer处理文本数据
inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
outputs = model(**inputs)

# 解析BERT模型的输出
tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])
print(tokens)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ['[CLS]', 'global', 'sustainability', 'report', '202', '##2', 'sustainability', 'is', 'about', 'operating', 'res', '##pon', '##si', '##bly', 'to', 'deliver', 'long', '-', 'term', 'impact', '.', 'at', 'abbott', ',', 'we', '’', 're', 'strengthening', 'the', 'res', '##ili', '##ence', 'of', 'our', 'company', 'so', 'we', 'can', 'continue', 'to', 'shape', 'the', 'future', 'of', 'healthcare', '—', 'to', 'help', 'more', 'people', 'live', 'better', ',', 'health', '##ier', 'lives', '.', 'in', 'this', 'report', ',', 'we', 'detail', 'our', 'progress', 'against', 'the', 'goals', 'of', 'our', '203', '##0', 'sustainability', 'plan', '.', 'the', 'data', 'presented', 'reflects', '202', '##2', 'performance', 'unless', 'otherwise', 'stated', '.', 'we', 'have', 'aligned', 'our', 'reporting', 'with', 'the', 'requirements', 'of', 'leading', 'environmental', ',', 'social', ',', 'and', 'governance', '(', 'es', '##g', ')', 'ratings', 'and', 'sustainability', 'indices', '(', 'available', 'in', 'the', 'appendix', ')', ',', 'seeking', 'stake', '##holder', 'feedback', 'to', 'drive', 'continuous', 'improvement', '.', 'welcome', 'table', 'of', 'contents', 'about', 'chairman', 'and', 'ceo', 'letter', '03', 'about', 'abbott', '04', 'realizing', 'our', 'purpose', '05', 'our', '203', '##0', 'sustainability', 'plan', '06', 'progress', 'against', 'our', '203', '##0', 'sustainability', 'plan', '07', 'supporting', 'our', 'global', 'communities', '22', 'sustainability', 'governance', '24', 'inn', '##ova', '##te', 'for', 'access', 'and', 'afford', '##ability', '26', 'our', 'approach', 'to', 'access', 'and', 'afford', '##ability', '27', 'access', 'and', 'afford', '##ability', 'through', 'product', 'innovation', '28', 'transforming', 'care', '30', 'advancing', 'health', 'equity', '32', 'res', '##pon', '##si', '##bly', 'connect', 'data', ',', 'technology', ',', 'and', 'care', '34', 'responsible', 'data', 'management', 'and', 'privacy', '35', 'build', 'the', 'diverse', ',', 'innovative', 'workforce', 'of', 'tomorrow', '38', 'our', 'approach', 'to', 'building', 'tomorrow', '’', 's', 'workforce', '39', 'diversity', ',', 'equity', ',', 'and', 'inclusion', '43', 'employee', 'well', '-', 'being', '45', 'financial', 'and', 'retirement', 'benefits', '46', 'employee', 'health', 'and', 'safety', '47', 'human', 'rights', '49', 'protect', 'a', 'healthy', 'environment', '50', 'our', 'approach', 'to', 'a', 'healthy', 'environment', '51', 'energy', 'and', 'emissions', '53', 'protecting', 'water', 'resources', '56', 'waste', 'management', '59', 'packaging', '62', 'responsible', 'sour', '##cing', 'and', 'product', 'steward', '##ship', '63', 'quality', 'management', '64', 'our', 'commitment', 'to', 'quality', '65', 'quality', 'embedded', 'throughout', 'our', 'business', '66', 'create', 'a', 'res', '##ili', '##ent', ',', 'diverse', ',', 'and', 'responsible', 'supply', 'chain', '69', 'supply', 'chain', 'management', '70', 'strengthening', 'the', 'supply', 'chain', '75', 'governance', 'and', 'business', 'ethics', '79', 'corporate', 'governance', 'and', 'board', 'oversight', '80', 'ethics', 'and', 'integrity', '83', 'compliance', '84', 'corruption', 'and', 'anti', '-', 'bribery', '87', 'protecting', 'our', 'people', ',', 'products', ',', 'and', 'brands', '88', 'public', 'policy', 'engagement', '89', 'end', '##notes', '90', 'appendix', '91', 'a', 'caution', 'concerning', 'forward', '-', 'looking', 'statements', ':', 'some', 'statements', 'in', 'this', 'report', 'may', 'be', 'forward', '-', 'looking', 'statements', 'for', 'purposes', 'of', 'the', 'private', 'securities', 'litigation', 'reform', 'act', 'of', '1995', '.', 'abbott', 'caution', '##s', 'that', 'these', 'forward', '-', 'looking', 'statements', 'are', 'subject', 'to', 'risks', 'and', 'uncertain', '##ties', 'that', 'may', 'cause', 'actual', 'results', 'to', 'differ', 'material', '##ly', 'from', 'those', 'indicated', 'in', 'the', 'forward', '-', 'looking', 'statements', '.', 'economic', ',', 'competitive', ',', 'governmental', ',', 'te ...

# %%
def extract_metric_value_with_bert(text, metric):
    # 通过BERT识别指标和数值
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    outputs = model(**inputs)

    # 根据上下文匹配BERT输出，获取数值和单位
    # 这里需要结合具体任务微调模型进行优化
    metric_value = None
    for token, score in zip(tokens, outputs[0][0]):
        if token.lower() == metric.lower():
            metric_value = extract_value_from_context(token, text)
            break
    return metric_value

def extract_value_from_context(metric, text):
    # 简单的正则表达式提取匹配值和单位
    pattern = rf'{metric}[^0-9]*([\d,.]+)\s*(\w+)?'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return {'value': match.group(1), 'unit': match.group(2), 'source': match.group(0)}
    return None

# %%
def assess_confidence_with_bert(result):
    confidence = 0
    if result['value']:
        confidence += 0.5
    if result['unit']:
        confidence += 0.5
    return confidence

# 遍历匹配到的指标，提取数据和单位
for metric in dictionary_df['metric'].unique():
    result = extract_metric_value_with_bert(text, metric)
    if result:
        confidence = assess_confidence_with_bert(result)
        print(f"指标: {metric}, 数据: {result['value']}, 单位: {result['unit']}, 可信度: {confidence}, 来源: {result['source']}")
# Out:
# 指标: Board, 数据: 80, 单位: Ethics, 可信度: 1.0, 来源: Board Oversight
# 80
# Ethics

# %%
import tabula

# 从PDF中提取所有表格
tables = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)

# 显示提取的表格
for table in tables:
    print(table.head())

# 进一步处理表格数据
for table in tables:
    text_table = table.to_string()
    for metric in dictionary_df['metric'].unique():
        result = extract_metric_value_with_bert(text_table, metric)
        if result:
            confidence = assess_confidence_with_bert(result)
            print(f"表格中提取: 指标: {metric}, 数据: {result['value']}, 单位: {result['unit']}, 可信度: {confidence}, 来源: {result['source']}")
# Out:
#   of healthcare. Our 2030 Sustainability Plan  Global Sustainability  \
# 0                                         NaN                   Team
# 1        formalizes our commitment to improve         Leads strategy
# 2    lives; embedding sustainability into our  implementation across
# 3                                         NaN      global operations
# 4    governance structure sets this Plan as a       and oversees ESG
#
#     Sustainability Goal         ESG Disclosures      Global Operations  \
# 0  Leads and Operations               Committee                Council
# 1             Functions             Responsible      Oversees strategy
# 2       Responsible for          for monitoring      execution for all
# 3    managing execution  regulatory, legal, and      operations, using
# 4   and enterprise-wide     financial reporting  internal assessments,
#
#          Global Citizenship
# 0          Advisory Council
# 1      External experts who
# 2       provide guidance on
# 3  strategic sustainability
# 4   issues, including risks
#                             HEALTH EQUIT Y  \
# 0                                      NaN
# 1                                      NaN
# 2  To reach as many people as possible, we
# 3     must remove barriers standing in the
# 4  way of good health. We’re partnering to
#
#             well-being, using biomarkers to identify  \
# 0                        micronutrient deficiencies.
# 1                    •  Fever Panel — In development
# 2  To help identify root causes of fever. Particu...
# 3             important for pregnant women and young
# 4  children, as well as patients with fever-like and
#
#     and five years of age through the donation of
# 0    2,000 MUAC z-score tapes and training of 600
# 1  healthcare professionals and teachers from the
# 2   Cuenca Cantonal Health Council and the Cuenca
# 3    Municipal Foundation for Women and Children.
# 4   A similar donation of tapes and training took
#           • #3 Company for Diversity (listed for  \
# 0                          19 consecutive years)
# 1                                            NaN
# 2  DiversityInc’s Top Companies Specialty Lists:
# 3                        • #1 Supplier Diversity
# 4     • #3 Environmental, Social, and Governance
#
#   E THNIC REPRESENTATION IN U. S . M ANAGEMENT  \
# 0                                    POSITIONS
# 1                               Totals by race
# 2                                    White 65%
# 3                  Underrepresented groups 35%
# 4                                          NaN
#
#      with activities and instruction that aids in
# 0  STEAM (science, technology, engineering, arts,
# 1                   and math) career exploration.
# 2                                             NaN
# 3    The goals and objectives of the STEAM Summer
# 4                     Camp include the following:
#   senior leaders participating in a variety of Abbott-        OHS PERFORMANCE  \
# 0       sponsored events including senior leadership                      NaN
# 1     gatherings, Abbott World Marathons Majors, and    Lost-Time Case Rate18
# 2                        division-level conferences.             Employee and
# 3                                                NaN               Contractor
# 4                                                NaN        Vehicle Accidents
#
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0      2019.0     2020.00     2021.00     2022.00
# 1         NaN         NaN         NaN         NaN
# 2         0.3        0.13        0.13        0.12
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#                        Renewable Energy Procurement  \
# 0                                               NaN
# 1  We continue to explore renewable energy sourcing
# 2      options, increasingly purchasing electricity
# 3       from providers with above-average renewable
# 4       generation in their energy mix. In 2022, we
#
#                                  Unnamed: 0  \
# 0  TRANSPORTATION MODES (% OF GLOBAL SPEND)
# 1                                       NaN
# 2                            2020 2021 2022
# 3                           Air 22% 26% 44%
# 4                                       NaN
#
#               Reuse and Responsible Waste Management
# 0                                                NaN
# 1        We partner with key suppliers to reduce the
# 2  environmental impacts of materials sent to Abbott
# 3         that become waste in our operations and to
# 4  responsibly dispose of waste, including diverting
#   with management to discuss a wide range of               Unnamed: 0  \
# 0                                        NaN         AUDIT COMMIT TEE
# 1                          enterprise risks.                      NaN
# 2                                        NaN   • Accounting, internal
# 3                                        NaN  controls, and financial
# 4                           RISK A SSESSMENT                reporting
#
#             Unnamed: 1             Unnamed: 2                       Unnamed: 3
# 0         COMPENSATION            NOMINATIONS                  PUBLIC P OLIC Y
# 1           COMMIT TEE         AND GOVERNANCE                       COMMIT TEE
# 2                  NaN              COMMITTEE                              NaN
# 3  • Executive officer                    NaN  •  Sustainability, environment,
# 4        compensation,  •  Board composition,        and social responsibility
#   1  Total number of lives improved was adjusted for indirect overlap  \
# 0  between businesses using a binomial probabilit...
# 1  adjusted for direct overlap within a business ...
# 2               available to support the adjustment.
# 3  2  Common rounding convention utilized, see ap...
# 4             3  Data on file, Abbott Diabetes Care.
#
#   circumstances exist justifying the authorization of emergency use  \
# 0  of in vitro diagnostics for detection and/or d...
# 1  with the mpox virus, including in vitro diagno...
# 2  and/or diagnose infection with non-variola Ort...
# 3  Section 564(b)(1) of the Federal Food, Drug, a...
# 4  21 U.S.C. § 360bbb-3(b)(1), unless the declara...
#
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3        25.0
# 4         NaN
#
#   otherwise would have been waste off-site to be used as an effective
# 0  substitute for a commercial product or commodi...
# 1  use material is used as is or in substantially...
# 2                                     was generated.
# 3  Abbott’s diversion rate is calculated as follo...
# 4  Beneficial Use - Landfilled and Incineration w...
#    Unnamed: 0                 PIIS2352-3018(18)30044-4/fulltext.  \
# 0        11.0  Tonen-Wolyec, S. Field evaluation of capillary...
# 1         NaN  fluid HIV self-tests in the Democratic Republi...
# 2         NaN  https://journals.plos.org/plosone/article?id=1...
# 3         NaN                                      pone.0239607.
#
#   and Downstream. Scope 3 estimations may be adjusted annually Unnamed: 1  \
# 0  to account for data availability and methodolo...                   31
# 1  Sourcing category spend allocations are subjec...                   32
# 2  over year in alignment with business strategy....                  NaN
# 3  Scope 3 footprint excludes known sources in Do...                33 34
#
#                                           Unnamed: 2
# 0  Includes China, Europe, India, and Latin America.
# 1  On-site audits may be repeated every three to ...
# 2                                                NaN
# 3  Applies to both full- and part-time employees....
#    2022  $2,888  2022.1  $15.10
# 0  2021  $2,742    2021  $15.00
# 1  2020  $2,420    2020   $7.58
# 2  2019  $2,440    2019   $6.71
# 3  2018  $2,300    2018   $6.58
#        Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0  Small Business     $1,433     $1,897     $2,358      2021.0    113,000
# 1             NaN        NaN        NaN        NaN         NaN        NaN
# 2   Veteran-Owned        $99       $153       $187      2020.0    109,000
#
#   Unnamed: 6 Unnamed: 7
# 0        43%        33%
# 1        NaN        NaN
# 2        42%        32%
#    2022  0.05  2022.1  0.25
# 0  2021  0.10    2021  0.30
# 1  2020  0.06    2020  0.28
# 2  2019  0.07    2019  0.46
# 3  2018  0.20    2018  0.41
#   SCOPE 1 AND 2 CARBON EMISSIONS Unnamed: 0 Unnamed: 1             Unnamed: 2  \
# 0         1,000 Metric Tons CO2e        NaN        NaN  Total (Scope 1 and 2)
# 1                            NaN        NaN        NaN           Market-Based
# 2                      2030 GOAL   -5.2%(f)        NaN  CO2e Emissions(i),(j)
# 3                           2022        NaN   -0.4%(g)                    929
# 4                           2021        NaN        NaN                    933
#
#               Unnamed: 3         Unnamed: 4         Unnamed: 5  \
# 0  Total (Scope 1 and 2)    Purchased Fuels        Refrigerant
# 1         Location-Based          (Scope 1)          (Scope 1)
# 2         CO2e Emissions  CO2e Emissions(k)  CO2e Emissions(l)
# 3                  1,006                516                 14
# 4                  1,013                526                 10
#
#        Unnamed: 6   Purchased Energy Purchased Energy.1
# 0    Total Direct          (Scope 2)          (Scope 2)
# 1       (Scope 1)       Market-Based     Location-Based
# 2  CO2e Emissions  CO2e Emissions(j)  CO2e Emissions(m)
# 3             530                399                476
# 4             536                397                478
#         SCOPE 1 AND 2 CO2e EMISSIONS BY DIVISION  Unnamed: 0  Unnamed: 1  \
# 0  1,000 Metric Tons CO2e – Market-Based Factors         NaN         NaN
# 1                                      2018 2019      2020.0      2021.0
# 2                 Scope 1 and 2 Carbon Emissions         NaN         NaN
# 3                              Corporate 267 272       232.0       250.0
# 4                              Diagnostics 97 97       100.0       110.0
#
#    Unnamed: 2 SCOPE 1 AND 2 CARBON EMISSIONS BY ENERGY SOURCE(n) Unnamed: 3  \
# 0         NaN      1,000 Metric Tons CO2e — Market-Based Factors        NaN
# 1      2022.0                                          2018 2019       2020
# 2         NaN                                 Stationary Sources        NaN
# 3       258.0                  Electricity (Purchased)  439  417        397
# 4       117.0                              Natural Gas  384  375        370
#
#   Unnamed: 4 Unnamed: 5
# 0        NaN        NaN
# 1       2021       2022
# 2        NaN        NaN
# 3        393        395
# 4        387        360
#   2022 SCOPE 3 CARBON EMISSIONS BY CATEGORY(o)  Unnamed: 0 BIOGENIC EMISSIONS  \
# 0                       1,000 Metric Tons CO2e         NaN  1,000 Metric Tons
# 1                                     Upstream         NaN               2022
# 2        1: Purchased Goods and Services 8,146         NaN               2021
# 3                         2: Capital Goods 596         NaN                NaN
# 4                                          NaN         NaN               2020
#
#   Unnamed: 1 Unnamed: 2
# 0        NaN        NaN
# 1        NaN        0.9
# 2        NaN        0.9
# 3        NaN        NaN
# 4        NaN        0.9
#               ENERGY CONSUMPTION Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0               1,000 Gigajoules        NaN        NaN        NaN        NaN
# 1                            NaN       2018       2019       2020       2021
# 2   Purchased Fuels (Scope 1)(k)      9,727      9,747      9,125      9,741
# 3  Purchased Energy (Scope 2)(m)      4,584      4,599      4,651      4,837
# 4          Total (Scope 1 and 2)     14,311     14,346     13,776     14,578
#
#   Unnamed: 4 ENERGY CONSUMPTION INTENSITY — NORMALIZED TO SALES Unnamed: 5  \
# 0        NaN                     Gigajoules per $ Million Sales        NaN
# 1       2022                                     2018 2019 2020       2021
# 2      9,452           Purchased Fuels (Scope 1)(k) 318 306 264        226
# 3      4,743          Purchased Energy (Scope 2)(m) 150 144 134        112
# 4     14,195                 Total (Scope 1 and 2)  468 450 398        338
#
#   Unnamed: 6
# 0        NaN
# 1       2022
# 2        217
# 3        109
# 4        325
#             SCOPE 1 AND 2 CARBON EMISSIONS BY REGION  Unnamed: 0 Unnamed: 1  \
# 0  1,000 Metric Tons CO2e — Market-Based (Corpora...         NaN        NaN
# 1                                          2018 2019      2020.0       2021
# 2                                       Asia Pacific         NaN        NaN
# 3                                        China 30 31        31.0         34
# 4                                        India 34 38        38.0         41
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2022        NaN       2018       2019       2020       2021       2022
# 2        NaN     Europe        NaN        NaN        NaN        NaN        NaN
# 3         28    Belgium         <1         <1         <1         <1         <1
# 4         42    Germany         16         18         13         14         13
#          SCOPE 1 (DIRECT) CARBON EMISSIONS BY REGION Unnamed: 0 Unnamed: 1  \
# 0  1,000 Metric Tons CO2e — Market-Based (Corpora...        NaN        NaN
# 1                                          2018 2019       2020       2021
# 2                                       Asia Pacific        NaN        NaN
# 3                                          China 7 8          7          9
# 4                                        India 15 17         16         18
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2022        NaN       2018       2019       2020       2021       2022
# 2        NaN     Europe        NaN        NaN        NaN        NaN        NaN
# 3          7    Belgium         <1         <1         <1         <1         <1
# 4         19    Germany         11         12         11         12         11
#   SCOPE 2 (PURCHASED ENERGY) CARBON EMISSIONS BY REGION Unnamed: 0 Unnamed: 1  \
# 0  1,000 Metric Tons CO2e — Market-Based (Corpora...           NaN        NaN
# 1                                     2018 2019 2020          2021       2022
# 2                                       Asia Pacific           NaN        NaN
# 3                                     China 23 23 23            25         21
# 4                                     India 19 22 22            23         23
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN       2018       2019       2020       2021       2022
# 2     Europe        NaN        NaN        NaN        NaN        NaN
# 3    Belgium         <1         <1         <1         <1         <1
# 4    Germany          5          6          2          2          2
#   TOTAL ENERGY CONSUMPTION (SCOPE 1 AND 2) BY REGION Unnamed: 0 Unnamed: 1  \
# 0                                   1,000 Gigajoules        NaN        NaN
# 1                                          2018 2019       2020       2021
# 2                                       Asia Pacific        NaN        NaN
# 3                                      China 298 300        303        328
# 4                                      India 374 419        417        456
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2022        NaN       2018       2019       2020       2021       2022
# 2        NaN     Europe        NaN        NaN        NaN        NaN        NaN
# 3        255    Belgium          3          3          3          3          3
# 4        482    Germany        349        343        332        354        343
#   ENERGY CONSUMPTION — PURCHASED FUELS (SCOPE 1) BY REGION Unnamed: 0  \
# 0                                   1,000 Gigajoules              NaN
# 1                                     2018 2019 2020             2021
# 2                                       Asia Pacific              NaN
# 3                                  China 141 141 140              155
# 4                                  India 226 256 255              285
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2022        NaN       2018       2019       2020       2021       2022
# 2        NaN     Europe        NaN        NaN        NaN        NaN        NaN
# 3        106    Belgium          1          1          1          1          2
# 4        298    Germany        240        233        224        243        228
#   ENERGY CONSUMPTION — PURCHASED ENERGY (SCOPE 2) BY REGION  Unnamed: 0  \
# 0                                   1,000 Gigajoules                NaN
# 1                                2018 2019 2020 2021             2022.0
# 2                                       Asia Pacific                NaN
# 3                              China 157 159 163 173              149.0
# 4                              India 149 163 163 171              183.0
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN       2018       2019       2020       2021       2022
# 2     Europe        NaN        NaN        NaN        NaN        NaN
# 3    Belgium          2          2          2          1          1
# 4    Germany        109        110        108        111        116
#   RENEWABLE ENERGY CONSUMPTION BY REGION Unnamed: 0  Unnamed: 1 Unnamed: 2  \
# 0                       1,000 Gigajoules        NaN         NaN        NaN
# 1                                   2018       2019      2020.0       2021
# 2                           Asia Pacific        NaN         NaN        NaN
# 3    Generated On-Site From Renewables 3          3         3.0          4
# 4  Renewables Generated by Third Party -          -         2.0          -
#
#   Unnamed: 3                           Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN                                  NaN        NaN        NaN
# 1       2022                                  NaN       2018       2019
# 2        NaN                               Europe        NaN        NaN
# 3          6    Generated On-Site From Renewables          1          1
# 4          -  Renewables Generated by Third Party        492        496
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN
# 1       2020       2021       2022
# 2        NaN        NaN        NaN
# 3          2          2          3
# 4        558        583        640
#    2022  13,793  2022.1  0.32
# 0  2021  13,823    2021  0.32
# 1  2020  13,284    2020  0.38
# 2  2019  13,402    2019  0.42
# 3  2018  13,479    2018  0.44
#    2022  5,998  2022.1  0.14
# 0  2021  5,904    2021  0.14
# 1  2020  5,697    2020  0.16
# 2  2019  5,731    2019  0.18
# 3  2018  5,967    2018  0.20
#   WATER WITHDRAWAL BY REGION (r) Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                     Megaliters        NaN        NaN        NaN        NaN
# 1                            NaN       2018       2019       2020       2021
# 2                   Asia Pacific        NaN        NaN        NaN        NaN
# 3                          China        356        347        364        378
# 4                          India        520        557        528        585
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2022        NaN       2018       2019       2020       2021
# 2        NaN     Europe        NaN        NaN        NaN        NaN
# 3        344    Belgium         <1          1          1          1
# 4        624    Germany        160        173        187        179
#
#   Unnamed: 10
# 0         NaN
# 1        2022
# 2         NaN
# 3           1
# 4         166
#    2022  90.0%  2022.1   8,145
# 0  2021  87.9%    2021   7,859
# 1  2020  87.7%    2020  10,135
# 2  2019  89.2%    2019   7,586
# 3  2018  86.6%    2018   6,582
#       2022  107,131                             Unnamed: 0 Unnamed: 1  \
# 0     2021  110,301                             Landfilled     17,344
# 1     2020   96,972                                    NaN        NaN
# 2     2019  114,770  Incinerated (Without Energy Recovery)      2,145
# 3  2018(t)   88,729     Incinerated (With Energy Recovery)     11,367
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0     16,731     16,548     18,241     14,540
# 1        NaN        NaN        NaN        NaN
# 2      2,464      2,941      3,637      2,743
# 3     17,061     13,083     13,149     15,647
#       2022 Unnamed: 0  107,131                                   Unnamed: 1  \
# 0     2021        NaN  110,301                            Landfilled 17,344
# 1     2020        NaN   96,972                                          NaN
# 2     2019        NaN  114,770  Incinerated (Without Energy Recovery) 2,145
# 3  2018(t)        NaN   88,729    Incinerated (With Energy Recovery) 11,367
# 4      NaN        NaN      NaN                              Recycled 25,341
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0        NaN     16,731     16,548     18,241     14,540
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN      2,464      2,941      3,637      2,743
# 3        NaN     17,061     13,083     13,149     15,647
# 4        NaN     27,495     28,404     35,106     32,676
#   TOTAL WASTE BY REGION (u) Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0               Metric Tons        NaN        NaN        NaN        NaN
# 1                       NaN       2018       2019       2020       2021
# 2              Asia Pacific        NaN        NaN        NaN        NaN
# 3                     China      2,634      2,678      1,419      1,849
# 4                     India      1,968      2,297      2,548      3,386
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2022        NaN       2018       2019       2020       2021
# 2        NaN     Europe        NaN        NaN        NaN        NaN
# 3      1,708    Belgium        346        392        295        297
# 4      3,099    Germany      2,794      3,152      3,019      3,043
#
#   Unnamed: 10
# 0         NaN
# 1        2022
# 2         NaN
# 3         321
# 4       3,022
#   HAZARDOUS WASTE BY REGION (u) Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                   Metric Tons        NaN        NaN        NaN        NaN
# 1                           NaN       2018       2019       2020       2021
# 2                  Asia Pacific        NaN        NaN        NaN        NaN
# 3                         China         62         75        130        216
# 4                         India        270        445        479        665
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2022        NaN       2018       2019       2020       2021
# 2        NaN     Europe        NaN        NaN        NaN        NaN
# 3        217    Belgium          2         13         10         15
# 4        716    Germany        670        708        632        505
#
#   Unnamed: 10
# 0         NaN
# 1        2022
# 2         NaN
# 3          12
# 4         536
#   NONHAZARDOUS WASTE BY REGION (u) Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                      Metric Tons        NaN        NaN        NaN
# 1                              NaN       2018       2019       2020
# 2                     Asia Pacific        NaN        NaN        NaN
# 3                            China      2,572      2,603      1,289
# 4                            India      1,698      1,852      2,070
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2021       2022        NaN       2018       2019       2020
# 2        NaN        NaN     Europe        NaN        NaN        NaN
# 3      1,633      1,490    Belgium        344        380        285
# 4      2,721      2,383    Germany      2,124      2,444      2,387
#
#   Unnamed: 9 Unnamed: 10
# 0        NaN         NaN
# 1       2021        2022
# 2        NaN         NaN
# 3        282         309
# 4      2,538       2,486
#                  EHS FINES Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0             U.S. Dollars        NaN        NaN        NaN         NaN
# 1                      NaN    2018(h)       2019       2020      2021.0
# 2      Environmental Fines          0     16,700          0         0.0
# 3  Health and Safety Fines      3,000          0      1,200         0.0
# 4          Total EHS Fines      3,000     16,700      1,200         0.0
#
#   Unnamed: 4
# 0        NaN
# 1       2022
# 2          0
# 3     14,694
# 4     14,694
#           GRI STANDARD          GRI DISCLOSURE  \
# 0  General Disclosures                     NaN
# 1                  NaN                     NaN
# 2           GRI 2: 2-1  Organizational details
# 3              General                     NaN
# 4          Disclosures                     NaN
#
#                                         LOCATION GRI STANDARD.1  \
# 0                                            NaN    GRI 2: 2-12
# 1                                            NaN        General
# 2                    www.abbott.com/contact.html    Disclosures
# 3  www.abbott.com/global-locations-contacts.html           2021
# 4                                            NaN            NaN
#
#                  GRI DISCLOSURE.1  \
# 0  Role of the highest governance
# 1          body in overseeing the
# 2           management of impacts
# 3                             NaN
# 4                             NaN
#
#                                           LOCATION.1
# 0                  Appendix, ESG Priorities, page 93
# 1                                                NaN
# 2          Appendix, Stakeholder Engagement, page 94
# 3  Corporate Governance and Board Oversight, page 80
# 4                                                NaN
#   GRI STANDARD   GRI DISCLOSURE  \
# 0        303-4  Water discharge
# 1          NaN              NaN
# 2          NaN              NaN
# 3          NaN              NaN
# 4          NaN              NaN
#
#                                             LOCATION GRI STANDARD.1  \
# 0                Protecting Water Resources, page 56          305-7
# 1                        CDP Water Response: page 4*            NaN
# 2                                                NaN            NaN
# 3  Appendix, Key Environmental Metrics — Water, p...            NaN
# 4                                                NaN            NaN
#
#                       GRI DISCLOSURE.1                             LOCATION.1
# 0        Nitrogen oxides (NOx), sulfur          Energy and Emissions, page 53
# 1  oxides (SOx), and other significant  Appendix, Key Environmental Metrics —
# 2                        air emissions                                    NaN
# 3                                  NaN          Energy and Emissions, page 98
# 4                                  NaN  CDP Climate Change Response (C.7.1a)*
#    GRI STANDARD GRI DISCLOSURE  Unnamed: 0  \
# 0  403-9 Work-related injuries         NaN
# 1                          NaN         NaN
# 2                          NaN         NaN
# 3                          NaN         NaN
# 4                          NaN         NaN
#
#                                             LOCATION  \
# 0                Employee Health and Safety, page 47
# 1                       Employee Well-Being, page 45
# 2  Our 2022 lost-time case rate target was 0.12 p...
# 3     which includes employees and contract workers.
# 4                                                NaN
#
#               GRI STANDARD GRI DISCLOSURE.1  Unnamed: 1  \
# 0           Diversity and Equal Opportunity         NaN
# 1  GRI 3: 3-3 Management of Material Topics         NaN
# 2                                  Material         NaN
# 3                               Topics 2021         NaN
# 4                                       NaN         NaN
#
#                                   LOCATION.1
# 0                                        NaN
# 1          Appendix, ESG Priorities, page 93
# 2  Diversity, Equity, and Inclusion, page 43
# 3                                        NaN
# 4                 Supplier Diversity Program
#                               METRIC 2022 DISCLOSURE  \
# 0                                                NaN
# 1              Medical Equipment & Supplies Standard
# 2                          Affordability and Pricing
# 3  HC-MS-240a.1: Ratio of Year Total Abbott Net S...
# 4      weighted average rate of net (year-on-year %)
#
#                      Unnamed: 0  Unnamed: 1                      Unnamed: 2  \
# 0                           NaN         NaN                             NaN
# 1                           NaN         NaN                             NaN
# 2                           NaN         NaN                  Product Safety
# 3  Global Consumer Price Index1         NaN            HC-MS-250a.1: Number
# 4              (year-on-year %)         NaN  of recalls issued, total units
#
#   group purchasing organizations, wholesalers, individual healthcare providers, and consumers.
# 0  We maintain pricing flexibility to meet the ne...
# 1  to help ensure that our essential healthcare p...
# 2                                                NaN
# 3                                                NaN
# 4                           FDA Class I and Class II
# 表格中提取: 指标: Board, 数据: 16, 单位: and, 可信度: 1.0, 来源: Board for Engineering                                                                                                       above and beyond government requirements.         NaN                                                                Wiesbaden, Germany.
# 16                                                                                                                                                                                                                                                                                                                 and
# 表格中提取: 指标: Board, 数据: 1,873, 单位: 2, 可信度: 1.0, 来源: board          1,873       2
# 表格中提取: 指标: Board, 数据: 80, 单位: 4, 可信度: 1.0, 来源: Board Oversight, page 80
# 4
# 表格中提取: 指标: Board, 数据: 20, 单位: None, 可信度: 0.5, 来源: Board Oversight, pages 20

# %%
# 保存最终结果到Excel
output_data = []
for metric in dictionary_df['metric'].unique():
    result = extract_metric_value_with_bert(text, metric)
    if result:
        confidence = assess_confidence_with_bert(result)
        output_data.append({
            'Metric': metric,
            'Value': result['value'],
            'Unit': result['unit'],
            'Confidence': confidence,
            'Source': result['source']
        })

output_df = pd.DataFrame(output_data)
output_df.to_excel('extracted_esg_data.xlsx', index=False)
