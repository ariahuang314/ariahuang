# %%
import re
import pandas as pd
import fitz 
from transformers import BertTokenizer, BertForTokenClassification

# %%
pdf_path = 'data/GSK-esg-performance-report-2023.pdf'
dictionary_path = 'dictionary.xlsx'

# 加载ESG指标字典
dictionary_df = pd.read_excel('dictionary.xlsx')  # 加载你提供的ESG字典文件

# %%
import pdfplumber

def extract_text_from_pdf(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text()
    return text

text = extract_text_from_pdf(pdf_path)

# %%
# def extract_text_from_pdf(pdf_path):
#     doc = fitz.open(pdf_path)  # 打开PDF文件
#     text = ""
#     for page_num in range(doc.page_count):
#         page = doc.load_page(page_num)  # 加载每一页
#         text += page.get_text()  # 提取每一页的文本
#     doc.close()  # 关闭PDF文件
#     return text

# %%
# 加载BERT模型和tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForTokenClassification.from_pretrained('bert-base-uncased')

# 函数：使用BERT模型提取指标和对应的数值及单位
def extract_metric_value_with_bert(text, metric):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    outputs = model(**inputs)

    # 使用BERT模型的输出匹配指标和数值
    tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])
    for token in tokens:
        if metric.lower() in token.lower():
            return extract_value_from_context(metric, text)
    return None

# 函数：从文本上下文中提取数值和单位
def extract_value_from_context(metric, text):
    pattern = rf'{metric}[^0-9]*([\d,.]+)\s*(\w+)?'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return {'value': match.group(1), 'unit': match.group(2), 'source': match.group(0)}
    return None

# 可信度评估
def assess_confidence_with_bert(result):
    confidence = 0
    if result['value']:
        confidence += 0.5
    if result['unit']:
        confidence += 0.5
    return confidence
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import tabula

# 从PDF文件中提取表格数据
tables = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)

# 显示提取的表格
for table in tables:
    print(table.head())

# 处理表格数据
for table in tables:
    text_table = table.to_string()
    for metric in dictionary_df['metric'].unique():
        result = extract_metric_value_with_bert(text_table, metric)
        if result:
            confidence = assess_confidence_with_bert(result)
            print(f"表格中提取: 指标: {metric}, 数据: {result['value']}, 单位: {result['unit']}, 可信度: {confidence}, 来源: {result['source']}")
# Out:
#   Our ESG focus areas    Our six commitments  \
# 0              Access      Make our products
# 1                 NaN    available at value-
# 2                 NaN  based prices that are
# 3                 NaN    sustainable for our
# 4                 NaN           business and
#
#                            Our metrics for 2023  \
# 0  – Progress towards our 2030 goal of reaching
# 1  1.3 billion people in lower income countries
# 2                             with our products
# 3                                           NaN
# 4                                           NaN
#
#                         Our progress in 2023
# 0      In 2023, we reached 89 million people
# 1  with our vaccines and antiretrovirals and
# 2     made 989 million doses of our products
# 3        available in lower income countries
# 4                                        NaN
#                   Unnamed: 0 2020 2021 2022 2023 Unnamed: 1 Unnamed: 2
# 0       Community investment  NaN  NaN  NaN  NaN        NaN        NaN
# 1                  Cash (£m)   91   83   79   80        NaN          A
# 2  Product and in-kind (£m)1  136  159  209  198        NaN          A
# 3                  Time (£m)  0.1  0.2  0.6    3        NaN          A
# 4      Management costs (£m)   18   17   19   23        NaN          A
#                                           Unnamed: 0 2020   2021    2022 2023  \
# 0  People reached through our healthcare access p...  NaN    NaN     NaN  NaN
# 1  People accessing a healthcare service, worker ...  400  438.0    91.0  103
# 2                           Save the Children ('000)  NaN    NaN     NaN  NaN
# 3  People accessing a healthcare worker, service ...    –  162.0  1061.0   –2
# 4                    CEO Roundtable programme ('000)  NaN    NaN     NaN  NaN
#
#   Unnamed: 1
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#                                   Unnamed: 0   2020   2021   2022   2023  \
# 0                                     Energy    NaN    NaN    NaN    NaN
# 1                Natural gas purchased (GWh)  1,873  1,744  1,655  1,567
# 2                     Electricity used (GWh)  1,102  1,008    970    958
# 3      Purchased renewable electricity (GWh)    487    631    697    782
# 4  Purchased non-renewable electricity (GWh)    605    372    263    163
#
#   Unnamed: 1 Unnamed: 2
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN          A
# 4        NaN        NaN
#                                           Unnamed: 0   2020   2021   2022  \
# 0    Use of sold products (thousands of tonnes CO2e)  5,836  5,120  5,523
# 1  – Emissions from use of propellant-based inhal...  5,631  5,039  5,429
# 2             End of life (thousands of tonnes CO2e)     24     51     47
# 3  Leased assets (downstream) (thousands of tonne...      0      0      –
# 4              Franchises (thousands of tonnes CO2e)      0      0      –
#
#     2023 Unnamed: 1
# 0      –        NaN
# 1  5,039          A
# 2      –        NaN
# 3      –        NaN
# 4      –        NaN
#                                           Unnamed: 0  2020  2021  2022  2023  \
# 0                               Waste and materials1   NaN   NaN   NaN   NaN
# 1  Total waste recovered via a circular route (th...     –  21.9  21.8  26.2
# 2  Total waste disposed via a non-circular route ...     –  33.9  28.5  23.5
# 3  Total waste and materials generated (thousand ...  63.0  55.8  50.3  49.7
# 4                                   % circular waste     –   39%   43%   53%
#
#   Unnamed: 1
# 0        NaN
# 1        NaN
# 2        NaN
# 3         PR
# 4        NaN
#                    Unnamed: 0 2020 2021 2022 2023 Unnamed: 1 Unnamed: 2
# 0           Gender diversity1  NaN  NaN  NaN  NaN        NaN        NaN
# 1  % of women (all employees)  47%  47%  47%  48%        NaN          A
# 2                SVP/VP level  38%  40%  42%  45%         PR          A
# 3              Director level  46%  48%  49%  50%        NaN          A
# 4               Manager level  50%  50%  51%  51%        NaN          A
#   Unnamed: 0       Unnamed: 1 Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 0         –2     0.4%0.4%0.3%       0.3%     0.3%0.4%0.3%       0.2%
# 1      18.8%  13.8%14.7%16.2%      16.8%  15.9%16.7%17.8%      18.4%
# 2       8.1%     5.5%5.2%6.0%       6.5%     6.3%7.1%7.9%       7.8%
# 3       6.4%     4.5%4.5%4.5%       4.9%     5.1%5.4%4.4%       4.9%
# 4         –2     0.3%0.3%0.2%       0.2%       0.1%0.1%–2       0.1%
#
#         Unnamed: 5 Unnamed: 6
# 0     0.4%0.4%0.3%       0.3%
# 1  12.9%13.7%14.9%      15.7%
# 2    9.9%9.8%10.4%      11.0%
# 3     5.1%5.3%5.3%       5.8%
# 4     0.2%0.2%0.2%       0.2%
#                                           Unnamed: 0   2020   2021   2022  \
# 0                                   Ethical conduct1    NaN    NaN    NaN
# 1  Employees who had concerns raised against them...  2,105  2,534  2,191
# 2                                        open cases)    NaN    NaN    NaN
# 3        Employees disciplined for policy violations    553    910    850
# 4            Breakdown of types of policy violation2    NaN    NaN    NaN
#
#     2023 Unnamed: 1 Unnamed: 2
# 0    NaN        NaN        NaN
# 1  1,960        NaN          A
# 2    NaN        NaN        NaN
# 3    798        NaN          A
# 4    NaN        NaN        NaN
#                        Unnamed: 0 2020 2021   2022 2023
# 0        Supplier spend by region  NaN  NaN    NaN  NaN
# 1                    Asia-Pacific    –    –   8.6%   8%
# 2  Europe, Middle East and Africa    –    –  58.5%  55%
# 3                   Latin America    –    –   1.5%   2%
# 4                   North America    –    –  31.3%  35%
#                                           Unnamed: 0   2020   2021    2022  \
# 0                  Regulatory inspections and audits    NaN    NaN     NaN
# 1     Audits of our third parties’ quality processes  1,451  1,044  1,0891
# 2  Total regulatory inspections from all health a...     86    111     122
# 3  % of inspections from all regulators with no c...   100%   100%     99%
# 4  Total regulatory inspections from FDA/MHRA/EMA...     27     35      36
#
#     2023 Unnamed: 1 Unnamed: 2
# 0    NaN        NaN        NaN
# 1  1,081        NaN        NaN
# 2    114         PR          A
# 3   100%         PR          A
# 4     32         PR          A
#                                    Unnamed: 0 2020 2021 2022 2023 Unnamed: 1  \
# 0  FDA product recalls by business and class1  NaN  NaN  NaN  NaN        NaN
# 1                    Pharmaceuticals business  NaN  NaN  NaN  NaN        NaN
# 2                     Class I product recalls    0    0    0    0         PR
# 3                    Class II product recalls    0    0    0    0         PR
# 4                   Class III product recalls    0    0    1    1        NaN
#
#   Unnamed: 2
# 0        NaN
# 1        NaN
# 2          A
# 3          A
# 4          A
#                                           Unnamed: 0   2020    2021    2022  \
# 0                                             Hiring    NaN     NaN     NaN
# 1                          Total number of new hires  9,305  11,110  12,513
# 2  % of open positions filled by internal candidates  30.0%   34.0%   31.4%
# 3                                  Employee turnover    NaN     NaN     NaN
# 4                                   Overall turnover  10.3%   15.2%   13.3%
#
#      2023 Unnamed: 1
# 0     NaN        NaN
# 1  10,730        NaN
# 2   29.9%        NaN
# 3     NaN        NaN
# 4   10.0%          A
#                                           Unnamed: 0   2020   2021   2022  \
# 0                                  Health and safety    NaN    NaN    NaN
# 1  Number of fatalities (employees and complement...    1.0    0.0    0.0
# 2  Number of fatalities (contractors not under GS...    1.0    0.0    0.0
# 3                 Reportable injuries with lost time  137.0  133.0  144.0
# 4                Reportable illnesses with lost time    8.0    5.0    8.0
#
#     2023 Unnamed: 1
# 0    NaN        NaN
# 1    0.0          A
# 2    0.0          A
# 3  195.0          A
# 4  301.0          A
#                            GRI indicator Description  Unnamed: 0  \
# 0                                       Biodiversity         NaN
# 1                  3-3 Management of material topics         NaN
# 2  304-1 Operational sites owned, leased, managed...         NaN
# 3  protected areas and areas of high biodiversity...         NaN
# 4                                    protected areas         NaN
#
#                        Where to find the information
# 0                                                NaN
# 1  Materiality assessment, ESG Performance Report...
# 2                       Annual Report, TNFD, page 71
# 3                                                NaN
# 4                                                NaN
#   Unnamed: 0                        Type, form and presentation  \
# 0   Vaccines                                                NaN
# 1    Engerix  Hepatitis B – Liquid: ready to use vial (one d...
# 2    Engerix  Hepatitis B – Liquid: ready to use vial (10 do...
# 3    Engerix  Hepatitis B – Liquid: ready to use vial (20 do...
# 4    Priorix  Measles, Mumps and Rubella – Lyophilised activ...
#
#    Date of prequalification
# 0                       NaN
# 1  Thursday, 1 January 1987
# 2  Thursday, 1 January 1987
# 3  Thursday, 1 January 1987
# 4      Friday, 9 March 2001
#   Independent Limited Assurance Report\rto the Directors of GSK plc\rDNV Business Assurance Services UK Limited (“DNV”, “us” or “we”) were commissioned by GSK Services Unlimited to provide limited\rassurance to GSK plc (“GSK”) over Selected Information presented in the ESG Performance Report 2023 (the “Report”) for the reporting year\rended 31 December 2023.\rOur Conclusion: On the basis of the work undertaken, nothing came to our attention to suggest\rthat the Selected Information is not fairly stated and has not been prepared, in all material\rrespects, in accordance with the Criteria.\rThis conclusion relates only to the Selected Information, and is to be read in the context of this\rIndependent Limited Assurance Report, in particular the inherent limitations explained overleaf.\rOur observations and areas for improvement will be raised in a separate report to GSK’s Management. These observations do\rnot affect our conclusion set out above.\rSelected Information\rThe scope and boundary of our work is restricted to the metrics included within the Report for the current reporting year (the “Selected\rInformation”), listed below and in the Appendix:\r•The Environmental Social and Governance (ESG) performance data listed in the Appendix of this document.\r•\rThe overall 2023 ESG Performance Rating score of “on track” relating to GSK’s performance against the 2023 Performance Rating metrics\rlisted on pages 6 and 7 of the Report.\rTo assess the Selected Information, which includes an assessment of the risk of material misstatement in the Report, we have used GSK’s ESG\rData Collection Process and Controls Documents which are summarised in the ESG reporting criteria (the “Criteria”), which can be found from\rpages 47 to 54 of the Report.\rWe have not performed any work, and do not express any conclusion, on any other information that may be published in the Report or on\rGSK’s website for the current reporting period or for previous periods.\rStandard and level of assurance\rWe performed a limited assurance engagement of specified data and information usingOur competence, independence\rDNV’s assurance methodology VerisustainTM, which is based on our professionaland quality control\rexperience and international assurance best practice including the International\rStandard on Assurance Engagements (ISAE) 3000 – ‘Assurance Engagements other thanDNV established policies and procedures are\rAudits and Reviews of Historical Financial Information’ (revised) issued by thedesigned to ensure that DNV, its personnel\rInternational Auditing and Assurance Standards Board. This methodology ensuresand, where applicable, others are subject to\rindependence requirements (including compliance with ethical requirements and mandates planning and execution of the\rpersonnel of other entities of DNV) and\rassurance engagement to obtain a limited level of assurance.\rmaintain independence where required by\rrelevant ethical requirements. This\rDNV applies its own management standards and compliance policies for quality control,\rengagement work was carried out by an\rwhich are based on the principles enclosed within ISO IEC 17029:2019 - Conformityindependent team of sustainability\rAssessment - General principles and requirements for validation and verification bodies,assurance professionals. DNV did not\rand accordingly maintains a comprehensive system of quality control includingprovide any services to GSK in 2023 that\rcould compromise the independence or documented policies and procedures regarding compliance with ethical requirements,\rimpartiality of our work. Our multi-\rprofessional standards, and applicable legal and regulatory requirements.\rdisciplinary team consisted of professionals\rwith a combination of environmental and\rThe procedures performed in a limited assurance engagement vary in nature and are\rsustainability assurance experience.\rshorter in extent than for a reasonable assurance engagement. Consequently, the level of\rassuranc ...
# 0  Our competence, independence\rand quality control                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 1  DNV established policies and procedures are\rd...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 2                                                NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
#   Independent Limited Assurance Report\rto the Directors of GSK plc\rDNV Business Assurance Services UK Limited (“DNV”, “us” or “we”) were commissioned by GSK Services Unlimited to provide limited\rassurance to GSK plc (“GSK”) over Selected Information presented in the ESG Performance Report 2023 (the “Report”) for the reporting year\rended 31 December 2023.\rOur Conclusion: On the basis of the work undertaken, nothing came to our attention to suggest\rthat the Selected Information is not fairly stated and has not been prepared, in all material\rrespects, in accordance with the Criteria.\rThis conclusion relates only to the Selected Information, and is to be read in the context of this\rIndependent Limited Assurance Report, in particular the inherent limitations explained overleaf.\rOur observations and areas for improvement will be raised in a separate report to GSK’s Management. These observations do\rnot affect our conclusion set out above.\rSelected Information\rThe scope and boundary of our work is restricted to the metrics included within the Report for the current reporting year (the “Selected\rInformation”), listed below and in the Appendix:\r•The Environmental Social and Governance (ESG) performance data listed in the Appendix of this document.\r•\rThe overall 2023 ESG Performance Rating score of “on track” relating to GSK’s performance against the 2023 Performance Rating metrics\rlisted on pages 6 and 7 of the Report.\rTo assess the Selected Information, which includes an assessment of the risk of material misstatement in the Report, we have used GSK’s ESG\rData Collection Process and Controls Documents which are summarised in the ESG reporting criteria (the “Criteria”), which can be found from\rpages 47 to 54 of the Report.\rWe have not performed any work, and do not express any conclusion, on any other information that may be published in the Report or on\rGSK’s website for the current reporting period or for previous periods.\rStandard and level of assurance\rWe performed a limited assurance engagement of specified data and information usingOur competence, independence\rDNV’s assurance methodology VerisustainTM, which is based on our professionaland quality control\rexperience and international assurance best practice including the International\rStandard on Assurance Engagements (ISAE) 3000 – ‘Assurance Engagements other thanDNV established policies and procedures are\rAudits and Reviews of Historical Financial Information’ (revised) issued by thedesigned to ensure that DNV, its personnel\rInternational Auditing and Assurance Standards Board. This methodology ensuresand, where applicable, others are subject to\rindependence requirements (including compliance with ethical requirements and mandates planning and execution of the\rpersonnel of other entities of DNV) and\rassurance engagement to obtain a limited level of assurance.\rmaintain independence where required by\rrelevant ethical requirements. This\rDNV applies its own management standards and compliance policies for quality control,\rengagement work was carried out by an\rwhich are based on the principles enclosed within ISO IEC 17029:2019 - Conformityindependent team of sustainability\rAssessment - General principles and requirements for validation and verification bodies,assurance professionals. DNV did not\rand accordingly maintains a comprehensive system of quality control includingprovide any services to GSK in 2023 that\rcould compromise the independence or documented policies and procedures regarding compliance with ethical requirements,\rimpartiality of our work. Our multi-\rprofessional standards, and applicable legal and regulatory requirements.\rdisciplinary team consisted of professionals\rwith a combination of environmental and\rThe procedures performed in a limited assurance engagement vary in nature and are\rsustainability assurance experience.\rshorter in extent than for a reasonable assurance engagement. Consequently, the level of\rassuranc ...
# 0                                                NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 1                                                NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 2                                                NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 3                                                NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# ...
# 2                           - Employee conduct\r304#
# 3                        - Sales and marketing\r122#
# 4                             - Product quality\r76#
#
#        Unnamed: 0 Unnamed: 1
# 0  Reported value       Unit
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
#    Appendix: Selected Information continued\rESG Performance data\rReported valueUnit\rBreakdown of types of policy violation:\r- Employee conduct\r304#\r- Sales and marketing\r122#\r- Product quality\r76#\r- Safeguarding people and information and assets\r177#\r- Employee relations\r99#\r- Research and development and medical practices\r7#\r- Anti-bribery and corruption\r39#\r- Cyber security\r24#\r- EHS and sustainability\r64#\r- Other\r4#\rEmployees who were dismissed or agreed to leave the company voluntarily as a result of misconduct\r256#\rDocumented warnings\r553#\rOpen cases awaiting investigation or a disciplinary decision at year end\r297#\r% of employees and complementary workers that complete GSK’s mandatory training100%\r% of employees who believe they ‘can and do Speak Up if things don't feel right’83%\r% of direct high-risk suppliers that achieve GSK’s minimum EcoVadis score or have an improvement plan in place89%\rProduct governance\rTotal regulatory inspections from all health authorities114#\r% of inspections from all regulators with no critical findings or official action indicated100%\rTotal regulatory inspections from FDA/MHRA/EMA regulators32#\rNumber of critical/major findings from FDA/MHRA/EMA regulators11#\rTotal FDA regulatory inspections5#\rNumber of FDA observations8#\rNumber of FDA warning letters0#\rTotal product recalls16#\r- Total number of Class I external product recalls2#\r- Total number of Class II external product recalls3#\r- Total number of Class III external product recalls11#\rPharmaceuticals business - Class product I recalls0#\rPharmaceuticals business - Class product II recalls0#\rPharmaceuticals business - Class product III recalls1#\rVaccines business - Class product I recalls1#\rVaccines business - Class product II recalls0#\rVaccines business - Class product III recalls1#\rPublicly available trial protocol summaries (register)103#\rPublicly available trial result summaries (disclose)98#\rPeople disclosures\rOverall turnover10%\rNumber of fatalities (employees and complementary workers under GSK direct supervision)0#\rFatalities (contractors not under GSK direct supervision)0#\rReportable injuries with lost time195#\rReportable illnesses with lost time30#\rLost time reportable injury rate0.13\rper 100,000 hours worked\rLost time reportable illness rate0.02\rper 100,000 hours worked\rReportable injuries with and without lost time292#\rReportable illnesses with and without lost time65#\rReportable injury rate0.19per 100,000 hours worked\rReportable illness rate0.04per 100,000 hours worked\rReportable injury and illness rate0.24per 100,000 hours worked\rHours worked151m
# 0                                                NaN
#                                           Unnamed: 0 Selected Information  \
# 0           Scope 1 emissions (thousand tonnes CO2e)                  581
# 1  Scope 2 emissions – Market Based – (thousand t...                   64
# 2  Scope 2 emissions – Location Based – (thousand...                  240
# 3  Total scope 1 and 2 market-based emissions (th...                  645
# 4                  Total energy for operations (GWh)                2,636
#
#    Unnamed: 1  Unnamed: 2  ssured Value  Unnamed: 3
# 0         NaN         NaN           NaN         NaN
# 1         NaN         NaN           NaN         NaN
# 2         NaN         NaN           NaN         NaN
# 3         NaN         NaN           NaN         NaN
# 4         NaN         NaN           NaN         NaN
#      •  \
# 0  NaN
# 1    •
#
#   Performed analytical review procedures and considered the risks of material misstatement of the
# 0                              Selected Information.
# 1  Through inquiries of management, obtained an u...
# 表格中提取: 指标: Board, 数据: 42, 单位: None, 可信度: 0.5, 来源: Board  42

# %%
# 遍历字典中的指标并提取数据
output_data = []
for metric in dictionary_df['metric'].unique():
    result = extract_metric_value_with_bert(text, metric)
    if result:
        confidence = assess_confidence_with_bert(result)
        output_data.append({
            'Metric': metric,
            'Value': result['value'],
            'Unit': result['unit'],
            'Confidence': confidence,
            'Source': result['source']
        })

# 将提取的数据输出为DataFrame并保存为Excel
output_df = pd.DataFrame(output_data)
output_df.to_csv('extracted_esg_data.csv', index=False)

# %%
import fitz  # PyMuPDF 用于处理 PDF
import re
import pandas as pd
from transformers import BertTokenizer, BertForTokenClassification

# 加载BERT模型和tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForTokenClassification.from_pretrained('bert-base-uncased')

# 函数：从PDF文件中提取所有文本
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)  # 打开PDF文件
    text = ""
    for page_num in range(doc.page_count):
        page = doc.load_page(page_num)  # 加载每一页
        text += page.get_text()  # 提取每一页的文本
    doc.close()  # 关闭PDF文件
    return text

# 函数：使用BERT模型提取指标和对应的数值及单位
def extract_metric_value_with_bert(text, metric):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    outputs = model(**inputs)

    # 使用BERT模型的输出匹配指标和数值
    tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])
    for token in tokens:
        if metric.lower() in token.lower():
            return extract_value_from_context(metric, text)
    return None

# 函数：从文本上下文中提取数值和单位
def extract_value_from_context(metric, text):
    pattern = rf'{metric}[^0-9]*([\d,.]+)\s*(\w+)?'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return {'value': match.group(1), 'unit': match.group(2), 'source': match.group(0)}
    return None

# 可信度评估
def assess_confidence_with_bert(result):
    confidence = 0
    if result['value']:
        confidence += 0.5
    if result['unit']:
        confidence += 0.5
    return confidence

# 提取PDF中的文本
pdf_path = 'path_to_your_pdf_file.pdf'  # 替换为你的PDF文件路径
text = extract_text_from_pdf(pdf_path)

# 加载ESG指标字典
dictionary_df = pd.read_excel('dictionary.xlsx')  # 加载你提供的ESG字典文件

# 遍历字典中的指标并提取数据
output_data = []
for metric in dictionary_df['metric'].unique():
    result = extract_metric_value_with_bert(text, metric)
    if result:
        confidence = assess_confidence_with_bert(result)
        output_data.append({
            'Metric': metric,
            'Value': result['value'],
            'Unit': result['unit'],
            'Confidence': confidence,
            'Source': result['source']
        })

# 将提取的数据输出为DataFrame并保存为Excel
output_df = pd.DataFrame(output_data)
output_df.to_excel('extracted_esg_data.xlsx', index=False)
