# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
import geopandas as gpd

# %%
world = gpd.read_file("../data/wk11_worldmap.geojson")
cities = gpd.read_file("../data/wk11_cities.geojson")
cities
# Out:
#             City         Country  Latitude  Longitude              geometry
# 0          Tokyo           Japan     35.68     139.69  POINT (139.69 35.68)
# 1  New York City   United States     40.71     -74.01  POINT (-74.01 40.71)
# 2         London  United Kingdom     51.51      -0.13   POINT (-0.13 51.51)
# 3      Singapore       Singapore      1.35     103.82   POINT (103.82 1.35)
# 4        Beijing           China     39.90     116.40    POINT (116.4 39.9)

# %%
singapore = cities[cities["Country"] == "Singapore"]

# %%
fig, ax = plt.subplots(frameon=False)
world.plot(color = "white", edgecolor = "lightgray", ax = ax, legend = False)
singapore.plot(color = "palegreen", marker = "o", markersize = 30, ax = ax)
us.plot(color="lightgreen", ax=ax)
china.plot(color="lightgreen", ax=ax)
ax.set_axis_off()
plt.show()
