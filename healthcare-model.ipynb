# %%
# !pip install tika
# Out:
# Requirement already satisfied: tika in /Users/martinchen/anaconda3/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: setuptools in /Users/martinchen/anaconda3/lib/python3.11/site-packages (from tika) (68.0.0)
# Requirement already satisfied: requests in /Users/martinchen/anaconda3/lib/python3.11/site-packages (from tika) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/martinchen/anaconda3/lib/python3.11/site-packages (from requests->tika) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/martinchen/anaconda3/lib/python3.11/site-packages (from requests->tika) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/martinchen/anaconda3/lib/python3.11/site-packages (from requests->tika) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/martinchen/anaconda3/lib/python3.11/site-packages (from requests->tika) (2023.7.22)

# %%
# !pip install ace-tools
# Out:
# Collecting ace-tools
#   Obtaining dependency information for ace-tools from https://files.pythonhosted.org/packages/27/c4/402d3ae2ecbfe72fbdcb2769f55580f1c54a3ca110c44e1efc034516a499/ace_tools-0.0-py3-none-any.whl.metadata
#   Downloading ace_tools-0.0-py3-none-any.whl.metadata (300 bytes)
# Downloading ace_tools-0.0-py3-none-any.whl (1.1 kB)
# Installing collected packages: ace-tools
# Successfully installed ace-tools-0.0

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#                       CompanyName                        Industry      Sector  \
# 0                      Amgen Inc.      Drug Manufacturers - Major  Healthcare
# 1                      Amgen Inc.      Drug Manufacturers - Major  Healthcare
# 2                      Amgen Inc.      Drug Manufacturers - Major  Healthcare
# 3                 AstraZeneca plc      Drug Manufacturers - Major  Healthcare
# 4                 AstraZeneca plc      Drug Manufacturers - Major  Healthcare
# 5                 AstraZeneca plc      Drug Manufacturers - Major  Healthcare
# 6                        Bayer AG      Drug Manufacturers - Major  Healthcare
# 7                        Bayer AG      Drug Manufacturers - Major  Healthcare
# 8                        Bayer AG      Drug Manufacturers - Major  Healthcare
# 9               Johnson & Johnson      Drug Manufacturers - Major  Healthcare
# 10              Johnson & Johnson      Drug Manufacturers - Major  Healthcare
# 11              Johnson & Johnson      Drug Manufacturers - Major  Healthcare
# 12                   Hologic Inc.  Medical Appliances & Equipment  Healthcare
# 13                   Hologic Inc.  Medical Appliances & Equipment  Healthcare
# 14                   Hologic Inc.  Medical Appliances & Equipment  Healthcare
# 15           Avanos Medical, Inc.  Medical Appliances & Equipment  Healthcare
# 16           Avanos Medical, Inc.  Medical Appliances & Equipment  Healthcare
# 17           Avanos Medical, Inc.  Medical Appliances & Equipment  Healthcare
# 18  Boston Scientific Corporation  Medical Appliances & Equipment  Healthcare
# 19  Boston Scientific Corporation  Medical Appliances & Equipment  Healthcare
# 20  Boston Scientific Corporation  Medical Appliances & Equipment  Healthcare
# 21               Cochlear Limited  Medical Appliances & Equipment  Healthcare
# 22               Cochlear Limited  Medical Appliances & Equipment  Healthcare
# 23               Cochlear Limited  Medical Appliances & Equipment  Healthcare
# 24              CIGNA Corporation               Health Care Plans  Healthcare
# 25              CIGNA Corporation               Health Care Plans  Healthcare
# 26              CIGNA Corporation               Health Care Plans  Healthcare
# 27                     CVS Health               Health Care Plans  Healthcare
# 28                     CVS Health               Health Care Plans  Healthcare
# 29                     CVS Health               Health Care Plans  Healthcare
# 30          Elevance Health, Inc.               Health Care Plans  Healthcare
# 31          Elevance Health, Inc.               Health Care Plans  Healthcare
# 32          Elevance Health, Inc.               Health Care Plans  Healthcare
# 33        UnitedHealth Group Inc.               Health Care Plans  Healthcare
# 34        UnitedHealth Group Inc.               Health Care Plans  Healthcare
# 35        UnitedHealth Group Inc.               Health Care Plans  Healthcare
#
#     Year                                                URL
# 0   2022  https://www.responsibilityreports.com/HostedDa...
# 1   2021  https://www.responsibilityreports.com/HostedDa...
# 2   2020  https://www.responsibilityreports.com/HostedDa...
# 3   2022  https://www.responsibilityreports.com/HostedDa...
# 4   2021  https://www.responsibilityreports.com/HostedDa...
# 5   2020  https://www.responsibilityreports.com/HostedDa...
# 6   2022  https://www.responsibilityreports.com/HostedDa...
# 7   2021  https://www.responsibilityreports.com/HostedDa...
# 8   2020  https://www.responsibilityreports.com/HostedDa...
# 9   2022  https://www.responsibilityreports.com/HostedDa...
# 10  2021  https://www.responsibilityreports.com/HostedDa...
# 11  2020  https://www.responsibilityreports.com/HostedDa...
# 12  2022  https://www.responsibilityreports.com/HostedDa...
# 13  2021  https://www.responsibilityreports.com/HostedDa...
# 14  2020  https://www.responsibilityreports.com/HostedDa...
# 15  2022  https://www.responsibilityreports.com/HostedDa...
# 16  2021  https://www.responsibilityreports.com/HostedDa...
# 17  2020  https://www.responsibilityreports.com/HostedDa...
# 18  2022  https://www.responsibilityreports.com/HostedDa...
# 19  2021  https://www.responsibilityreports.com/HostedDa...
# 20  2020  https://www.responsibilityreports.com/HostedDa...
# 21  2022  https://www.responsibilityreports.com/HostedDa...
# 22  2021  https://www.responsibilityreports.com/HostedDa...
# 23  2020  https://www.responsibilityreports.com/HostedDa...
# 24  2022  https://www.responsibilityreports.com/HostedDa...
# 25  2021  https://www.responsibilityreports.com/HostedDa...
# 26  2020  https://www.responsibilityreports.com/HostedDa...
# 27  2022  https://www.responsibilityreports.com/HostedDa...
# 28  2021  https://www.responsibilityreports.com/HostedDa...
# 29  2020  https://www.responsibilityreports.com/HostedDa...
# 30  2022  https://www.responsibilityreports.com/HostedDa...
# 31  2021  https://www.responsibilityreports.com/HostedDa...
# 32  2020  https://www.responsibilityreports.com/HostedDa...
# 33  2022  https://www.responsibilityreports.com/HostedDa...
# 34  2021  https://www.responsibilityreports.com/HostedDa...
# 35  2020  https://www.responsibilityreports.com/HostedDa...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import pipeline
from tika import parser
import re


tokenizer = AutoTokenizer.from_pretrained("nbroad/ESG-BERT")

model = AutoModelForSequenceClassification.from_pretrained("nbroad/ESG-BERT")

# Create the pipeline for text classification
classifier = pipeline('text-classification', model=model, tokenizer=tokenizer)

max_length = 1024
model_checkpoint = "prajjwal1/bert-medium"
model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint)
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)

tokenizer.model_max_length = max_length
model.config.max_position_embeddings = max_length
model.base_model.embeddings.position_ids = torch.arange(max_length).expand((1, -1))
model.base_model.embeddings.token_type_ids = torch.zeros(max_length).expand((1, -1))
orig_pos_emb = model.base_model.embeddings.position_embeddings.weight
model.base_model.embeddings.position_embeddings.weight = torch.nn.Parameter(torch.cat((orig_pos_emb, orig_pos_emb)))
# Out:
# /Users/martinchen/anaconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:446: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# Some weights of the model checkpoint at prajjwal1/bert-medium were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at prajjwal1/bert-medium and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Create a Class to parse PDF
class PDFParser:
    def __init__(self, file_path):
        self.file_path = file_path
        self.raw = parser.from_file(self.file_path)
        self.text = self.raw['content']

    def get_text(self):
        return self.text

    def get_text_clean(self):
        text = self.text
        text = re.sub(r'\n', ' ', text)
        text = re.sub(r'\s+', ' ', text)
        return text

    def get_text_clean_list(self):
        text = self.get_text_clean()
        text_list = text.split('.')
        return text_list

# %%
def preprocess_text(sentences):
    # Preprocess and split text into manageable parts
    processed_texts = []
    for sentence in sentences:
        tokens = tokenizer.encode(sentence, add_special_tokens=True)
        if len(tokens) > 512:
            # If the sentence exceeds the limit, split it into chunks
            start = 0
            while start < len(tokens):
                chunk = tokens[start:start + 511]  # reserve space for special tokens
                processed_texts.append(tokenizer.decode(chunk))
                start += 511
        else:
            processed_texts.append(sentence)
    return processed_texts

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd
from transformers import pipeline

# Assuming PDFParser and classifier are already defined and imported correctly

def process_company_report(company_name, industry, sector, year, url):
    try:
        pp = PDFParser(url)
        sentences = pp.get_text_clean_list()
        print(f"Processing {company_name} report for {year} with {len(sentences):,d} sentences.")
        results = []

        batch_size = 10
        current_batch = []

        for sentence in sentences:
            # Tokenize the sentence and check its length
            tokens = tokenizer.encode(sentence, add_special_tokens=True, truncation=True, max_length=512)
            truncated_sentence = tokenizer.decode(tokens, skip_special_tokens=True)

            # Accumulate sentences until the batch is full
            if len(current_batch) < batch_size:
                current_batch.append(truncated_sentence)
            else:
                # When batch is full, process it
                if current_batch:
                    results.extend(classifier(current_batch))
                current_batch = [truncated_sentence]  # Start a new batch with the current sentence

        # Process the last batch if it's not empty
        if current_batch:
            results.extend(classifier(current_batch))

        df = pd.DataFrame(results)
        # Add the additional columns for output format
        df['CompanyName'] = company_name
        df['Industry'] = industry
        df['Sector'] = sector
        df['Year'] = year
        return df
    except Exception as e:
        print(f"Failed to process {company_name} for {year} from {url}: {e}")
        return pd.DataFrame()  # Return an empty DataFrame in case of failure

def run_classifier_parallel(company_data_df):
    all_data = []
    company_info = company_data_df[['CompanyName', 'Industry', 'Sector', 'Year', 'URL']].values.tolist()
    with ThreadPoolExecutor() as executor:
        # Submit tasks with the additional information
        future_to_url = {
            executor.submit(process_company_report, company_name, industry, sector, year, url): 
            (company_name, industry, sector, year, url) 
            for company_name, industry, sector, year, url in company_info
        }
        
        for future in as_completed(future_to_url):
            df = future.result()
            if not df.empty:
                all_data.append(df)

    # Concatenate all results into a single DataFrame
    return pd.concat(all_data, ignore_index=True) if all_data else pd.DataFrame()

# Assuming 'df' is the DataFrame with columns 'Company Name', 'Industry', 'Sector', 'Year', and 'URL'
result_data = run_classifier_parallel(df)

print(result_data)
# Out:
# 2024-11-07 22:15:14,070 [ThreadPoolEx] [INFO ]  Retrieving https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/
://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/u/NYSE_UNH_2020.pdf to /var/folders/3n/ym5c9__567b2nsmfm2wz5_br0000gn/T/hosteddata-responsibilityreportarchive-u-nyse_unh_2020.pdf.
# Processing UnitedHealth Group Inc. report for 2020 with 888 sentences.
#                                               label     score  \
# 0                          Access_And_Affordability  0.340901
# 1                              Competitive_Behavior  0.279085
# 2                          Access_And_Affordability  0.656968
# 3      Management_Of_Legal_And_Regulatory_Framework  0.540538
# 4                         Business_Model_Resilience  0.309790
# ...                                             ...       ...
# 81160            Physical_Impacts_Of_Climate_Change  0.910186
# 81161  Management_Of_Legal_And_Regulatory_Framework  0.648359
# 81162                              Customer_Welfare  0.269527
# 81163            Physical_Impacts_Of_Climate_Change  0.910186
# 81164   Employee_Engagement_Inclusion_And_Diversity  0.393710
#
#              CompanyName                    Industry      Sector  Year
# 0        AstraZeneca plc  Drug Manufacturers - Major  Healthcare  2021
# 1        AstraZeneca plc  Drug Manufacturers - Major  Healthcare  2021
# 2        AstraZeneca plc  Drug Manufacturers - Major  Healthcare  2021
# 3        AstraZeneca plc  Drug Manufacturers - Major  Healthcare  2021
# 4        AstraZeneca plc  Drug Manufacturers - Major  Healthcare  2021
# ...                  ...                         ...         ...   ...
# 81160  CIGNA Corporation           Health Care Plans  Healthcare  2020
# 81161  CIGNA Corporation           Health Care Plans  Healthcare  2020
# 81162  CIGNA Corporation           Health Care Plans  Healthcare  2020
# 81163  CIGNA Corporation           Health Care Plans  Healthcare  2020
# 81164  CIGNA Corporation           Health Care Plans  Healthcare  2020
#
# [81165 rows x 6 columns]

# %%
grouped_data = result_data.groupby(['CompanyName', 'Industry', 'Sector', 'Year', 'label']).score.mean().reset_index()

# Pivot the data so each unique label becomes a column, with scores as values
pivoted_data = grouped_data.pivot(index=['CompanyName', 'Industry', 'Sector', 'Year'], columns='label', values='score').reset_index()

# Rename columns to remove multi-index structure created by pivot
pivoted_data.columns.name = None  # Remove the index name

pivoted_data
# Out:
#                       CompanyName                        Industry      Sector  \
# 0                      Amgen Inc.      Drug Manufacturers - Major  Healthcare
# 1                      Amgen Inc.      Drug Manufacturers - Major  Healthcare
# 2                      Amgen Inc.      Drug Manufacturers - Major  Healthcare
# 3                 AstraZeneca plc      Drug Manufacturers - Major  Healthcare
# 4                 AstraZeneca plc      Drug Manufacturers - Major  Healthcare
# 5                 AstraZeneca plc      Drug Manufacturers - Major  Healthcare
# 6            Avanos Medical, Inc.  Medical Appliances & Equipment  Healthcare
# 7            Avanos Medical, Inc.  Medical Appliances & Equipment  Healthcare
# 8            Avanos Medical, Inc.  Medical Appliances & Equipment  Healthcare
# 9                        Bayer AG      Drug Manufacturers - Major  Healthcare
# 10                       Bayer AG      Drug Manufacturers - Major  Healthcare
# 11                       Bayer AG      Drug Manufacturers - Major  Healthcare
# 12  Boston Scientific Corporation  Medical Appliances & Equipment  Healthcare
# 13  Boston Scientific Corporation  Medical Appliances & Equipment  Healthcare
# 14  Boston Scientific Corporation  Medical Appliances & Equipment  Healthcare
# 15              CIGNA Corporation               Health Care Plans  Healthcare
# 16              CIGNA Corporation               Health Care Plans  Healthcare
# 17              CIGNA Corporation               Health Care Plans  Healthcare
# 18                     CVS Health               Health Care Plans  Healthcare
# 19                     CVS Health               Health Care Plans  Healthcare
# 13                   0.414288              0.214626
# 14                   0.496877              0.253574
# 15                   0.492530              0.257238
# 16                   0.465395              0.238055
# 17                   0.442518              0.284892
# 18                   0.396979              0.244625
# 19                   0.399643              0.211544
# 20                   0.422636              0.216152
# 21                   0.360057              0.263049
# 22                   0.403556              0.281472
# 23                   0.510623              0.210060
# 24                   0.400912              0.191047
# 25                   0.424897              0.239820
# 26                   0.379623              0.291787
# 27                   0.391449              0.296558
# 28                   0.404323              0.265049
# 29                   0.361687              0.248768
# 30                   0.365353              0.226094
# 31                   0.388762              0.229444
# 32                   0.555007              0.235703
# 33                   0.422525              0.220935
# 34                   0.460806              0.221538
#
#     Critical_Incident_Risk_Management  ...  Labor_Practices  \
# 0                            0.611724  ...         0.559824
# 1                            0.593990  ...         0.686468
# 2                            0.568351  ...         0.533106
# 3                            0.667499  ...         0.749569
# 4                            0.594196  ...         0.683276
# 5                            0.204364  ...         0.741022
# 6                            0.799637  ...         0.787273
# 7                            0.740210  ...         0.842935
# 8                            0.863162  ...         0.842493
# 9                            0.727791  ...         0.711013
# 10                           0.668481  ...         0.701793
# 11                           0.730785  ...         0.683941
# 12                           0.763565  ...         0.681862
# 13                           0.859032  ...         0.714418
# 14                           0.570319  ...         0.736814
# 15                           0.813141  ...         0.692923
# 16                           0.955411  ...         0.839581
# 17                           0.746692  ...         0.779304
# 18                           0.661678  ...         0.788620
# 19                           0.727816  ...         0.751139
# 20                                NaN  ...         0.640587
# 21                                NaN  ...         0.740944
# 22                           0.479915  ...         0.581778
# 23                           0.971069  ...         0.404437
# 24                           0.761543  ...         0.756894
# 25                           0.775602  ...         0.769122
# 26                           0.792566  ...         0.714939
# 27                           0.750124  ...         0.568391
# 28                           0.482538  ...         0.567103
# 29                           0.645158  ...         0.701139
# 30                           0.720207  ...         0.715941
# 31                           0.626485  ...         0.688994
# 32                           0.597199  ...         0.758506
# 33                           0.760763  ...         0.630860
# 34                           0.621133  ...         0.566391
#
#     Management_Of_Legal_And_Regulatory_Framework  \
# 0                                       0.528019
# 1                                       0.524149
# 2                                       0.494548
# 3                                       0.452209
# 4                                       0.419751
# 5                                       0.468208
# 6                                       0.496993
# 7                                       0.486709
# 8                                       0.565937
# 9                                       0.463574
# 10                                      0.485306
# 11                                      0.472631
# 12                                      0.396300
# 13                                      0.387802
# 14                                      0.369116
# 15                                      0.460460
# 16                                      0.581905
# 17                                      0.510570
# 18                                      0.391721
# 19                                      0.465652
# 20                                      0.416808
# 21                                      0.540097
# 22                                      0.507497
# 23                                      0.367013
# 24                                      0.487248
# 25                                      0.443650
# 26                                      0.495074
# 27                                      0.511700
# 28                                      0.440430
# 29                                      0.391079
# 30                                      0.422467
# 31                                      0.422039
# 32                                      0.438608
# 33                                      0.521476
# 34                                      0.495683
#
#     Physical_Impacts_Of_Climate_Change  \
# 0                             0.766068
# 1                             0.700338
# 2                             0.805487
# 3                             0.797712
# 4                             0.847874
# 5                             0.777058
# 6                                  NaN
# 7                             0.610708
# 8                                  NaN
# 9                             0.639328
# 10                            0.657668
# 11                            0.661757
# 12                            0.870961
# 13                            0.889336
# 14                            0.878094
# 15                            0.807641
# 16                            0.920247
# 17                            0.865790
# 18                            0.745289
# 19                            0.837319
# 20                            0.646760
# 21                            0.686231
# 22                            0.795850
# 23                            0.090893
# 24                            0.863677
# 25                            0.849056
# 26                            0.366852
# 27                            0.731410
# 28                            0.925750
# 29                            0.498123
# 30                            0.542856
# 31                            0.578819
# 32                                 NaN
# 33                            0.798551
# 34                            0.767338
#
#     Product_Design_And_Lifecycle_Management  Product_Quality_And_Safety  \
# 0                                  0.653420                    0.563373
# 1                                  0.667017                    0.673004
# 2                                  0.662221                    0.685324
# 3                                  0.656500                    0.462833
# 4                                  0.651687                    0.444614
# 5                                  0.654430                    0.529257
# 6                                  0.716462                    0.632381
# 7                                  0.617583                    0.644806
# 8                                  0.666240                    0.641077
# 9                                  0.720330                    0.627021
# 10                                 0.737523                    0.639090
# 11                                 0.753657                    0.639537
# 12                                 0.646775                    0.530575
# 13                                 0.705186                    0.594632
# 14                                 0.674426                    0.618443
# 15                                 0.502976                    0.322941
# 16                                 0.513984                    0.239582
# 17                                 0.577281                    0.423197
# 18                                 0.735705                    0.426746
# 19                                 0.567578                    0.504954
# 20                                 0.605098                    0.634203
# 21                                 0.603082                    0.681831
# 22                                 0.643335                    0.509271
# 23                                 0.130910                    0.208220
# 24                                 0.454370                    0.301476
# 25                                 0.486801                    0.254506
# 26                                 0.639755                    0.465657
# 27                                 0.693783                    0.486852
# 28                                 0.632263                    0.489182
# 29                                 0.677023                    0.528683
# 30                                 0.622351                    0.570829
# 31                                 0.638429                    0.521266
# 32                                 0.505508                    0.527446
# 33                                 0.430458                    0.320420
# 34                                 0.482439                    0.264692
#
#     Selling_Practices_And_Product_Labeling  Supply_Chain_Management  \
# 0                                 0.473794                 0.243049
# 1                                 0.423807                 0.216817
# 2                                 0.374829                 0.317656
# 3                                 0.512877                 0.794841
# 4                                 0.535195                 0.770781
# 5                                 0.270332                 0.784577
# 6                                 0.645623                 0.744499
# 7                                 0.645623                 0.749767
# 8                                 0.645623                 0.749725
# 9                                 0.559500                 0.696585
# 10                                0.558156                 0.656513
# 11                                0.553393                 0.663460
# 12                                0.503682                 0.741737
# 13                                0.714805                 0.797914
# 14                                0.673244                 0.781810
# 15                                0.294650                 0.755651
# 16                                     NaN                 0.680282
# 17                                0.418059                 0.750697
# 18                                0.573333                 0.673668
# 19                                0.290130                 0.804854
# 20                                0.368456                 0.920759
# 21                                0.361346                 0.852064
# 22                                0.370758                 0.799157
# 23                                     NaN                      NaN
# 24                                0.245196                 0.741887
# 25                                0.254505                 0.782700
# 26                                0.588377                 0.779011
# 27                                0.629723                 0.844693
# 28                                0.528418                 0.886290
# 29                                0.303718                 0.794550
# 30                                0.318632                 0.776698
# 31                                0.366960                 0.791980
# 32                                     NaN                 0.834004
# 33                                0.368207                 0.841580
# 34                                0.289970                 0.819152
#
#     Systemic_Risk_Management  Waste_And_Hazardous_Materials_Management  \
# 0                   0.511720                                  0.914585
# 1                   0.486892                                  0.755648
# 2                   0.474715                                  0.910131
# 3                   0.452684                                  0.920139
# 4                   0.448741                                  0.873677
# 5                   0.434794                                  0.892388
# 6                   0.385688                                  0.895167
# 7                   0.385688                                  0.913885
# 8                   0.341507                                  0.845486
# 9                   0.550496                                  0.319860
# 10                  0.556490                                  0.320820
# 11                  0.557454                                  0.323681
# 12                  0.496631                                  0.777861
# 13                  0.506547                                  0.569270
# 14                  0.531512                                  0.525303
# 15                  0.528383                                  0.786952
# 16                  0.419601                                  0.982486
# 17                  0.535810                                  0.883529
# 18                  0.240621                                  0.851765
# 19                  0.274907                                  0.940593
# 20                  0.613284                                  0.775917
# 21                  0.636257                                  0.663597
# 22                  0.552998                                  0.925233
# 23                  0.708584                                  0.104235
# 24                  0.570878                                  0.702597
# 25                  0.657416                                  0.632412
# 26                  0.542162                                  0.792028
# 27                  0.502508                                  0.797760
# 28                  0.569316                                  0.847249
# 29                  0.389013                                  0.861757
# 30                  0.368781                                  0.590390
# 31                  0.374672                                  0.782612
# 32                  0.628116                                  0.827019
# 33                  0.575560                                  0.977440
# 34                  0.428714                                  0.827856
#
#     Water_And_Wastewater_Management
# 0                          0.946340
# 1                          0.812780
# 2                          0.883247
# 3                          0.915620
# 4                          0.843332
# 5                          0.853952
# 6                          0.772111
# 7                          0.732053
# 8                          0.845534
# 9                          0.913034
# 10                         0.922385
# 11                         0.875364
# 12                         0.972888
# 13                         0.904639
# 14                         0.957917
# 15                         0.886033
# 16                         0.959697
# 17                         0.911523
# 18                         0.968182
# 19                         0.969429
# 20                         0.830308
# 21                         0.966613
# 22                         0.967963
# 23                              NaN
# 24                         0.926504
# 25                         0.915287
# 26                         0.140488
# 27                         0.395949
# 28                         0.859291
# 29                         0.800673
# 30                         0.816309
# 31                         0.871120
# 32                         0.871429
# 33                         0.943833
# 34                         0.974259
#
# [35 rows x 30 columns]

# %% [markdown]
# # Data Cleaning

# %%
pivoted_data = pivoted_data.fillna(0)
pivoted_data = pivoted_data.round(2)

pivoted_data
# Out:
#                       CompanyName                        Industry      Sector  \
# 0                      Amgen Inc.      Drug Manufacturers - Major  Healthcare
# 1                      Amgen Inc.      Drug Manufacturers - Major  Healthcare
# 2                      Amgen Inc.      Drug Manufacturers - Major  Healthcare
# 3                 AstraZeneca plc      Drug Manufacturers - Major  Healthcare
# 4                 AstraZeneca plc      Drug Manufacturers - Major  Healthcare
# 5                 AstraZeneca plc      Drug Manufacturers - Major  Healthcare
# 6            Avanos Medical, Inc.  Medical Appliances & Equipment  Healthcare
# 7            Avanos Medical, Inc.  Medical Appliances & Equipment  Healthcare
# 8            Avanos Medical, Inc.  Medical Appliances & Equipment  Healthcare
# 9                        Bayer AG      Drug Manufacturers - Major  Healthcare
# 10                       Bayer AG      Drug Manufacturers - Major  Healthcare
# 11                       Bayer AG      Drug Manufacturers - Major  Healthcare
# 12  Boston Scientific Corporation  Medical Appliances & Equipment  Healthcare
# 13  Boston Scientific Corporation  Medical Appliances & Equipment  Healthcare
# 10                       0.38                  0.37
# 11                       0.37                  0.38
# 12                       0.50                  0.25
# 13                       0.41                  0.21
# 14                       0.50                  0.25
# 15                       0.49                  0.26
# 16                       0.47                  0.24
# 17                       0.44                  0.28
# 18                       0.40                  0.24
# 19                       0.40                  0.21
# 20                       0.42                  0.22
# 21                       0.36                  0.26
# 22                       0.40                  0.28
# 23                       0.51                  0.21
# 24                       0.40                  0.19
# 25                       0.42                  0.24
# 26                       0.38                  0.29
# 27                       0.39                  0.30
# 28                       0.40                  0.27
# 29                       0.36                  0.25
# 30                       0.37                  0.23
# 31                       0.39                  0.23
# 32                       0.56                  0.24
# 33                       0.42                  0.22
# 34                       0.46                  0.22
#
#     Critical_Incident_Risk_Management  ...  Labor_Practices  \
# 0                                0.61  ...             0.56
# 1                                0.59  ...             0.69
# 2                                0.57  ...             0.53
# 3                                0.67  ...             0.75
# 4                                0.59  ...             0.68
# 5                                0.20  ...             0.74
# 6                                0.80  ...             0.79
# 7                                0.74  ...             0.84
# 8                                0.86  ...             0.84
# 9                                0.73  ...             0.71
# 10                               0.67  ...             0.70
# 11                               0.73  ...             0.68
# 12                               0.76  ...             0.68
# 13                               0.86  ...             0.71
# 14                               0.57  ...             0.74
# 15                               0.81  ...             0.69
# 16                               0.96  ...             0.84
# 17                               0.75  ...             0.78
# 18                               0.66  ...             0.79
# 19                               0.73  ...             0.75
# 20                               0.00  ...             0.64
# 21                               0.00  ...             0.74
# 22                               0.48  ...             0.58
# 23                               0.97  ...             0.40
# 24                               0.76  ...             0.76
# 25                               0.78  ...             0.77
# 26                               0.79  ...             0.71
# 27                               0.75  ...             0.57
# 28                               0.48  ...             0.57
# 29                               0.65  ...             0.70
# 30                               0.72  ...             0.72
# 31                               0.63  ...             0.69
# 32                               0.60  ...             0.76
# 33                               0.76  ...             0.63
# 34                               0.62  ...             0.57
#
#     Management_Of_Legal_And_Regulatory_Framework  \
# 0                                           0.53
# 1                                           0.52
# 2                                           0.49
# 3                                           0.45
# 4                                           0.42
# 5                                           0.47
# 6                                           0.50
# 7                                           0.49
# 8                                           0.57
# 9                                           0.46
# 10                                          0.49
# 11                                          0.47
# 12                                          0.40
# 13                                          0.39
# 14                                          0.37
# 15                                          0.46
# 16                                          0.58
# 17                                          0.51
# 18                                          0.39
# 19                                          0.47
# 20                                          0.42
# 21                                          0.54
# 22                                          0.51
# 23                                          0.37
# 24                                          0.49
# 25                                          0.44
# 26                                          0.50
# 27                                          0.51
# 28                                          0.44
# 29                                          0.39
# 30                                          0.42
# 31                                          0.42
# 32                                          0.44
# 33                                          0.52
# 34                                          0.50
#
#     Physical_Impacts_Of_Climate_Change  \
# 0                                 0.77
# 1                                 0.70
# 2                                 0.81
# 3                                 0.80
# 4                                 0.85
# 5                                 0.78
# 6                                 0.00
# 7                                 0.61
# 8                                 0.00
# 9                                 0.64
# 10                                0.66
# 11                                0.66
# 12                                0.87
# 13                                0.89
# 14                                0.88
# 15                                0.81
# 16                                0.92
# 17                                0.87
# 18                                0.75
# 19                                0.84
# 20                                0.65
# 21                                0.69
# 22                                0.80
# 23                                0.09
# 24                                0.86
# 25                                0.85
# 26                                0.37
# 27                                0.73
# 28                                0.93
# 29                                0.50
# 30                                0.54
# 31                                0.58
# 32                                0.00
# 33                                0.80
# 34                                0.77
#
#     Product_Design_And_Lifecycle_Management  Product_Quality_And_Safety  \
# 0                                      0.65                        0.56
# 1                                      0.67                        0.67
# 2                                      0.66                        0.69
# 3                                      0.66                        0.46
# 4                                      0.65                        0.44
# 5                                      0.65                        0.53
# 6                                      0.72                        0.63
# 7                                      0.62                        0.64
# 8                                      0.67                        0.64
# 9                                      0.72                        0.63
# 10                                     0.74                        0.64
# 11                                     0.75                        0.64
# 12                                     0.65                        0.53
# 13                                     0.71                        0.59
# 14                                     0.67                        0.62
# 15                                     0.50                        0.32
# 16                                     0.51                        0.24
# 17                                     0.58                        0.42
# 18                                     0.74                        0.43
# 19                                     0.57                        0.50
# 20                                     0.61                        0.63
# 21                                     0.60                        0.68
# 22                                     0.64                        0.51
# 23                                     0.13                        0.21
# 24                                     0.45                        0.30
# 25                                     0.49                        0.25
# 26                                     0.64                        0.47
# 27                                     0.69                        0.49
# 28                                     0.63                        0.49
# 29                                     0.68                        0.53
# 30                                     0.62                        0.57
# 31                                     0.64                        0.52
# 32                                     0.51                        0.53
# 33                                     0.43                        0.32
# 34                                     0.48                        0.26
#
#     Selling_Practices_And_Product_Labeling  Supply_Chain_Management  \
# 0                                     0.47                     0.24
# 1                                     0.42                     0.22
# 2                                     0.37                     0.32
# 3                                     0.51                     0.79
# 4                                     0.54                     0.77
# 5                                     0.27                     0.78
# 6                                     0.65                     0.74
# 7                                     0.65                     0.75
# 8                                     0.65                     0.75
# 9                                     0.56                     0.70
# 10                                    0.56                     0.66
# 11                                    0.55                     0.66
# 12                                    0.50                     0.74
# 13                                    0.71                     0.80
# 14                                    0.67                     0.78
# 15                                    0.29                     0.76
# 16                                    0.00                     0.68
# 17                                    0.42                     0.75
# 18                                    0.57                     0.67
# 19                                    0.29                     0.80
# 20                                    0.37                     0.92
# 21                                    0.36                     0.85
# 22                                    0.37                     0.80
# 23                                    0.00                     0.00
# 24                                    0.25                     0.74
# 25                                    0.25                     0.78
# 26                                    0.59                     0.78
# 27                                    0.63                     0.84
# 28                                    0.53                     0.89
# 29                                    0.30                     0.79
# 30                                    0.32                     0.78
# 31                                    0.37                     0.79
# 32                                    0.00                     0.83
# 33                                    0.37                     0.84
# 34                                    0.29                     0.82
#
#     Systemic_Risk_Management  Waste_And_Hazardous_Materials_Management  \
# 0                       0.51                                      0.91
# 1                       0.49                                      0.76
# 2                       0.47                                      0.91
# 3                       0.45                                      0.92
# 4                       0.45                                      0.87
# 5                       0.43                                      0.89
# 6                       0.39                                      0.90
# 7                       0.39                                      0.91
# 8                       0.34                                      0.85
# 9                       0.55                                      0.32
# 10                      0.56                                      0.32
# 11                      0.56                                      0.32
# 12                      0.50                                      0.78
# 13                      0.51                                      0.57
# 14                      0.53                                      0.53
# 15                      0.53                                      0.79
# 16                      0.42                                      0.98
# 17                      0.54                                      0.88
# 18                      0.24                                      0.85
# 19                      0.27                                      0.94
# 20                      0.61                                      0.78
# 21                      0.64                                      0.66
# 22                      0.55                                      0.93
# 23                      0.71                                      0.10
# 24                      0.57                                      0.70
# 25                      0.66                                      0.63
# 26                      0.54                                      0.79
# 27                      0.50                                      0.80
# 28                      0.57                                      0.85
# 29                      0.39                                      0.86
# 30                      0.37                                      0.59
# 31                      0.37                                      0.78
# 32                      0.63                                      0.83
# 33                      0.58                                      0.98
# 34                      0.43                                      0.83
#
#     Water_And_Wastewater_Management
# 0                              0.95
# 1                              0.81
# 2                              0.88
# 3                              0.92
# 4                              0.84
# 5                              0.85
# 6                              0.77
# 7                              0.73
# 8                              0.85
# 9                              0.91
# 10                             0.92
# 11                             0.88
# 12                             0.97
# 13                             0.90
# 14                             0.96
# 15                             0.89
# 16                             0.96
# 17                             0.91
# 18                             0.97
# 19                             0.97
# 20                             0.83
# 21                             0.97
# 22                             0.97
# 23                             0.00
# 24                             0.93
# 25                             0.92
# 26                             0.14
# 27                             0.40
# 28                             0.86
# 29                             0.80
# 30                             0.82
# 31                             0.87
# 32                             0.87
# 33                             0.94
# 34                             0.97
#
# [35 rows x 30 columns]

# %%
pivoted_data.to_csv('esg_data.csv', index=False)

# %%
import pandas as pd


# Define the categories
environmental_labels = ['Air_Quality', 'Ecological_Impacts', 'Energy_Management', 'GHG_Emissions',
                        'Physical_Impacts_Of_Climate_Change', 'Product_Design_And_Lifecycle_Management',
                        'Waste_And_Hazardous_Materials_Management', 'Water_And_Wastewater_Management']

social_labels = ['Access_And_Affordability', 'Customer_Privacy', 'Customer_Welfare',
                 'Employee_Engagement_Inclusion_And_Diversity', 'Employee_Health_And_Safety',
                 'Human_Rights_And_Community_Relations', 'Labor_Practices']

governance_labels = ['Business_Ethics', 'Business_Model_Resilience', 'Competitive_Behavior',
                     'Critical_Incident_Risk_Management', 'Data_Security', 'Director_Removal',
                     'Management_Of_Legal_And_Regulatory_Framework', 'Product_Quality_And_Safety',
                     'Selling_Practices_And_Product_Labeling', 'Supply_Chain_Management', 'Systemic_Risk_Management']

# Sum the scores in each category and then divide by the total number of non-NaN entries for each row to get the average
pivoted_data['E_Score'] = pivoted_data[environmental_labels].sum(axis=1) 
pivoted_data['S_Score'] = pivoted_data[social_labels].sum(axis=1) 
pivoted_data['G_Score'] = pivoted_data[governance_labels].sum(axis=1) 
pivoted_data['ESG_Score'] = pivoted_data['E_Score'] + pivoted_data['S_Score'] + pivoted_data['G_Score']

# Display the updated DataFrame
pivoted_data1 = pivoted_data[['CompanyName', 'Year', 'E_Score', 'S_Score', 'G_Score', 'ESG_Score']]
pivoted_data1
# Out:
#                       CompanyName  Year  E_Score  S_Score  G_Score  ESG_Score
# 0                      Amgen Inc.  2020     5.66     3.96     5.96      15.58
# 1                      Amgen Inc.  2021     5.50     3.54     5.39      14.43
# 2                      Amgen Inc.  2022     5.83     3.32     5.44      14.59
# 3                 AstraZeneca plc  2020     6.08     4.04     6.01      16.13
# 9                        0.37                  0.36
# 10                       0.38                  0.37
# 11                       0.37                  0.38
# 12                       0.50                  0.25
# 13                       0.41                  0.21
# 14                       0.50                  0.25
# 15                       0.49                  0.26
# 16                       0.47                  0.24
# 17                       0.44                  0.28
# 18                       0.40                  0.24
# 19                       0.40                  0.21
# 20                       0.42                  0.22
# 21                       0.36                  0.26
# 22                       0.40                  0.28
# 23                       0.51                  0.21
# 24                       0.40                  0.19
# 25                       0.42                  0.24
# 26                       0.38                  0.29
# 27                       0.39                  0.30
# 28                       0.40                  0.27
# 29                       0.36                  0.25
# 30                       0.37                  0.23
# 31                       0.39                  0.23
# 32                       0.56                  0.24
# 33                       0.42                  0.22
# 34                       0.46                  0.22
#
#     Critical_Incident_Risk_Management  ...  Product_Quality_And_Safety  \
# 0                                0.61  ...                        0.56
# 1                                0.59  ...                        0.67
# 2                                0.57  ...                        0.69
# 3                                0.67  ...                        0.46
# 4                                0.59  ...                        0.44
# 5                                0.20  ...                        0.53
# 6                                0.80  ...                        0.63
# 7                                0.74  ...                        0.64
# 8                                0.86  ...                        0.64
# 9                                0.73  ...                        0.63
# 10                               0.67  ...                        0.64
# 11                               0.73  ...                        0.64
# 12                               0.76  ...                        0.53
# 13                               0.86  ...                        0.59
# 14                               0.57  ...                        0.62
# 15                               0.81  ...                        0.32
# 16                               0.96  ...                        0.24
# 17                               0.75  ...                        0.42
# 18                               0.66  ...                        0.43
# 19                               0.73  ...                        0.50
# 20                               0.00  ...                        0.63
# 21                               0.00  ...                        0.68
# 22                               0.48  ...                        0.51
# 23                               0.97  ...                        0.21
# 24                               0.76  ...                        0.30
# 25                               0.78  ...                        0.25
# 26                               0.79  ...                        0.47
# 27                               0.75  ...                        0.49
# 28                               0.48  ...                        0.49
# 29                               0.65  ...                        0.53
# 30                               0.72  ...                        0.57
# 31                               0.63  ...                        0.52
# 32                               0.60  ...                        0.53
# 33                               0.76  ...                        0.32
# 34                               0.62  ...                        0.26
#
#     Selling_Practices_And_Product_Labeling  Supply_Chain_Management  \
# 0                                     0.47                     0.24
# 1                                     0.42                     0.22
# 2                                     0.37                     0.32
# 3                                     0.51                     0.79
# 4                                     0.54                     0.77
# 5                                     0.27                     0.78
# 6                                     0.65                     0.74
# 7                                     0.65                     0.75
# 8                                     0.65                     0.75
# 9                                     0.56                     0.70
# 10                                    0.56                     0.66
# 11                                    0.55                     0.66
# 12                                    0.50                     0.74
# 13                                    0.71                     0.80
# 14                                    0.67                     0.78
# 15                                    0.29                     0.76
# 16                                    0.00                     0.68
# 17                                    0.42                     0.75
# 18                                    0.57                     0.67
# 19                                    0.29                     0.80
# 20                                    0.37                     0.92
# 21                                    0.36                     0.85
# 22                                    0.37                     0.80
# 23                                    0.00                     0.00
# 24                                    0.25                     0.74
# 25                                    0.25                     0.78
# 26                                    0.59                     0.78
# 27                                    0.63                     0.84
# 28                                    0.53                     0.89
# 29                                    0.30                     0.79
# 30                                    0.32                     0.78
# 31                                    0.37                     0.79
# 32                                    0.00                     0.83
# 33                                    0.37                     0.84
